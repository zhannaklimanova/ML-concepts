# %% [markdown]
# # **SECTION 0: Imports**

# %%
import sys

import random

import numpy as np

import pandas as pd 

from typing import List
from tqdm import tqdm
import collections

import tensorflow as tf
import keras
from keras.utils import np_utils

import pickle
import copy

import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import keras
import tensorflow
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers import BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import model_from_json
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPool2D, Dropout, MaxPooling2D, Activation, ZeroPadding2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

np.random.seed(0)

# %% [markdown]
# # **SECTION 1: Data Preprocessing**

# %% [markdown]
# ### Data Acquisition

# %% [markdown]
# Associated Labels:
# *   0: T-shirt/top1
# *   1: Trouser
# *   2: Pullover
# *   3: Dress
# *   4: Coat
# *   5: Sandal
# *   6: Shirt
# *   7: Sneaker
# *   8: Bag
# *   9: Ankle boot

# %%
# Import dataset
fashion_data = tf.keras.datasets.fashion_mnist
(X_train_fashion_original, y_train_fashion_original), (X_test_fashion_original, y_test_fashion_original) = fashion_data.load_data()
assert X_train_fashion_original.shape == (60000, 28, 28)
assert X_test_fashion_original.shape == (10000, 28, 28)
assert y_train_fashion_original.shape == (60000,)
assert y_test_fashion_original.shape == (10000,)

# %%
# Verify train dataset correctness
plt.imshow(X_train_fashion_original[0], cmap='gray')
plt.show()
print("Label:", y_train_fashion_original[0])
# Out:
# Label: 9

# %%
# Verify test dataset correctness
plt.imshow(X_test_fashion_original[78], cmap='gray')
plt.show()
print("Label:", y_test_fashion_original[78])
# Out:
# Label: 8

# %%
# Data exploration
print("X_train_fashion dataset shape: ", X_train_fashion_original.shape)
print("y_train_fashion dataset shape: ", y_train_fashion_original.shape)
print("X_test_fashion dataset shape: ", X_test_fashion_original.shape)
print("y_test_fashion dataset shape: ", y_test_fashion_original.shape)
print("Train class distribution: ", collections.Counter(y_train_fashion_original))
print("Test class distribution: ", collections.Counter(y_test_fashion_original))
print("Check train dataset for any NaN values: ", any(np.isnan(X_train_fashion_original.shape)))
print("Check test dataset for any NaN values: ", any(np.isnan(X_test_fashion_original.shape)))
# Out:
# X_train_fashion dataset shape:  (60000, 28, 28)
# y_train_fashion dataset shape:  (60000,)
# X_test_fashion dataset shape:  (10000, 28, 28)
# y_test_fashion dataset shape:  (10000,)
# Train class distribution:  Counter({9: 6000, 0: 6000, 3: 6000, 2: 6000, 7: 6000, 5: 6000, 1: 6000, 6: 6000, 4: 6000, 8: 6000})
# Test class distribution:  Counter({9: 1000, 2: 1000, 1: 1000, 6: 1000, 4: 1000, 5: 1000, 7: 1000, 3: 1000, 8: 1000, 0: 1000})
# Check train dataset for any NaN values:  False
# Check test dataset for any NaN values:  False

# %% [markdown]
# ### Fashion-MNIST Un-Normalized

# %%
X_train_fashion = X_train_fashion_original.reshape(X_train_fashion_original.shape[0], -1); # (60000, 784)
y_train_fashion = y_train_fashion_original # (60000, 1)
X_test_fashion = X_test_fashion_original.reshape(X_test_fashion_original.shape[0], -1) # (10000, 784)
y_test_fashion = y_test_fashion_original # (10000, 1)
print(X_train_fashion.shape)
print(y_train_fashion.shape)
print(X_test_fashion.shape)
print(y_test_fashion.shape)

plt.imshow(X_train_fashion[0].reshape(28,28), cmap='gray')
plt.show()
print("Label:", y_train_fashion[0])
# Out:
# (60000, 784)
# (60000,)
# (10000, 784)
# (10000,)
# Label: 9

# %% [markdown]
# ### Fashion-MNIST Normalized

# %%
# Normalize data
scaler = MinMaxScaler()
X_train_fashion_normalized = scaler.fit_transform(X_train_fashion)
X_test_fashion_normalized = scaler.fit_transform(X_test_fashion)

X_train_fashion_normalized_v2 = X_train_fashion / 255.0
X_test_fashion_v2 = X_test_fashion / 255.0

# %% [markdown]
# ### Data Normalized with StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_fashion_std = scaler.fit_transform(X_train_fashion)
X_test_fashion_std = scaler.fit_transform(X_test_fashion)

# %% [markdown]
# # **SECTION 2: Machine Learning Algorithm Implementations**

# %% [markdown]
# ## **MLP Implementation 1**

# %% [markdown]
# ### Layer Classes

# %%
class NeuralNetLayer:
    def __init__(self):
        self.gradient = None
        self.parameters = None
        
    def forward(self, x):
        raise NotImplementedError

    def backward(self, gradient):
        raise NotImplementedError

# %%
class LinearLayer(NeuralNetLayer):
    def __init__(self, input_size, output_size, l2_regularization_weight=0):
        super().__init__()
        self.ni = input_size
        self.no = output_size
        self.w = np.random.randn(output_size, input_size)
        self.b = np.random.randn(output_size)
        self.cur_input = None
        self.l2_regularization_weight = l2_regularization_weight
        self.parameters = [self.w, self.b]

    def forward(self, x):
        self.cur_input = x
        return (self.w[None, :, :] @ x[:, :, None]).squeeze() + self.b

    def backward(self, gradient):
        assert self.cur_input is not None, "Must call forward before backward"
        dw = gradient[:, :, None] @ self.cur_input[:, None, :]
        db = gradient

        if self.l2_regularization_weight > 0:
          dw += self.l2_regularization_weight * self.w

        self.gradient = [dw, db]
        return gradient.dot(self.w)

# %%
class ReLULayer(NeuralNetLayer):
    def __init__(self):
        super().__init__()
        
    def forward(self, x):
        self.gradient = np.where(x > 0, 1.0, 0.0)
        return np.maximum(0, x)

    def backward(self, gradient):
        assert self.gradient is not None, "Must call forward before backward"
        return gradient * self.gradient

# %%
class SoftmaxOutputLayer(NeuralNetLayer):
    def __init__(self):
        super().__init__()
        self.cur_probs = None

    def forward(self, x):
        exps = np.exp(x - np.max(x, axis=-1, keepdims=True))
        probs = exps / np.sum(exps, axis=-1)[:, None]
        self.cur_probs = probs
        return probs

    def backward(self, target):
        assert self.cur_probs is not None, "Must call forward before backward"
        return self.cur_probs - target

# %% [markdown]
# ### MLP Class

# %%
# evaluate the model accuracy
def evaluate_acc(y, yh):
    accuracy = sum(yh == y) / y.shape[0]
    return accuracy

# %%
class MLP:
    def __init__(self, *args: List[NeuralNetLayer]):
        self.layers = args

    def forward(self, x):
        for layer in self.layers:
            x = layer.forward(x)
        return x

    def backward(self, target):
        for layer in self.layers[::-1]:
            target = layer.backward(target)

    def fit(self, optimizer, data_x, data_y, steps, batch_size, showplot=False):
        print("")
        losses = []
        accuracies = []
        for i in tqdm(range(1, steps + 1)):
            # Generate batch
            indices = np.random.choice(60000, batch_size)
            x, y = data_x[indices], data_y[indices]
            labels = np.eye(10)[np.array(y)]
            # Forward pass
            predictions = self.forward(x)
            # Calculate loss
            if showplot:
                loss = -(labels * np.log(predictions+1e-300)).sum(axis=-1).mean()
                losses.append(loss)
                acc = evaluate_acc(y, np.argmax(predictions, axis=1))
                accuracies.append(acc)
            # Backward pass
            self.backward(labels)
            # Optimize
            optimizer.step()
        if showplot:
            plt.figure(figsize=(15,5))
            plt.subplot(121), plt.plot(losses)
            plt.title("Plot of CE as function of Epochs"), plt.xlabel("Epoch"), plt.ylabel("Cross entropy loss")
            plt.subplot(122), plt.plot(accuracies)
            plt.title("Plot of Accuracy as function of Epochs"), plt.xlabel("Epoch"), plt.ylabel("Train accuracy")

    def predict(self, data_x):
        predictions = self.forward(data_x)
        return np.argmax(predictions, axis=1)

# %% [markdown]
# ### Optimizer Class

# %%
class Optimizer:
    def __init__(self, net: MLP):
        self.net = net

    def step(self):
        for layer in self.net.layers[::-1]:
            if layer.parameters is not None:
                self.update(layer.parameters, layer.gradient)

    def update(self, params, gradient):
        raise NotImplementedError

class GradientDescentOptimizer(Optimizer):
    def __init__(self, net: MLP, lr: float):
        super().__init__(net)
        self.lr = lr

    def update(self, params, gradient):
        for (p, g) in zip(params, gradient):
            p -= self.lr * g.mean(axis=0)

# %% [markdown]
# ## **MLP Implementation 2**

# %%
class Layer_Dense:
    # Layer initialization
    def __init__(self, n_inputs, n_neurons, weight_regularizer_l2=0, bias_regularizer_l2=0):
        self.weights = 0.01 * np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1, n_neurons))
        self.weight_regularizer_l2 = weight_regularizer_l2
        self.bias_regularizer_l2 = bias_regularizer_l2

    def forward(self, inputs, training):
        self.inputs = inputs
        self.output = np.matmul(inputs, self.weights) + self.biases

    def backward(self, dvalues):
        self.dweights = np.dot(self.inputs.T, dvalues)
        self.dbiases = np.sum(dvalues, axis=0, keepdims=True)

        if self.weight_regularizer_l2 > 0:
            self.dweights += 2 * self.weight_regularizer_l2 * self.weights
        if self.bias_regularizer_l2 > 0:
            self.dbiases += 2 * self.bias_regularizer_l2 * self.biases
        
        self.dinputs = np.dot(dvalues, self.weights.T)

    def get_parameters(self):
        return self.weights, self.biases

    def set_parameters(self, weights, biases):
        self.weights = weights
        self.biases = biases

class Activation_Leaky_ReLU:
    def __init__(self, alpha=0.01):
        self.alpha = alpha

    def forward(self, inputs, training):
        self.inputs = inputs
        self.output = np.where(inputs > 0, inputs, inputs * self.alpha)  

    def backward(self, dvalues):
        self.dinputs = dvalues.copy()
        self.dinputs = dvalues*(np.where(self.inputs >= 0, 1, self.alpha))

    def predictions(self, outputs):
        return outputs

class Activation_ReLU:
    def forward(self, inputs, training):
        self.inputs = inputs
        self.output = np.maximum(0, inputs)

    def backward(self, dvalues):
        self.dinputs = dvalues.copy()
        self.dinputs[self.inputs <= 0] = 0

    def predictions(self, outputs):
        return outputs


class Activation_Tanh:
    def forward(self, inputs, training):
        self.inputs = inputs
        self.output = np.tanh(inputs)

    def backward(self, dvalues):
        self.dinputs = dvalues*(1.-((self.output)**2))

    def predictions(self, outputs):
        return outputs

class Activation_Softmax:
    def forward(self, inputs, training):
        self.inputs = inputs
        exp_values = np.exp(inputs - np.max(inputs, axis=1, keepdims=True))
        probabilities = exp_values / np.sum(exp_values, axis=1, keepdims=True)

        self.output = probabilities

    def backward(self, dvalues):
        self.dinputs = np.empty_like(dvalues)

        for index, (single_output, single_dvalues) in enumerate(zip(self.output, dvalues)):
            single_output = single_output.reshape(-1, 1)
            jacobian_matrix = np.diagflat(single_output) - np.dot(single_output, single_output.T)
            self.dinputs[index] = np.dot(jacobian_matrix, single_dvalues)

    def predictions(self, outputs):
        return np.argmax(outputs, axis=1)

class Optimizer_SGD:
    def __init__(self, learning_rate=1., decay=0., momentum=0.):
        self.learning_rate = learning_rate
        self.current_learning_rate = learning_rate
        self.decay = decay
        self.iterations = 0
        self.momentum = momentum

    # Call once before any parameter updates
    def pre_update_params(self):
        if self.decay:
            self.current_learning_rate = self.learning_rate * (1. / (1. + self.decay * self.iterations))

    def update_params(self, layer):
        if self.momentum:
            if not hasattr(layer, 'weight_momentums'):
                layer.weight_momentums = np.zeros_like(layer.weights)
                layer.bias_momentums = np.zeros_like(layer.biases)
            weight_updates = self.momentum * layer.weight_momentums - self.current_learning_rate * layer.dweights
            layer.weight_momentums = weight_updates

            bias_updates = self.momentum * layer.bias_momentums - self.current_learning_rate * layer.dbiases
            layer.bias_momentums = bias_updates

        else:
            weight_updates = -self.current_learning_rate * layer.dweights
            bias_updates = -self.current_learning_rate * layer.dbiases

        layer.weights += weight_updates
        layer.biases += bias_updates

    def post_update_params(self):
        self.iterations += 1

class Loss:
    def regularization_loss(self):
        regularization_loss = 0
        for layer in self.trainable_layers:
            if layer.weight_regularizer_l2 > 0:
                regularization_loss += layer.weight_regularizer_l2 * np.sum(layer.weights * layer.weights)
            if layer.bias_regularizer_l2 > 0:
                regularization_loss += layer.bias_regularizer_l2 * np.sum(layer.biases * layer.biases)
        return regularization_loss

    def remember_trainable_layers(self, trainable_layers):
        self.trainable_layers = trainable_layers

    def calculate(self, output, y, *, include_regularization=False):
        sample_losses = self.forward(output, y)
        data_loss = np.mean(sample_losses)
        self.accumulated_sum += np.sum(sample_losses)
        self.accumulated_count += len(sample_losses)
        if not include_regularization:
            return data_loss
        return data_loss, self.regularization_loss()

    def calculate_accumulated(self, *, include_regularization=False):
        data_loss = self.accumulated_sum / self.accumulated_count
        if not include_regularization:
            return data_loss
        return data_loss, self.regularization_loss()

    def new_pass(self):
        self.accumulated_sum = 0
        self.accumulated_count = 0

class Loss_CategoricalCrossentropy(Loss):
    def forward(self, y_pred, y_true):
        samples = len(y_pred)
        y_pred_clipped = np.clip(y_pred, 1e-7, 1 - 1e-7) # clip data to prevent division by 0
        if len(y_true.shape) == 1:
            correct_confidences = y_pred_clipped[range(samples),y_true]
        elif len(y_true.shape) == 2:
            correct_confidences = np.sum(y_pred_clipped * y_true, axis=1)
        negative_log_likelihoods = -np.log(correct_confidences)
        return negative_log_likelihoods

    def backward(self, dvalues, y_true):
        samples = len(dvalues)
        labels = len(dvalues[0])
        if len(y_true.shape) == 1:
            y_true = np.eye(labels)[y_true]

        self.dinputs = -y_true / dvalues
        self.dinputs = self.dinputs / samples # normalizing gradient output value

class Activation_Softmax_Loss_CategoricalCrossentropy():
    def backward(self, dvalues, y_true):
        samples = len(dvalues)

        if len(y_true.shape) == 2:
            y_true = np.argmax(y_true, axis=1)

        self.dinputs = dvalues.copy()
        self.dinputs[range(samples), y_true] -= 1
        self.dinputs = self.dinputs / samples # normalize the gradient

class Accuracy:
    def calculate(self, predictions, y):
        comparisons = self.compare(predictions, y)
        accuracy = np.mean(comparisons)
        self.accumulated_sum += np.sum(comparisons)
        self.accumulated_count += len(comparisons)
        return accuracy

    def calculate_accumulated(self):
        accuracy = self.accumulated_sum / self.accumulated_count
        return accuracy
    def new_pass(self):
        self.accumulated_sum = 0
        self.accumulated_count = 0

class Accuracy_Categorical(Accuracy):

    def __init__(self, *, binary=False):
        self.binary = binary

    def init(self, y):
        pass

    def compare(self, predictions, y):
        if not self.binary and len(y.shape) == 2:
            y = np.argmax(y, axis=1)
        return predictions == y

class Layer_Input:
    def forward(self, inputs, training):
        self.output = inputs

# Model class
class Model:
    def __init__(self):
        self.layers = []
        self.softmax_classifier_output = None
        self.validation_accuracies = []
        self.training_accuracies = []
        self.loss_accuracies = []

    # Add objects to the model
    def add(self, layer):
        self.layers.append(layer)

    # Set loss, optimizer and accuracy
    def set(self, *, loss=None, optimizer=None, accuracy=None):
        if loss is not None:
            self.loss = loss
        if optimizer is not None:
            self.optimizer = optimizer
        if accuracy is not None:
            self.accuracy = accuracy

    # Finalize the model
    def finalize(self):
        self.input_layer = Layer_Input()
        layer_count = len(self.layers)
        self.trainable_layers = []

        for i in range(layer_count):
            if i == 0:
                self.layers[i].prev = self.input_layer
                self.layers[i].next = self.layers[i+1]
            elif i < layer_count - 1:
                self.layers[i].prev = self.layers[i-1]
                self.layers[i].next = self.layers[i+1]
            else:
                self.layers[i].prev = self.layers[i-1]
                self.layers[i].next = self.loss
                self.output_layer_activation = self.layers[i]
            if hasattr(self.layers[i], 'weights'):
                self.trainable_layers.append(self.layers[i])

        if self.loss is not None:
            self.loss.remember_trainable_layers(self.trainable_layers)

        if isinstance(self.layers[-1], Activation_Softmax) and isinstance(self.loss, Loss_CategoricalCrossentropy):
            self.softmax_classifier_output = Activation_Softmax_Loss_CategoricalCrossentropy()

    def train(self, X, y, *, epochs=1, batch_size=None, print_every=1, validation_data=None):
        self.accuracy.init(y)
        train_steps = 1
        if batch_size is not None:
            train_steps = len(X) // batch_size
            if train_steps * batch_size < len(X):
                train_steps += 1

        for epoch in range(1, epochs+1):
            print(f'epoch: {epoch}')

            self.loss.new_pass()
            self.accuracy.new_pass()

            for step in range(train_steps):
                if batch_size is None:
                    batch_X = X
                    batch_y = y
                else:
                    batch_X = X[step*batch_size:(step+1)*batch_size]
                    batch_y = y[step*batch_size:(step+1)*batch_size]

                output = self.forward(batch_X, training=True)

                data_loss, regularization_loss = self.loss.calculate(output, batch_y, include_regularization=True)
                loss = data_loss + regularization_loss
                predictions = self.output_layer_activation.predictions(output)
                accuracy = self.accuracy.calculate(predictions, batch_y)
                self.backward(output, batch_y)
                self.optimizer.pre_update_params()
                for layer in self.trainable_layers:
                    self.optimizer.update_params(layer)
                self.optimizer.post_update_params()
                
                if not step % print_every or step == train_steps - 1:
                    print(f'step: {step}, ' + f'acc: {accuracy:.3f}, ' +  f'loss: {loss:.3f} (' + f'data_loss: {data_loss:.3f}, ' + f'reg_loss: {regularization_loss:.3f}), ' + f'lr: {self.optimizer.current_learning_rate}')

            epoch_data_loss, epoch_regularization_loss = self.loss.calculate_accumulated(include_regularization=True)
            epoch_loss = epoch_data_loss + epoch_regularization_loss
            epoch_accuracy = self.accuracy.calculate_accumulated()
            self.training_accuracies.append(accuracy)
            print(f'training, ' + f'acc: {epoch_accuracy:.3f}, ' + f'loss: {epoch_loss:.3f} (' + f'data_loss: {epoch_data_loss:.3f}, ' + f'reg_loss: {epoch_regularization_loss:.3f}), ' + f'lr: {self.optimizer.current_learning_rate}')

            if validation_data is not None:
                self.evaluate(*validation_data, batch_size=batch_size)

    def evaluate(self, X_val, y_val, *, batch_size=None):
        validation_steps = 1

        if batch_size is not None:
            validation_steps = len(X_val) // batch_size
            if validation_steps * batch_size < len(X_val):
                validation_steps += 1
        self.loss.new_pass()
        self.accuracy.new_pass()

        for step in range(validation_steps):
            if batch_size is None:
                batch_X = X_val
                batch_y = y_val
            else:
                batch_X = X_val[step*batch_size:(step+1)*batch_size]
                batch_y = y_val[step*batch_size:(step+1)*batch_size]
            output = self.forward(batch_X, training=False)
            self.loss.calculate(output, batch_y)
            predictions = self.output_layer_activation.predictions(output)
            self.accuracy.calculate(predictions, batch_y)
        validation_loss = self.loss.calculate_accumulated()
        validation_accuracy = self.accuracy.calculate_accumulated()
        self.validation_accuracies.append(validation_accuracy)
        print(f'validation, ' + f'acc: {validation_accuracy:.3f}, ' + f'loss: {validation_loss:.3f}')
        
    def predict(self, X, *, batch_size=None):
        prediction_steps = 1
        if batch_size is not None:
            prediction_steps = len(X) // batch_size
            if prediction_steps * batch_size < len(X):
                prediction_steps += 1
        output = []
        for step in range(prediction_steps):
            if batch_size is None:
                batch_X = X
            else:
                batch_X = X[step*batch_size:(step+1)*batch_size]
            batch_output = self.forward(batch_X, training=False)
            output.append(batch_output)
        return np.vstack(output)
    def forward(self, X, training):
        self.input_layer.forward(X, training)
        for layer in self.layers:
            layer.forward(layer.prev.output, training)
        return layer.output

    def backward(self, output, y):
        if self.softmax_classifier_output is not None:
            self.softmax_classifier_output.backward(output, y)
            self.layers[-1].dinputs = self.softmax_classifier_output.dinputs
            for layer in reversed(self.layers[:-1]):
                layer.backward(layer.next.dinputs)
            return

        self.loss.backward(output, y)
        for layer in reversed(self.layers):
            layer.backward(layer.next.dinputs)

    def get_parameters(self):
        parameters = []
        for layer in self.trainable_layers:
            parameters.append(layer.get_parameters())
        return parameters

    def set_parameters(self, parameters):
        for parameter_set, layer in zip(parameters, self.trainable_layers): layer.set_parameters(*parameter_set)

# Code learned from textbook: Harrison Kinsley & Daniel Kukieła Neural Networks from Scratch (NNFS) https://nnfs.io

# %% [markdown]
# # **SECTION 3: Experiments**

# %% [markdown]
# ## **Part 0 - Choosing MLP hyperparameters.**

# %% [markdown]
# ### CNN

# %%
# Normalizing and reshaping the data
# First, we normalize the image pixel values from [0, 255] to [-0.5, 0.5]. 
# Second, we reshape the images from (28, 28) to (28, 28, 1) to add the third dimension required by Keras

# Normalize the images
X_train_fashion_normalized_cnn = (X_train_fashion_original / 255) - 0.5
X_test_fashion_normalized_cnn = (X_test_fashion_original / 255) - 0.5

print(X_train_fashion_normalized_cnn.shape) # (60000, 28, 28)
print(X_test_fashion_normalized_cnn.shape)  # (10000, 28, 28)

# Reshape the images.
X_train_fashion_normalized_cnn = np.expand_dims(X_train_fashion_normalized_cnn, axis=3)
X_test_fashion_normalized_cnn = np.expand_dims(X_test_fashion_normalized_cnn, axis=3)

print(X_train_fashion_normalized_cnn.shape) # (60000, 28, 28, 1)
print(X_test_fashion_normalized_cnn.shape)  # (10000, 28, 28, 1)

y_train_fashion_cnn = keras.utils.np_utils.to_categorical(y_train_fashion_original)
y_test_fashion_cnn = keras.utils.np_utils.to_categorical(y_test_fashion_original)
print(y_train_fashion_cnn.shape) # (60000, 10)
print(y_test_fashion_cnn.shape)  # (10000, 10)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)
# (60000, 10)
# (10000, 10)

# %%
num_filters = 8
filter_size = 3
pool_size   = 2
num_classes = len(set(y_test_fashion_original))
input_shape = (X_train_fashion_normalized_cnn.shape[1:]) # (28, 28, 1)
batch_size  = 64
strides     = 1
padding     = 'valid' # valid: no padding, same: for zeros evenly right/left and up/down
                      # when padding="same" and strides=1, the output has the same size as the input
optimizer = keras.optimizers.SGD(lr=0.001)
cnn_model = Sequential()
cnn_model.add(Conv2D(filters = 4 * num_filters, # 8 filters 
                 kernel_size = filter_size,
                 strides     = strides,
                 input_shape = input_shape,
                 padding     = padding,
                 activation  = 'relu')) # Sequential model needs the input shape
# model.add(MaxPooling2D(pool_size=pool_size)) # Keras automatically infers the shapes of inputs of later layers
cnn_model.add(Conv2D(filters = 8 * num_filters, kernel_size = (filter_size, filter_size)))
# model.add(MaxPooling2D(pool_size=(pool_size, pool_size)))
cnn_model.add(Dropout(0.25)) # randomly sets input units to 0 with a frequency of rate at each step during training time, to avoid overfitting
cnn_model.add(Flatten()) # Flatten serves as a connection between the convolution and dense layers
cnn_model.add(Dense(128, activation='relu')) # fully connected layer
cnn_model.add(Dense(num_classes, activation='softmax')) # output layer

# Compile the model
cnn_model.compile(
  optimizer=optimizer,                              # Optimizer: SGD for gradient descent-based: https://keras.io/api/optimizers/
  loss='categorical_crossentropy',    # Loss function: Categorical for 10 classes: https://keras.io/api/losses/
  metrics=['accuracy'],               # accuracy metric, can choose from keras metrics: https://keras.io/api/metrics/
)

# Fitting the model
history = cnn_model.fit(
  X_train_fashion_normalized_cnn,
  y_train_fashion_cnn, 
  epochs=5,                # number of training epochs
  batch_size=batch_size,
  verbose = 1,
  validation_data=(X_test_fashion_normalized_cnn, y_test_fashion_cnn), # validation data
)
# Out:
# Epoch 1/5
# 938/938 [==============================] - 181s 192ms/step - loss: 1.3201 - accuracy: 0.6064 - val_loss: 0.7254 - val_accuracy: 0.7306
# Epoch 2/5
# 938/938 [==============================] - 183s 195ms/step - loss: 0.6524 - accuracy: 0.7600 - val_loss: 0.6152 - val_accuracy: 0.7701
# Epoch 3/5
# 938/938 [==============================] - 180s 192ms/step - loss: 0.5833 - accuracy: 0.7860 - val_loss: 0.5700 - val_accuracy: 0.7923
# Epoch 4/5
# 938/938 [==============================] - 183s 195ms/step - loss: 0.5458 - accuracy: 0.8023 - val_loss: 0.5419 - val_accuracy: 0.8030
# Epoch 5/5
# 938/938 [==============================] - 183s 195ms/step - loss: 0.5219 - accuracy: 0.8090 - val_loss: 0.5288 - val_accuracy: 0.8066

# %% [markdown]
# ### MLP Implementation 1

# %% [markdown]
# ### Small Pertubation Analysis

# %%
layer = mlp.layers[4]
upper_layer = mlp.layers[5]

w = layer.w
b = layer.b
print(w.shape) # (10, 128)
print(b.shape) # (10,)

dw, db = layer.gradient
dw_num = dw.mean(axis=0)
db_num = db.mean(axis=0)
print(dw_num.shape) # (10, 128)
print(db_num.shape) # (10,)

w0 = w
epsilon = 1e-3 #np.random.randn(1)[0] * 1e-5
w1 = w0 + epsilon
w2 = w0 - epsilon
# print(w0, w1, w2)

x = layer.cur_input
a1 = (w1[None, :, :] @ x[:, :, None]).squeeze() + b
a2 = (w2[None, :, :] @ x[:, :, None]).squeeze() + b
print(x.shape)
print(a1.shape)

yh1 = upper_layer.forward(a1)
yh2 = upper_layer.forward(a2)
print(yh1.shape)

y = np.eye(10)[np.array(y_test)]
print(y.shape)

L1 = -(y * np.log(yh1+1e-300)).sum(axis=-1).mean()
L2 = -(y * np.log(yh2+1e-300)).sum(axis=-1).mean()
print(L1, L2)

dw_num = (L1 - L2)/(2*epsilon)
print(dw_num)

# %%
# Number of features & classes
n_features = 784
n_classes = 10

# Number of neurons
K1 = 128    # Layer 1
K2 = 128    # Layer 2

# Hyper-parameters
epochs = 500
batch_size = 256

lr_choices = [0.001, 0.01, 0.05, 0.1, 0.5, 1]
accuracies = []

for lr in lr_choices:
    mlp = MLP(
        # First Layer
        LinearLayer(n_features, K1),
        ReLULayer(),
        # Second Layer
        LinearLayer(K1, K2),
        ReLULayer(),
        # Output Layer
        LinearLayer(K2, n_classes),
        SoftmaxOutputLayer()
    )
    opt = GradientDescentOptimizer(mlp, lr)

    mlp.fit(opt, X_train_fashion_normalized, y_train_fashion, epochs, batch_size, showplot=False)

    # Performance on Train dataset
    yh_train = mlp.predict(X_train_fashion_normalized)
    acc_train = evaluate_acc(y_train_fashion, yh_train)

    # Performance on Test dataset
    yh_test = mlp.predict(X_test_fashion_normalized)
    acc_test = evaluate_acc(y_test_fashion, yh_test)

    accuracies.append((acc_train, acc_test))

print(lr_choices)
print(accuracies)
# Out:
# 100%|██████████| 500/500 [02:10<00:00,  3.82it/s]
# 100%|██████████| 500/500 [02:12<00:00,  3.78it/s]
# 100%|██████████| 500/500 [02:02<00:00,  4.08it/s]
# 100%|██████████| 500/500 [02:13<00:00,  3.74it/s]
# 100%|██████████| 500/500 [02:12<00:00,  3.77it/s]
# 100%|██████████| 500/500 [01:52<00:00,  4.46it/s]
# [0.001, 0.01, 0.05, 0.1, 0.5, 1]
# [(0.69145, 0.6843), (0.6509833333333334, 0.6463), (0.41178333333333333, 0.4072), (0.12461666666666667, 0.1254), (0.1, 0.1), (0.09998333333333333, 0.1)]

# %% [markdown]
# ### Learning Rate: MLP Implementation 2

# %%
learning_rate_choices = [0.001, 0.01, 0.05, 0.1, 0.2, 0.5, 1]
# Instantiate the model
model_test_params = Model()
# Add layers
model_test_params.add(Layer_Dense(X_train_fashion_normalized.shape[1], 128))
model_test_params.add(Activation_ReLU())
model_test_params.add(Layer_Dense(128, 128))
model_test_params.add(Activation_ReLU())
model_test_params.add(Layer_Dense(128, 10))
model_test_params.add(Activation_Softmax())

# Set loss, optimizer and accuracy objects
model_test_params.set(
loss=Loss_CategoricalCrossentropy(),
optimizer=Optimizer_SGD(learning_rate=1), # Plug the different values to observe accuracy results
accuracy=Accuracy_Categorical()
)

# Finalize the model
model_test_params.finalize()
# Train the model
model_test_params.train(X_train_fashion_normalized, y_train_fashion, validation_data=(X_test_fashion_normalized, y_test_fashion),
epochs=20, batch_size=128, print_every=100)
model_test_params.evaluate(X_test_fashion_normalized, y_test_fashion)
# Out:
# epoch: 1
# step: 0, acc: 0.109, loss: 2.303 (data_loss: 2.303, reg_loss: 0.000), lr: 1
# step: 100, acc: 0.172, loss: 1.984 (data_loss: 1.984, reg_loss: 0.000), lr: 1
# step: 200, acc: 0.375, loss: 1.452 (data_loss: 1.452, reg_loss: 0.000), lr: 1
# step: 300, acc: 0.461, loss: 1.185 (data_loss: 1.185, reg_loss: 0.000), lr: 1
# step: 400, acc: 0.406, loss: 1.619 (data_loss: 1.619, reg_loss: 0.000), lr: 1
# step: 468, acc: 0.260, loss: 1.832 (data_loss: 1.832, reg_loss: 0.000), lr: 1
# training, acc: 0.300, loss: 1.735 (data_loss: 1.735, reg_loss: 0.000), lr: 1
# validation, acc: 0.295, loss: 1.647
# epoch: 2
# step: 0, acc: 0.227, loss: 1.616 (data_loss: 1.616, reg_loss: 0.000), lr: 1
# step: 100, acc: 0.414, loss: 1.289 (data_loss: 1.289, reg_loss: 0.000), lr: 1
# step: 200, acc: 0.414, loss: 1.986 (data_loss: 1.986, reg_loss: 0.000), lr: 1
# step: 300, acc: 0.414, loss: 1.291 (data_loss: 1.291, reg_loss: 0.000), lr: 1
# step: 400, acc: 0.422, loss: 1.377 (data_loss: 1.377, reg_loss: 0.000), lr: 1
# step: 468, acc: 0.354, loss: 1.429 (data_loss: 1.429, reg_loss: 0.000), lr: 1
# training, acc: 0.396, loss: 1.457 (data_loss: 1.457, reg_loss: 0.000), lr: 1
# validation, acc: 0.462, loss: 1.233
# epoch: 3
# step: 0, acc: 0.414, loss: 1.244 (data_loss: 1.244, reg_loss: 0.000), lr: 1
# step: 100, acc: 0.312, loss: 1.522 (data_loss: 1.522, reg_loss: 0.000), lr: 1
# step: 200, acc: 0.375, loss: 1.463 (data_loss: 1.463, reg_loss: 0.000), lr: 1
# step: 300, acc: 0.234, loss: 1.620 (data_loss: 1.620, reg_loss: 0.000), lr: 1
# step: 400, acc: 0.234, loss: 1.557 (data_loss: 1.557, reg_loss: 0.000), lr: 1
# step: 468, acc: 0.312, loss: 1.643 (data_loss: 1.643, reg_loss: 0.000), lr: 1
# training, acc: 0.312, loss: 1.600 (data_loss: 1.600, reg_loss: 0.000), lr: 1
# validation, acc: 0.344, loss: 1.452
# epoch: 4
# step: 0, acc: 0.297, loss: 1.505 (data_loss: 1.505, reg_loss: 0.000), lr: 1
# step: 100, acc: 0.344, loss: 1.419 (data_loss: 1.419, reg_loss: 0.000), lr: 1
# step: 200, acc: 0.297, loss: 3.412 (data_loss: 3.412, reg_loss: 0.000), lr: 1
# step: 300, acc: 0.344, loss: 1.388 (data_loss: 1.388, reg_loss: 0.000), lr: 1
# step: 400, acc: 0.359, loss: 1.507 (data_loss: 1.507, reg_loss: 0.000), lr: 1
# step: 468, acc: 0.302, loss: 1.612 (data_loss: 1.612, reg_loss: 0.000), lr: 1
# training, acc: 0.346, loss: 1.505 (data_loss: 1.505, reg_loss: 0.000), lr: 1
# validation, acc: 0.393, loss: 1.396
# epoch: 5
# step: 0, acc: 0.375, loss: 1.380 (data_loss: 1.380, reg_loss: 0.000), lr: 1
# step: 100, acc: 0.352, loss: 1.410 (data_loss: 1.410, reg_loss: 0.000), lr: 1
# step: 200, acc: 0.320, loss: 1.499 (data_loss: 1.499, reg_loss: 0.000), lr: 1
# step: 300, acc: 0.398, loss: 1.256 (data_loss: 1.256, reg_loss: 0.000), lr: 1
# step: 400, acc: 0.406, loss: 2.232 (data_loss: 2.232, reg_loss: 0.000), lr: 1
# step: 468, acc: 0.312, loss: 1.694 (data_loss: 1.694, reg_loss: 0.000), lr: 1
# training, acc: 0.369, loss: 1.468 (data_loss: 1.468, reg_loss: 0.000), lr: 1
# validation, acc: 0.344, loss: 1.424
# epoch: 6
# step: 0, acc: 0.297, loss: 1.444 (data_loss: 1.444, reg_loss: 0.000), lr: 1
# step: 100, acc: 0.359, loss: 1.348 (data_loss: 1.348, reg_loss: 0.000), lr: 1
# step: 200, acc: 0.328, loss: 1.562 (data_loss: 1.562, reg_loss: 0.000), lr: 1
# step: 300, acc: 0.352, loss: 1.464 (data_loss: 1.464, reg_loss: 0.000), lr: 1
# step: 400, acc: 0.289, loss: 1.910 (data_loss: 1.910, reg_loss: 0.000), lr: 1
# step: 468, acc: 0.240, loss: 1.888 (data_loss: 1.888, reg_loss: 0.000), lr: 1
# training, acc: 0.342, loss: 1.529 (data_loss: 1.529, reg_loss: 0.000), lr: 1
# validation, acc: 0.360, loss: 1.528
# epoch: 7
# step: 0, acc: 0.328, loss: 1.562 (data_loss: 1.562, reg_loss: 0.000), lr: 1
# step: 100, acc: 0.289, loss: 1.762 (data_loss: 1.762, reg_loss: 0.000), lr: 1
# step: 200, acc: 0.227, loss: 1.675 (data_loss: 1.675, reg_loss: 0.000), lr: 1
# step: 300, acc: 0.336, loss: 1.419 (data_loss: 1.419, reg_loss: 0.000), lr: 1
# step: 400, acc: 0.258, loss: 1.579 (data_loss: 1.579, reg_loss: 0.000), lr: 1
# step: 468, acc: 0.198, loss: 1.840 (data_loss: 1.840, reg_loss: 0.000), lr: 1
# training, acc: 0.280, loss: 1.693 (data_loss: 1.693, reg_loss: 0.000), lr: 1
# validation, acc: 0.299, loss: 1.641
# epoch: 8
# step: 0, acc: 0.289, loss: 1.641 (data_loss: 1.641, reg_loss: 0.000), lr: 1
# step: 100, acc: 0.289, loss: 1.558 (data_loss: 1.558, reg_loss: 0.000), lr: 1
# step: 200, acc: 0.297, loss: 1.519 (data_loss: 1.519, reg_loss: 0.000), lr: 1
# step: 300, acc: 0.391, loss: 1.392 (data_loss: 1.392, reg_loss: 0.000), lr: 1
# step: 400, acc: 0.125, loss: 1.749 (data_loss: 1.749, reg_loss: 0.000), lr: 1
# step: 468, acc: 0.167, loss: 1.734 (data_loss: 1.734, reg_loss: 0.000), lr: 1
# training, acc: 0.281, loss: 1.625 (data_loss: 1.625, reg_loss: 0.000), lr: 1
# validation, acc: 0.212, loss: 1.720
# epoch: 9
# step: 0, acc: 0.180, loss: 1.706 (data_loss: 1.706, reg_loss: 0.000), lr: 1
# step: 100, acc: 0.156, loss: 1.668 (data_loss: 1.668, reg_loss: 0.000), lr: 1
# step: 200, acc: 0.383, loss: 1.400 (data_loss: 1.400, reg_loss: 0.000), lr: 1
# step: 300, acc: 0.336, loss: 1.448 (data_loss: 1.448, reg_loss: 0.000), lr: 1
# step: 400, acc: 0.328, loss: 1.541 (data_loss: 1.541, reg_loss: 0.000), lr: 1
# step: 468, acc: 0.188, loss: 1.741 (data_loss: 1.741, reg_loss: 0.000), lr: 1
# training, acc: 0.285, loss: 1.599 (data_loss: 1.599, reg_loss: 0.000), lr: 1
# validation, acc: 0.252, loss: 1.644
# epoch: 10
# step: 0, acc: 0.195, loss: 1.654 (data_loss: 1.654, reg_loss: 0.000), lr: 1
# step: 100, acc: 0.297, loss: 1.560 (data_loss: 1.560, reg_loss: 0.000), lr: 1
# step: 200, acc: 0.273, loss: 1.633 (data_loss: 1.633, reg_loss: 0.000), lr: 1
# step: 300, acc: 0.188, loss: 1.824 (data_loss: 1.824, reg_loss: 0.000), lr: 1
# step: 400, acc: 0.188, loss: 1.734 (data_loss: 1.734, reg_loss: 0.000), lr: 1
# step: 468, acc: 0.167, loss: 1.758 (data_loss: 1.758, reg_loss: 0.000), lr: 1
# training, acc: 0.263, loss: 1.659 (data_loss: 1.659, reg_loss: 0.000), lr: 1
# validation, acc: 0.202, loss: 1.702
# epoch: 11
# step: 0, acc: 0.164, loss: 1.743 (data_loss: 1.743, reg_loss: 0.000), lr: 1
# step: 100, acc: 0.148, loss: 1.732 (data_loss: 1.732, reg_loss: 0.000), lr: 1
# step: 200, acc: 0.188, loss: 1.677 (data_loss: 1.677, reg_loss: 0.000), lr: 1
# step: 300, acc: 0.164, loss: 1.659 (data_loss: 1.659, reg_loss: 0.000), lr: 1
# step: 400, acc: 0.312, loss: 1.569 (data_loss: 1.569, reg_loss: 0.000), lr: 1
# step: 468, acc: 0.219, loss: 1.717 (data_loss: 1.717, reg_loss: 0.000), lr: 1
# training, acc: 0.228, loss: 1.669 (data_loss: 1.669, reg_loss: 0.000), lr: 1
# validation, acc: 0.326, loss: 1.508
# epoch: 12
# step: 0, acc: 0.305, loss: 1.574 (data_loss: 1.574, reg_loss: 0.000), lr: 1
# step: 100, acc: 0.250, loss: 1.571 (data_loss: 1.571, reg_loss: 0.000), lr: 1
# step: 200, acc: 0.328, loss: 1.442 (data_loss: 1.442, reg_loss: 0.000), lr: 1
# step: 300, acc: 0.219, loss: 1.681 (data_loss: 1.681, reg_loss: 0.000), lr: 1
# step: 400, acc: 0.242, loss: 1.717 (data_loss: 1.717, reg_loss: 0.000), lr: 1
# step: 468, acc: 0.167, loss: 1.737 (data_loss: 1.737, reg_loss: 0.000), lr: 1
# training, acc: 0.245, loss: 1.675 (data_loss: 1.675, reg_loss: 0.000), lr: 1
# validation, acc: 0.193, loss: 1.743
# epoch: 13
# step: 0, acc: 0.133, loss: 1.711 (data_loss: 1.711, reg_loss: 0.000), lr: 1
# step: 100, acc: 0.148, loss: 1.686 (data_loss: 1.686, reg_loss: 0.000), lr: 1
# step: 200, acc: 0.227, loss: 1.674 (data_loss: 1.674, reg_loss: 0.000), lr: 1
# step: 300, acc: 0.164, loss: 1.709 (data_loss: 1.709, reg_loss: 0.000), lr: 1
# step: 400, acc: 0.180, loss: 1.719 (data_loss: 1.719, reg_loss: 0.000), lr: 1
# step: 468, acc: 0.167, loss: 1.766 (data_loss: 1.766, reg_loss: 0.000), lr: 1
# training, acc: 0.201, loss: 1.712 (data_loss: 1.712, reg_loss: 0.000), lr: 1
# validation, acc: 0.189, loss: 1.697
# epoch: 14
# step: 0, acc: 0.125, loss: 1.715 (data_loss: 1.715, reg_loss: 0.000), lr: 1
# step: 100, acc: 0.180, loss: 1.727 (data_loss: 1.727, reg_loss: 0.000), lr: 1
# step: 200, acc: 0.227, loss: 1.670 (data_loss: 1.670, reg_loss: 0.000), lr: 1
# step: 300, acc: 0.141, loss: 1.709 (data_loss: 1.709, reg_loss: 0.000), lr: 1
# step: 400, acc: 0.242, loss: 1.723 (data_loss: 1.723, reg_loss: 0.000), lr: 1
# step: 468, acc: 0.167, loss: 1.727 (data_loss: 1.727, reg_loss: 0.000), lr: 1
# training, acc: 0.200, loss: 1.703 (data_loss: 1.703, reg_loss: 0.000), lr: 1
# validation, acc: 0.191, loss: 1.693
# epoch: 15
# step: 0, acc: 0.133, loss: 1.693 (data_loss: 1.693, reg_loss: 0.000), lr: 1
# step: 100, acc: 0.148, loss: 1.678 (data_loss: 1.678, reg_loss: 0.000), lr: 1
# step: 200, acc: 0.227, loss: 1.637 (data_loss: 1.637, reg_loss: 0.000), lr: 1
# step: 300, acc: 0.219, loss: 1.664 (data_loss: 1.664, reg_loss: 0.000), lr: 1
# step: 400, acc: 0.219, loss: 1.699 (data_loss: 1.699, reg_loss: 0.000), lr: 1
# step: 468, acc: 0.167, loss: 1.756 (data_loss: 1.756, reg_loss: 0.000), lr: 1
# training, acc: 0.201, loss: 1.700 (data_loss: 1.700, reg_loss: 0.000), lr: 1
# validation, acc: 0.200, loss: 1.700
# epoch: 16
# step: 0, acc: 0.188, loss: 1.705 (data_loss: 1.705, reg_loss: 0.000), lr: 1
# step: 100, acc: 0.180, loss: 1.700 (data_loss: 1.700, reg_loss: 0.000), lr: 1
# step: 200, acc: 0.227, loss: 1.629 (data_loss: 1.629, reg_loss: 0.000), lr: 1
# step: 300, acc: 0.164, loss: 1.664 (data_loss: 1.664, reg_loss: 0.000), lr: 1
# step: 400, acc: 0.180, loss: 1.714 (data_loss: 1.714, reg_loss: 0.000), lr: 1
# step: 468, acc: 0.167, loss: 1.724 (data_loss: 1.724, reg_loss: 0.000), lr: 1
# training, acc: 0.200, loss: 1.697 (data_loss: 1.697, reg_loss: 0.000), lr: 1
# validation, acc: 0.191, loss: 1.694
# epoch: 17
# step: 0, acc: 0.133, loss: 1.692 (data_loss: 1.692, reg_loss: 0.000), lr: 1
# step: 100, acc: 0.148, loss: 1.672 (data_loss: 1.672, reg_loss: 0.000), lr: 1
# step: 200, acc: 0.227, loss: 1.661 (data_loss: 1.661, reg_loss: 0.000), lr: 1
# step: 300, acc: 0.305, loss: 1.644 (data_loss: 1.644, reg_loss: 0.000), lr: 1
# step: 400, acc: 0.250, loss: 1.660 (data_loss: 1.660, reg_loss: 0.000), lr: 1
# step: 468, acc: 0.167, loss: 1.752 (data_loss: 1.752, reg_loss: 0.000), lr: 1
# training, acc: 0.204, loss: 1.692 (data_loss: 1.692, reg_loss: 0.000), lr: 1
# validation, acc: 0.200, loss: 1.692
# epoch: 18
# step: 0, acc: 0.188, loss: 1.685 (data_loss: 1.685, reg_loss: 0.000), lr: 1
# step: 100, acc: 0.258, loss: 1.535 (data_loss: 1.535, reg_loss: 0.000), lr: 1
# step: 200, acc: 0.227, loss: 1.639 (data_loss: 1.639, reg_loss: 0.000), lr: 1
# step: 300, acc: 0.164, loss: 1.824 (data_loss: 1.824, reg_loss: 0.000), lr: 1
# step: 400, acc: 0.250, loss: 1.657 (data_loss: 1.657, reg_loss: 0.000), lr: 1
# step: 468, acc: 0.167, loss: 1.799 (data_loss: 1.799, reg_loss: 0.000), lr: 1
# training, acc: 0.210, loss: 1.696 (data_loss: 1.696, reg_loss: 0.000), lr: 1
# validation, acc: 0.199, loss: 1.730
# epoch: 19
# step: 0, acc: 0.188, loss: 1.703 (data_loss: 1.703, reg_loss: 0.000), lr: 1
# step: 100, acc: 0.156, loss: 1.711 (data_loss: 1.711, reg_loss: 0.000), lr: 1
# step: 200, acc: 0.227, loss: 1.685 (data_loss: 1.685, reg_loss: 0.000), lr: 1
# step: 300, acc: 0.219, loss: 1.654 (data_loss: 1.654, reg_loss: 0.000), lr: 1
# step: 400, acc: 0.242, loss: 1.694 (data_loss: 1.694, reg_loss: 0.000), lr: 1
# step: 468, acc: 0.167, loss: 1.753 (data_loss: 1.753, reg_loss: 0.000), lr: 1
# training, acc: 0.201, loss: 1.700 (data_loss: 1.700, reg_loss: 0.000), lr: 1
# validation, acc: 0.192, loss: 1.696
# epoch: 20
# step: 0, acc: 0.141, loss: 1.702 (data_loss: 1.702, reg_loss: 0.000), lr: 1
# step: 100, acc: 0.180, loss: 1.672 (data_loss: 1.672, reg_loss: 0.000), lr: 1
# step: 200, acc: 0.227, loss: 1.662 (data_loss: 1.662, reg_loss: 0.000), lr: 1
# step: 300, acc: 0.156, loss: 1.673 (data_loss: 1.673, reg_loss: 0.000), lr: 1
# step: 400, acc: 0.227, loss: 1.659 (data_loss: 1.659, reg_loss: 0.000), lr: 1
# step: 468, acc: 0.167, loss: 1.754 (data_loss: 1.754, reg_loss: 0.000), lr: 1
# training, acc: 0.201, loss: 1.694 (data_loss: 1.694, reg_loss: 0.000), lr: 1
# validation, acc: 0.200, loss: 1.700
# validation, acc: 0.200, loss: 1.700

# %% [markdown]
# ## **Main Implementation 1: Part 1 - MLP variants and softmax classification.**

# %% [markdown]
# ### MLP with no hidden layer

# %%
# Hyper-parameters
epochs = 5000
batch_size = 256
lr = 1e-2

mlp0 = MLP(
    # Output Layer
    LinearLayer(n_features, n_classes),
    SoftmaxOutputLayer()
)
opt0 = GradientDescentOptimizer(mlp0, lr)

mlp0.fit(opt0, X_train_fashion_std, y_train_fashion, epochs, batch_size, showplot=True)
# Out:
# 100%|██████████| 5000/5000 [01:32<00:00, 53.90it/s]

# %%
# Performance on Train dataset
yh_train = mlp0.predict(X_train_fashion_std)
print("Train accuracy:", evaluate_acc(y_train_fashion, yh_train))

# Performance on Test dataset
yh_test = mlp0.predict(X_test_fashion_std)
print("Train accuracy:", evaluate_acc(y_test_fashion, yh_test))
# Out:
# Train accuracy: 0.7420333333333333
# Train accuracy: 0.7364

# %% [markdown]
# ### MLP with 1 hidden layer and ReLU activations

# %%
# Number of neurons
K1 = 128    # Layer 1

# Hyper-parameters
epochs = 2500
batch_size = 256
lr = 1e-2

mlp1 = MLP(
    # First Layer
    LinearLayer(n_features, K1),
    ReLULayer(),
    # Output Layer
    LinearLayer(K1, n_classes),
    SoftmaxOutputLayer()
)
opt1 = GradientDescentOptimizer(mlp1, lr)

mlp1.fit(opt1, X_train_fashion_std, y_train_fashion, epochs, batch_size, showplot=True)
# Out:
# 100%|██████████| 2500/2500 [08:16<00:00,  5.04it/s]

# %%
# Performance on Train dataset
yh_train = mlp1.predict(X_train_fashion_std)
print("Train accuracy:", evaluate_acc(y_train_fashion, yh_train))

# Performance on Test dataset
yh_test = mlp1.predict(X_test_fashion_std)
print("Train accuracy:", evaluate_acc(y_test_fashion, yh_test))
# Out:
# Train accuracy: 0.8099333333333333
# Train accuracy: 0.7911

# %% [markdown]
# ### MLP with 2 hidden layers and ReLU activations

# %%
# Number of neurons
K1 = 128    # Layer 1
K2 = 128    # Layer 2

# Hyper-parameters
epochs = 1250
batch_size = 256
lr = 1e-2

mlp2 = MLP(
    # First Layer
    LinearLayer(n_features, K1),
    ReLULayer(),
    # Second Layer
    LinearLayer(K1, K2),
    ReLULayer(),
    # Output Layer
    LinearLayer(K2, n_classes),
    SoftmaxOutputLayer()
)
opt2 = GradientDescentOptimizer(mlp2, lr)

mlp2.fit(opt2, X_train_fashion_std, y_train_fashion, epochs, batch_size, showplot=True)
# Out:
# 100%|██████████| 1250/1250 [04:49<00:00,  4.32it/s]

# %%
# Performance on Train dataset
yh_train = mlp2.predict(X_train_fashion_std)
print("Train accuracy:", evaluate_acc(y_train_fashion, yh_train))

# Performance on Test dataset
yh_test = mlp2.predict(X_test_fashion_std)
print("Train accuracy:", evaluate_acc(y_test_fashion, yh_test))
# Out:
# Train accuracy: 0.74295
# Train accuracy: 0.7249

# %% [markdown]
# ## **Implementation 2: Part 1 - MLP variants and softmax classification.**

# %% [markdown]
# ### MLP with no hidden layer

# %%
# Instantiate the model
model = Model()
# Add layers
model.add(Layer_Dense(X_train_fashion_normalized.shape[1], 10))
model.add(Activation_Softmax())

# Set loss, optimizer and accuracy objects
model.set(
    loss=Loss_CategoricalCrossentropy(),
    optimizer=Optimizer_SGD(learning_rate=0.1),
    accuracy=Accuracy_Categorical()
)

# Finalize the model
model.finalize()
# Train the model
model.train(X_train_fashion_normalized, y_train_fashion, validation_data=(X_test_fashion_normalized, y_test_fashion),
epochs=20, batch_size=128, print_every=100)
model.evaluate(X_test_fashion_normalized, y_test_fashion)

plt.figure(figsize=(8, 8))
plt.title("MLP Implementation 2: Plot of Accuracies as Function of Epochs", fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.plot(model.validation_accuracies, 'g-',label='Test Accuracies')
plt.plot(model.training_accuracies, 'r-',label='Training Accuracies')
plt.legend()
# Out:
# epoch: 1
# step: 0, acc: 0.125, loss: 2.309 (data_loss: 2.309, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.805, loss: 0.676 (data_loss: 0.676, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.773, loss: 0.582 (data_loss: 0.582, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.828, loss: 0.580 (data_loss: 0.580, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.758, loss: 0.652 (data_loss: 0.652, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.844, loss: 0.488 (data_loss: 0.488, reg_loss: 0.000), lr: 0.1
# training, acc: 0.773, loss: 0.688 (data_loss: 0.688, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.811, loss: 0.565
# epoch: 2
# step: 0, acc: 0.867, loss: 0.429 (data_loss: 0.429, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.859, loss: 0.463 (data_loss: 0.463, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.820, loss: 0.466 (data_loss: 0.466, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.859, loss: 0.508 (data_loss: 0.508, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.797, loss: 0.595 (data_loss: 0.595, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.865, loss: 0.450 (data_loss: 0.450, reg_loss: 0.000), lr: 0.1
# training, acc: 0.826, loss: 0.520 (data_loss: 0.520, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.824, loss: 0.519
# epoch: 3
# step: 0, acc: 0.898, loss: 0.366 (data_loss: 0.366, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.859, loss: 0.421 (data_loss: 0.421, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.812, loss: 0.432 (data_loss: 0.432, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.867, loss: 0.480 (data_loss: 0.480, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.820, loss: 0.566 (data_loss: 0.566, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.865, loss: 0.431 (data_loss: 0.431, reg_loss: 0.000), lr: 0.1
# training, acc: 0.836, loss: 0.486 (data_loss: 0.486, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.829, loss: 0.498
# epoch: 4
# step: 0, acc: 0.914, loss: 0.335 (data_loss: 0.335, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.859, loss: 0.400 (data_loss: 0.400, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.828, loss: 0.414 (data_loss: 0.414, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.859, loss: 0.463 (data_loss: 0.463, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.820, loss: 0.546 (data_loss: 0.546, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.865, loss: 0.418 (data_loss: 0.418, reg_loss: 0.000), lr: 0.1
# training, acc: 0.842, loss: 0.468 (data_loss: 0.468, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.832, loss: 0.486
# epoch: 5
# step: 0, acc: 0.930, loss: 0.316 (data_loss: 0.316, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.867, loss: 0.388 (data_loss: 0.388, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.828, loss: 0.403 (data_loss: 0.403, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.867, loss: 0.451 (data_loss: 0.451, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.820, loss: 0.532 (data_loss: 0.532, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.865, loss: 0.409 (data_loss: 0.409, reg_loss: 0.000), lr: 0.1
# training, acc: 0.845, loss: 0.456 (data_loss: 0.456, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.835, loss: 0.477
# epoch: 6
# step: 0, acc: 0.922, loss: 0.303 (data_loss: 0.303, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.883, loss: 0.379 (data_loss: 0.379, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.828, loss: 0.395 (data_loss: 0.395, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.859, loss: 0.442 (data_loss: 0.442, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.836, loss: 0.521 (data_loss: 0.521, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.865, loss: 0.401 (data_loss: 0.401, reg_loss: 0.000), lr: 0.1
# training, acc: 0.848, loss: 0.447 (data_loss: 0.447, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.836, loss: 0.471
# epoch: 7
# step: 0, acc: 0.922, loss: 0.293 (data_loss: 0.293, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.883, loss: 0.374 (data_loss: 0.374, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.836, loss: 0.388 (data_loss: 0.388, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.867, loss: 0.435 (data_loss: 0.435, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.836, loss: 0.512 (data_loss: 0.512, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.865, loss: 0.394 (data_loss: 0.394, reg_loss: 0.000), lr: 0.1
# training, acc: 0.850, loss: 0.440 (data_loss: 0.440, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.836, loss: 0.467
# epoch: 8
# step: 0, acc: 0.930, loss: 0.286 (data_loss: 0.286, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.883, loss: 0.370 (data_loss: 0.370, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.844, loss: 0.384 (data_loss: 0.384, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.867, loss: 0.430 (data_loss: 0.430, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.844, loss: 0.504 (data_loss: 0.504, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.865, loss: 0.389 (data_loss: 0.389, reg_loss: 0.000), lr: 0.1
# training, acc: 0.851, loss: 0.435 (data_loss: 0.435, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.838, loss: 0.463
# epoch: 9
# step: 0, acc: 0.930, loss: 0.280 (data_loss: 0.280, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.883, loss: 0.366 (data_loss: 0.366, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.844, loss: 0.379 (data_loss: 0.379, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.867, loss: 0.425 (data_loss: 0.425, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.852, loss: 0.498 (data_loss: 0.498, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.865, loss: 0.384 (data_loss: 0.384, reg_loss: 0.000), lr: 0.1
# training, acc: 0.853, loss: 0.430 (data_loss: 0.430, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.839, loss: 0.460
# epoch: 10
# step: 0, acc: 0.930, loss: 0.276 (data_loss: 0.276, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.883, loss: 0.364 (data_loss: 0.364, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.836, loss: 0.376 (data_loss: 0.376, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.867, loss: 0.420 (data_loss: 0.420, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.859, loss: 0.492 (data_loss: 0.492, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.865, loss: 0.379 (data_loss: 0.379, reg_loss: 0.000), lr: 0.1
# training, acc: 0.854, loss: 0.427 (data_loss: 0.427, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.839, loss: 0.457
# epoch: 11
# step: 0, acc: 0.938, loss: 0.272 (data_loss: 0.272, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.883, loss: 0.362 (data_loss: 0.362, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.836, loss: 0.373 (data_loss: 0.373, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.867, loss: 0.417 (data_loss: 0.417, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.859, loss: 0.487 (data_loss: 0.487, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.865, loss: 0.376 (data_loss: 0.376, reg_loss: 0.000), lr: 0.1
# training, acc: 0.855, loss: 0.423 (data_loss: 0.423, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.840, loss: 0.455
# epoch: 12
# step: 0, acc: 0.938, loss: 0.269 (data_loss: 0.269, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.883, loss: 0.361 (data_loss: 0.361, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.836, loss: 0.371 (data_loss: 0.371, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.867, loss: 0.413 (data_loss: 0.413, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.859, loss: 0.483 (data_loss: 0.483, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.865, loss: 0.372 (data_loss: 0.372, reg_loss: 0.000), lr: 0.1
# training, acc: 0.856, loss: 0.420 (data_loss: 0.420, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.841, loss: 0.453
# epoch: 13
# step: 0, acc: 0.938, loss: 0.266 (data_loss: 0.266, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.883, loss: 0.359 (data_loss: 0.359, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.836, loss: 0.368 (data_loss: 0.368, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.867, loss: 0.411 (data_loss: 0.411, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.859, loss: 0.479 (data_loss: 0.479, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.865, loss: 0.369 (data_loss: 0.369, reg_loss: 0.000), lr: 0.1
# training, acc: 0.857, loss: 0.418 (data_loss: 0.418, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.842, loss: 0.452
# epoch: 14
# step: 0, acc: 0.938, loss: 0.264 (data_loss: 0.264, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.883, loss: 0.358 (data_loss: 0.358, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.852, loss: 0.367 (data_loss: 0.367, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.867, loss: 0.408 (data_loss: 0.408, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.859, loss: 0.475 (data_loss: 0.475, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.865, loss: 0.366 (data_loss: 0.366, reg_loss: 0.000), lr: 0.1
# training, acc: 0.857, loss: 0.416 (data_loss: 0.416, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.843, loss: 0.450
# epoch: 15
# step: 0, acc: 0.938, loss: 0.262 (data_loss: 0.262, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.883, loss: 0.357 (data_loss: 0.357, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.859, loss: 0.365 (data_loss: 0.365, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.867, loss: 0.406 (data_loss: 0.406, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.859, loss: 0.472 (data_loss: 0.472, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.865, loss: 0.364 (data_loss: 0.364, reg_loss: 0.000), lr: 0.1
# training, acc: 0.858, loss: 0.413 (data_loss: 0.413, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.843, loss: 0.449
# epoch: 16
# step: 0, acc: 0.938, loss: 0.260 (data_loss: 0.260, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.883, loss: 0.357 (data_loss: 0.357, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.859, loss: 0.363 (data_loss: 0.363, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.867, loss: 0.403 (data_loss: 0.403, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.859, loss: 0.468 (data_loss: 0.468, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.865, loss: 0.361 (data_loss: 0.361, reg_loss: 0.000), lr: 0.1
# training, acc: 0.859, loss: 0.412 (data_loss: 0.412, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.844, loss: 0.448
# epoch: 17
# step: 0, acc: 0.930, loss: 0.259 (data_loss: 0.259, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.883, loss: 0.356 (data_loss: 0.356, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.859, loss: 0.362 (data_loss: 0.362, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.867, loss: 0.401 (data_loss: 0.401, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.859, loss: 0.466 (data_loss: 0.466, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.865, loss: 0.359 (data_loss: 0.359, reg_loss: 0.000), lr: 0.1
# training, acc: 0.859, loss: 0.410 (data_loss: 0.410, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.843, loss: 0.447
# epoch: 18
# step: 0, acc: 0.930, loss: 0.257 (data_loss: 0.257, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.875, loss: 0.356 (data_loss: 0.356, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.859, loss: 0.360 (data_loss: 0.360, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.867, loss: 0.400 (data_loss: 0.400, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.859, loss: 0.463 (data_loss: 0.463, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.865, loss: 0.357 (data_loss: 0.357, reg_loss: 0.000), lr: 0.1
# training, acc: 0.860, loss: 0.408 (data_loss: 0.408, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.843, loss: 0.446
# epoch: 19
# step: 0, acc: 0.930, loss: 0.256 (data_loss: 0.256, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.875, loss: 0.355 (data_loss: 0.355, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.859, loss: 0.359 (data_loss: 0.359, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.867, loss: 0.398 (data_loss: 0.398, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.859, loss: 0.461 (data_loss: 0.461, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.865, loss: 0.356 (data_loss: 0.356, reg_loss: 0.000), lr: 0.1
# training, acc: 0.860, loss: 0.407 (data_loss: 0.407, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.843, loss: 0.445
# epoch: 20
# step: 0, acc: 0.930, loss: 0.255 (data_loss: 0.255, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.875, loss: 0.355 (data_loss: 0.355, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.859, loss: 0.358 (data_loss: 0.358, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.867, loss: 0.397 (data_loss: 0.397, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.867, loss: 0.458 (data_loss: 0.458, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.865, loss: 0.354 (data_loss: 0.354, reg_loss: 0.000), lr: 0.1
# training, acc: 0.861, loss: 0.405 (data_loss: 0.405, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.844, loss: 0.444
# validation, acc: 0.844, loss: 0.444

# %% [markdown]
# ### MLP with 1 hidden layer and ReLU activations

# %%
# Instantiate the model
model = Model()
# Add layers
model.add(Layer_Dense(X_train_fashion_normalized.shape[1], 128))
model.add(Activation_ReLU())
model.add(Layer_Dense(128, 10))
model.add(Activation_Softmax())

# Set loss, optimizer and accuracy objects
model.set(
loss=Loss_CategoricalCrossentropy(),
optimizer=Optimizer_SGD(learning_rate=0.1),
accuracy=Accuracy_Categorical()
)

# Finalize the model
model.finalize()
# Train the model
model.train(X_train_fashion_normalized, y_train_fashion, validation_data=(X_test_fashion_normalized, y_test_fashion),
epochs=20, batch_size=128, print_every=100)
model.evaluate(X_test_fashion_normalized, y_test_fashion)

plt.figure(figsize=(8, 8))
plt.title("MLP Implementation 2: Plot of Accuracies as Function of Epochs", fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.plot(model.validation_accuracies, 'g-',label='Test Accuracies')
plt.plot(model.training_accuracies, 'r-',label='Training Accuracies')
plt.legend()
# Out:
# epoch: 1
# step: 0, acc: 0.109, loss: 2.302 (data_loss: 2.302, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.656, loss: 0.862 (data_loss: 0.862, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.703, loss: 0.694 (data_loss: 0.694, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.789, loss: 0.617 (data_loss: 0.617, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.719, loss: 0.678 (data_loss: 0.678, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.833, loss: 0.497 (data_loss: 0.497, reg_loss: 0.000), lr: 0.1
# training, acc: 0.693, loss: 0.864 (data_loss: 0.864, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.799, loss: 0.574
# epoch: 2
# step: 0, acc: 0.852, loss: 0.452 (data_loss: 0.452, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.797, loss: 0.536 (data_loss: 0.536, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.781, loss: 0.464 (data_loss: 0.464, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.844, loss: 0.479 (data_loss: 0.479, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.758, loss: 0.596 (data_loss: 0.596, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.865, loss: 0.424 (data_loss: 0.424, reg_loss: 0.000), lr: 0.1
# training, acc: 0.817, loss: 0.517 (data_loss: 0.517, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.826, loss: 0.496
# epoch: 3
# step: 0, acc: 0.898, loss: 0.349 (data_loss: 0.349, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.836, loss: 0.453 (data_loss: 0.453, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.820, loss: 0.404 (data_loss: 0.404, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.859, loss: 0.427 (data_loss: 0.427, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.797, loss: 0.531 (data_loss: 0.531, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.875, loss: 0.393 (data_loss: 0.393, reg_loss: 0.000), lr: 0.1
# training, acc: 0.839, loss: 0.458 (data_loss: 0.458, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.836, loss: 0.465
# epoch: 4
# step: 0, acc: 0.914, loss: 0.307 (data_loss: 0.307, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.852, loss: 0.403 (data_loss: 0.403, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.836, loss: 0.363 (data_loss: 0.363, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.859, loss: 0.391 (data_loss: 0.391, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.797, loss: 0.488 (data_loss: 0.488, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.875, loss: 0.375 (data_loss: 0.375, reg_loss: 0.000), lr: 0.1
# training, acc: 0.850, loss: 0.424 (data_loss: 0.424, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.842, loss: 0.442
# epoch: 5
# step: 0, acc: 0.906, loss: 0.277 (data_loss: 0.277, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.867, loss: 0.354 (data_loss: 0.354, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.859, loss: 0.333 (data_loss: 0.333, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.859, loss: 0.365 (data_loss: 0.365, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.820, loss: 0.456 (data_loss: 0.456, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.875, loss: 0.353 (data_loss: 0.353, reg_loss: 0.000), lr: 0.1
# training, acc: 0.858, loss: 0.401 (data_loss: 0.401, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.847, loss: 0.429
# epoch: 6
# step: 0, acc: 0.914, loss: 0.266 (data_loss: 0.266, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.875, loss: 0.328 (data_loss: 0.328, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.883, loss: 0.313 (data_loss: 0.313, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.867, loss: 0.347 (data_loss: 0.347, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.828, loss: 0.433 (data_loss: 0.433, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.875, loss: 0.327 (data_loss: 0.327, reg_loss: 0.000), lr: 0.1
# training, acc: 0.863, loss: 0.383 (data_loss: 0.383, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.851, loss: 0.416
# epoch: 7
# step: 0, acc: 0.914, loss: 0.252 (data_loss: 0.252, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.883, loss: 0.312 (data_loss: 0.312, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.891, loss: 0.302 (data_loss: 0.302, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.875, loss: 0.333 (data_loss: 0.333, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.836, loss: 0.416 (data_loss: 0.416, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.896, loss: 0.298 (data_loss: 0.298, reg_loss: 0.000), lr: 0.1
# training, acc: 0.868, loss: 0.368 (data_loss: 0.368, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.855, loss: 0.404
# epoch: 8
# step: 0, acc: 0.922, loss: 0.237 (data_loss: 0.237, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.883, loss: 0.294 (data_loss: 0.294, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.891, loss: 0.296 (data_loss: 0.296, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.883, loss: 0.318 (data_loss: 0.318, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.859, loss: 0.393 (data_loss: 0.393, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.896, loss: 0.281 (data_loss: 0.281, reg_loss: 0.000), lr: 0.1
# training, acc: 0.872, loss: 0.356 (data_loss: 0.356, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.859, loss: 0.395
# epoch: 9
# step: 0, acc: 0.922, loss: 0.225 (data_loss: 0.225, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.891, loss: 0.276 (data_loss: 0.276, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.891, loss: 0.290 (data_loss: 0.290, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.891, loss: 0.308 (data_loss: 0.308, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.883, loss: 0.375 (data_loss: 0.375, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.896, loss: 0.271 (data_loss: 0.271, reg_loss: 0.000), lr: 0.1
# training, acc: 0.876, loss: 0.346 (data_loss: 0.346, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.860, loss: 0.389
# epoch: 10
# step: 0, acc: 0.922, loss: 0.221 (data_loss: 0.221, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.898, loss: 0.261 (data_loss: 0.261, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.891, loss: 0.287 (data_loss: 0.287, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.898, loss: 0.302 (data_loss: 0.302, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.875, loss: 0.364 (data_loss: 0.364, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.906, loss: 0.263 (data_loss: 0.263, reg_loss: 0.000), lr: 0.1
# training, acc: 0.879, loss: 0.337 (data_loss: 0.337, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.862, loss: 0.383
# epoch: 11
# step: 0, acc: 0.914, loss: 0.214 (data_loss: 0.214, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.898, loss: 0.250 (data_loss: 0.250, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.898, loss: 0.284 (data_loss: 0.284, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.906, loss: 0.296 (data_loss: 0.296, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.875, loss: 0.353 (data_loss: 0.353, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.906, loss: 0.256 (data_loss: 0.256, reg_loss: 0.000), lr: 0.1
# training, acc: 0.881, loss: 0.329 (data_loss: 0.329, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.865, loss: 0.378
# epoch: 12
# step: 0, acc: 0.914, loss: 0.207 (data_loss: 0.207, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.898, loss: 0.241 (data_loss: 0.241, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.898, loss: 0.282 (data_loss: 0.282, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.906, loss: 0.297 (data_loss: 0.297, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.883, loss: 0.340 (data_loss: 0.340, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.906, loss: 0.248 (data_loss: 0.248, reg_loss: 0.000), lr: 0.1
# training, acc: 0.885, loss: 0.321 (data_loss: 0.321, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.868, loss: 0.373
# epoch: 13
# step: 0, acc: 0.914, loss: 0.201 (data_loss: 0.201, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.914, loss: 0.234 (data_loss: 0.234, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.906, loss: 0.279 (data_loss: 0.279, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.906, loss: 0.292 (data_loss: 0.292, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.883, loss: 0.336 (data_loss: 0.336, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.906, loss: 0.244 (data_loss: 0.244, reg_loss: 0.000), lr: 0.1
# training, acc: 0.887, loss: 0.314 (data_loss: 0.314, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.869, loss: 0.369
# epoch: 14
# step: 0, acc: 0.914, loss: 0.198 (data_loss: 0.198, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.906, loss: 0.231 (data_loss: 0.231, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.906, loss: 0.278 (data_loss: 0.278, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.906, loss: 0.283 (data_loss: 0.283, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.891, loss: 0.329 (data_loss: 0.329, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.906, loss: 0.244 (data_loss: 0.244, reg_loss: 0.000), lr: 0.1
# training, acc: 0.889, loss: 0.307 (data_loss: 0.307, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.870, loss: 0.366
# epoch: 15
# step: 0, acc: 0.922, loss: 0.191 (data_loss: 0.191, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.906, loss: 0.226 (data_loss: 0.226, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.906, loss: 0.276 (data_loss: 0.276, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.898, loss: 0.280 (data_loss: 0.280, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.906, loss: 0.319 (data_loss: 0.319, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.906, loss: 0.237 (data_loss: 0.237, reg_loss: 0.000), lr: 0.1
# training, acc: 0.891, loss: 0.301 (data_loss: 0.301, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.872, loss: 0.361
# epoch: 16
# step: 0, acc: 0.922, loss: 0.185 (data_loss: 0.185, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.914, loss: 0.217 (data_loss: 0.217, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.898, loss: 0.276 (data_loss: 0.276, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.898, loss: 0.274 (data_loss: 0.274, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.906, loss: 0.312 (data_loss: 0.312, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.906, loss: 0.229 (data_loss: 0.229, reg_loss: 0.000), lr: 0.1
# training, acc: 0.894, loss: 0.295 (data_loss: 0.295, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.872, loss: 0.358
# epoch: 17
# step: 0, acc: 0.922, loss: 0.182 (data_loss: 0.182, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.914, loss: 0.213 (data_loss: 0.213, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.898, loss: 0.273 (data_loss: 0.273, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.898, loss: 0.274 (data_loss: 0.274, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.898, loss: 0.306 (data_loss: 0.306, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.896, loss: 0.225 (data_loss: 0.225, reg_loss: 0.000), lr: 0.1
# training, acc: 0.895, loss: 0.290 (data_loss: 0.290, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.874, loss: 0.355
# epoch: 18
# step: 0, acc: 0.914, loss: 0.177 (data_loss: 0.177, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.914, loss: 0.211 (data_loss: 0.211, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.898, loss: 0.272 (data_loss: 0.272, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.898, loss: 0.269 (data_loss: 0.269, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.914, loss: 0.303 (data_loss: 0.303, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.896, loss: 0.221 (data_loss: 0.221, reg_loss: 0.000), lr: 0.1
# training, acc: 0.897, loss: 0.285 (data_loss: 0.285, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.874, loss: 0.352
# epoch: 19
# step: 0, acc: 0.930, loss: 0.175 (data_loss: 0.175, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.914, loss: 0.207 (data_loss: 0.207, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.898, loss: 0.268 (data_loss: 0.268, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.906, loss: 0.265 (data_loss: 0.265, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.914, loss: 0.299 (data_loss: 0.299, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.896, loss: 0.217 (data_loss: 0.217, reg_loss: 0.000), lr: 0.1
# training, acc: 0.898, loss: 0.280 (data_loss: 0.280, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.875, loss: 0.349
# epoch: 20
# step: 0, acc: 0.938, loss: 0.169 (data_loss: 0.169, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.914, loss: 0.204 (data_loss: 0.204, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.906, loss: 0.268 (data_loss: 0.268, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.906, loss: 0.257 (data_loss: 0.257, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.922, loss: 0.290 (data_loss: 0.290, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.906, loss: 0.215 (data_loss: 0.215, reg_loss: 0.000), lr: 0.1
# training, acc: 0.900, loss: 0.275 (data_loss: 0.275, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.876, loss: 0.347
# validation, acc: 0.876, loss: 0.347

# %% [markdown]
# ### MLP with 2 hidden layers and ReLU activations

# %%
# Instantiate the model
model = Model()
# Add layers
model.add(Layer_Dense(X_train_fashion_normalized.shape[1], 128))
model.add(Activation_ReLU())
model.add(Layer_Dense(128, 128))
model.add(Activation_ReLU())
model.add(Layer_Dense(128, 10))
model.add(Activation_Softmax())

# Set loss, optimizer and accuracy objects
model.set(
loss=Loss_CategoricalCrossentropy(),
optimizer=Optimizer_SGD(learning_rate=0.1),
accuracy=Accuracy_Categorical()
)

# Finalize the model
model.finalize()
# Train the model
model.train(X_train_fashion_normalized, y_train_fashion, validation_data=(X_test_fashion_normalized, y_test_fashion),
epochs=20, batch_size=128, print_every=100)
model.evaluate(X_test_fashion_normalized, y_test_fashion)

plt.figure(figsize=(8, 8))
plt.title("MLP Implementation 2: Plot of Accuracies as Function of Epochs", fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.plot(model.validation_accuracies, 'g-',label='Test Accuracies')
plt.plot(model.training_accuracies, 'r-',label='Training Accuracies')
plt.legend()
# Out:
# epoch: 1
# step: 0, acc: 0.125, loss: 2.303 (data_loss: 2.303, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.180, loss: 2.283 (data_loss: 2.283, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.391, loss: 1.334 (data_loss: 1.334, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.555, loss: 1.208 (data_loss: 1.208, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.641, loss: 0.908 (data_loss: 0.908, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.688, loss: 0.839 (data_loss: 0.839, reg_loss: 0.000), lr: 0.1
# training, acc: 0.429, loss: 1.494 (data_loss: 1.494, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.689, loss: 0.827
# epoch: 2
# step: 0, acc: 0.734, loss: 0.716 (data_loss: 0.716, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.758, loss: 0.664 (data_loss: 0.664, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.734, loss: 0.629 (data_loss: 0.629, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.773, loss: 0.603 (data_loss: 0.603, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.727, loss: 0.674 (data_loss: 0.674, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.781, loss: 0.552 (data_loss: 0.552, reg_loss: 0.000), lr: 0.1
# training, acc: 0.746, loss: 0.689 (data_loss: 0.689, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.794, loss: 0.594
# epoch: 3
# step: 0, acc: 0.875, loss: 0.444 (data_loss: 0.444, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.812, loss: 0.536 (data_loss: 0.536, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.758, loss: 0.511 (data_loss: 0.511, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.844, loss: 0.473 (data_loss: 0.473, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.727, loss: 0.625 (data_loss: 0.625, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.854, loss: 0.523 (data_loss: 0.523, reg_loss: 0.000), lr: 0.1
# training, acc: 0.804, loss: 0.549 (data_loss: 0.549, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.814, loss: 0.523
# epoch: 4
# step: 0, acc: 0.891, loss: 0.358 (data_loss: 0.358, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.852, loss: 0.453 (data_loss: 0.453, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.789, loss: 0.418 (data_loss: 0.418, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.859, loss: 0.407 (data_loss: 0.407, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.766, loss: 0.586 (data_loss: 0.586, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.865, loss: 0.501 (data_loss: 0.501, reg_loss: 0.000), lr: 0.1
# training, acc: 0.830, loss: 0.476 (data_loss: 0.476, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.827, loss: 0.491
# epoch: 5
# step: 0, acc: 0.898, loss: 0.330 (data_loss: 0.330, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.844, loss: 0.425 (data_loss: 0.425, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.859, loss: 0.358 (data_loss: 0.358, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.852, loss: 0.373 (data_loss: 0.373, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.789, loss: 0.515 (data_loss: 0.515, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.875, loss: 0.434 (data_loss: 0.434, reg_loss: 0.000), lr: 0.1
# training, acc: 0.845, loss: 0.432 (data_loss: 0.432, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.835, loss: 0.464
# epoch: 6
# step: 0, acc: 0.906, loss: 0.301 (data_loss: 0.301, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.859, loss: 0.395 (data_loss: 0.395, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.867, loss: 0.335 (data_loss: 0.335, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.875, loss: 0.354 (data_loss: 0.354, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.797, loss: 0.474 (data_loss: 0.474, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.885, loss: 0.384 (data_loss: 0.384, reg_loss: 0.000), lr: 0.1
# training, acc: 0.854, loss: 0.404 (data_loss: 0.404, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.844, loss: 0.442
# epoch: 7
# step: 0, acc: 0.891, loss: 0.274 (data_loss: 0.274, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.859, loss: 0.365 (data_loss: 0.365, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.867, loss: 0.316 (data_loss: 0.316, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.875, loss: 0.336 (data_loss: 0.336, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.812, loss: 0.454 (data_loss: 0.454, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.885, loss: 0.342 (data_loss: 0.342, reg_loss: 0.000), lr: 0.1
# training, acc: 0.861, loss: 0.382 (data_loss: 0.382, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.850, loss: 0.421
# epoch: 8
# step: 0, acc: 0.906, loss: 0.247 (data_loss: 0.247, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.859, loss: 0.350 (data_loss: 0.350, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.883, loss: 0.305 (data_loss: 0.305, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.891, loss: 0.327 (data_loss: 0.327, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.820, loss: 0.425 (data_loss: 0.425, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.896, loss: 0.330 (data_loss: 0.330, reg_loss: 0.000), lr: 0.1
# training, acc: 0.868, loss: 0.365 (data_loss: 0.365, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.853, loss: 0.408
# epoch: 9
# step: 0, acc: 0.906, loss: 0.233 (data_loss: 0.233, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.875, loss: 0.326 (data_loss: 0.326, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.891, loss: 0.294 (data_loss: 0.294, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.898, loss: 0.318 (data_loss: 0.318, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.836, loss: 0.391 (data_loss: 0.391, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.906, loss: 0.311 (data_loss: 0.311, reg_loss: 0.000), lr: 0.1
# training, acc: 0.872, loss: 0.350 (data_loss: 0.350, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.858, loss: 0.394
# epoch: 10
# step: 0, acc: 0.914, loss: 0.227 (data_loss: 0.227, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.891, loss: 0.301 (data_loss: 0.301, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.883, loss: 0.284 (data_loss: 0.284, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.898, loss: 0.312 (data_loss: 0.312, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.836, loss: 0.380 (data_loss: 0.380, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.896, loss: 0.296 (data_loss: 0.296, reg_loss: 0.000), lr: 0.1
# training, acc: 0.876, loss: 0.337 (data_loss: 0.337, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.861, loss: 0.387
# epoch: 11
# step: 0, acc: 0.922, loss: 0.215 (data_loss: 0.215, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.883, loss: 0.288 (data_loss: 0.288, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.883, loss: 0.282 (data_loss: 0.282, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.898, loss: 0.303 (data_loss: 0.303, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.836, loss: 0.354 (data_loss: 0.354, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.896, loss: 0.289 (data_loss: 0.289, reg_loss: 0.000), lr: 0.1
# training, acc: 0.880, loss: 0.326 (data_loss: 0.326, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.861, loss: 0.386
# epoch: 12
# step: 0, acc: 0.930, loss: 0.206 (data_loss: 0.206, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.898, loss: 0.285 (data_loss: 0.285, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.883, loss: 0.279 (data_loss: 0.279, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.898, loss: 0.294 (data_loss: 0.294, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.836, loss: 0.341 (data_loss: 0.341, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.885, loss: 0.285 (data_loss: 0.285, reg_loss: 0.000), lr: 0.1
# training, acc: 0.883, loss: 0.316 (data_loss: 0.316, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.861, loss: 0.382
# epoch: 13
# step: 0, acc: 0.938, loss: 0.201 (data_loss: 0.201, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.898, loss: 0.299 (data_loss: 0.299, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.891, loss: 0.272 (data_loss: 0.272, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.898, loss: 0.287 (data_loss: 0.287, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.867, loss: 0.323 (data_loss: 0.323, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.896, loss: 0.272 (data_loss: 0.272, reg_loss: 0.000), lr: 0.1
# training, acc: 0.886, loss: 0.307 (data_loss: 0.307, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.863, loss: 0.379
# epoch: 14
# step: 0, acc: 0.938, loss: 0.198 (data_loss: 0.198, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.906, loss: 0.276 (data_loss: 0.276, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.875, loss: 0.274 (data_loss: 0.274, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.906, loss: 0.280 (data_loss: 0.280, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.875, loss: 0.308 (data_loss: 0.308, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.885, loss: 0.274 (data_loss: 0.274, reg_loss: 0.000), lr: 0.1
# training, acc: 0.889, loss: 0.299 (data_loss: 0.299, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.864, loss: 0.373
# epoch: 15
# step: 0, acc: 0.930, loss: 0.187 (data_loss: 0.187, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.898, loss: 0.274 (data_loss: 0.274, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.883, loss: 0.274 (data_loss: 0.274, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.922, loss: 0.271 (data_loss: 0.271, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.891, loss: 0.305 (data_loss: 0.305, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.906, loss: 0.262 (data_loss: 0.262, reg_loss: 0.000), lr: 0.1
# training, acc: 0.892, loss: 0.291 (data_loss: 0.291, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.867, loss: 0.368
# epoch: 16
# step: 0, acc: 0.930, loss: 0.183 (data_loss: 0.183, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.891, loss: 0.292 (data_loss: 0.292, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.875, loss: 0.273 (data_loss: 0.273, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.922, loss: 0.269 (data_loss: 0.269, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.898, loss: 0.294 (data_loss: 0.294, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.896, loss: 0.263 (data_loss: 0.263, reg_loss: 0.000), lr: 0.1
# training, acc: 0.895, loss: 0.284 (data_loss: 0.284, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.868, loss: 0.371
# epoch: 17
# step: 0, acc: 0.930, loss: 0.175 (data_loss: 0.175, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.891, loss: 0.258 (data_loss: 0.258, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.875, loss: 0.281 (data_loss: 0.281, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.922, loss: 0.255 (data_loss: 0.255, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.906, loss: 0.292 (data_loss: 0.292, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.917, loss: 0.249 (data_loss: 0.249, reg_loss: 0.000), lr: 0.1
# training, acc: 0.897, loss: 0.278 (data_loss: 0.278, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.869, loss: 0.361
# epoch: 18
# step: 0, acc: 0.938, loss: 0.169 (data_loss: 0.169, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.906, loss: 0.259 (data_loss: 0.259, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.883, loss: 0.281 (data_loss: 0.281, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.914, loss: 0.255 (data_loss: 0.255, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.906, loss: 0.285 (data_loss: 0.285, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.896, loss: 0.247 (data_loss: 0.247, reg_loss: 0.000), lr: 0.1
# training, acc: 0.899, loss: 0.271 (data_loss: 0.271, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.873, loss: 0.356
# epoch: 19
# step: 0, acc: 0.930, loss: 0.170 (data_loss: 0.170, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.914, loss: 0.262 (data_loss: 0.262, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.883, loss: 0.285 (data_loss: 0.285, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.906, loss: 0.248 (data_loss: 0.248, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.906, loss: 0.271 (data_loss: 0.271, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.917, loss: 0.234 (data_loss: 0.234, reg_loss: 0.000), lr: 0.1
# training, acc: 0.902, loss: 0.265 (data_loss: 0.265, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.872, loss: 0.356
# epoch: 20
# step: 0, acc: 0.938, loss: 0.161 (data_loss: 0.161, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.906, loss: 0.262 (data_loss: 0.262, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.906, loss: 0.281 (data_loss: 0.281, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.906, loss: 0.244 (data_loss: 0.244, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.906, loss: 0.269 (data_loss: 0.269, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.906, loss: 0.228 (data_loss: 0.228, reg_loss: 0.000), lr: 0.1
# training, acc: 0.904, loss: 0.260 (data_loss: 0.260, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.877, loss: 0.346
# validation, acc: 0.877, loss: 0.346

# %% [markdown]
# ## **Main Implementation 1: Part 2: MLP with 2 hidden layers.**

# %% [markdown]
# ### Leaky ReLU activation function

# %%
class LeakyReLULayer(NeuralNetLayer):
    def __init__(self, alpha):
        super().__init__()
        self.alpha = alpha
        
    def forward(self, x):
        self.gradient = np.where(x > 0, 1.0, self.alpha) 
        return np.maximum(0, x) + self.alpha * np.minimum(0, x)

    def backward(self, gradient):
        assert self.gradient is not None, "Must call forward before backward"
        return gradient * self.gradient

# %%
# Hyper-parameters
epochs = 250
batch_size = 256
lr = 1e-2

alpha_choices = [0.001, 0.01, 0.05, 0.1, 0.5, 1]
accuracies = []

for alpha in alpha_choices:
    mlp_leaky = MLP(
        # First Layer
        LinearLayer(n_features, K1),
        LeakyReLULayer(alpha),
        # Second Layer
        LinearLayer(K1, K2),
        LeakyReLULayer(alpha),
        # Output Layer
        LinearLayer(K2, n_classes),
        SoftmaxOutputLayer()
    )
    opt_leaky = GradientDescentOptimizer(mlp_leaky, lr)

    mlp_leaky.fit(opt_leaky, X_train_fashion_std, y_train_fashion, epochs, batch_size, showplot=False)

    # Performance on Train dataset
    yh_train = mlp_leaky.predict(X_train_fashion_std)
    acc_train = evaluate_acc(y_train_fashion, yh_train)

    # Performance on Test dataset
    yh_test = mlp_leaky.predict(X_test_fashion_std)
    acc_test = evaluate_acc(y_test_fashion, yh_test)

    accuracies.append((acc_train, acc_test))

print(alpha_choices)
print(accuracies)
# Out:
# 100%|██████████| 250/250 [01:04<00:00,  3.90it/s]
# 100%|██████████| 250/250 [01:06<00:00,  3.74it/s]
# 100%|██████████| 250/250 [01:05<00:00,  3.84it/s]
# 100%|██████████| 250/250 [01:02<00:00,  4.01it/s]
# 100%|██████████| 250/250 [01:01<00:00,  4.04it/s]
# 100%|██████████| 250/250 [01:00<00:00,  4.13it/s]
# [0.001, 0.01, 0.05, 0.1, 0.5, 1]
# [(0.7540666666666667, 0.7385), (0.7648333333333334, 0.7476), (0.7794666666666666, 0.7558), (0.79225, 0.7782), (0.7811666666666667, 0.7679), (0.7711, 0.7573)]

# %%
# Number of neurons
K1 = 128    # Layer 1
K2 = 128    # Layer 2

# Hyper-parameters
epochs = 1250
batch_size = 256
lr = 1e-2
alpha = 0.01

mlp_leaky = MLP(
    # First Layer
    LinearLayer(n_features, K1),
    LeakyReLULayer(alpha),
    # Second Layer
    LinearLayer(K1, K2),
    LeakyReLULayer(alpha),
    # Output Layer
    LinearLayer(K2, n_classes),
    SoftmaxOutputLayer()
)
opt_leaky = GradientDescentOptimizer(mlp_leaky, lr)

mlp_leaky.fit(opt_leaky, X_train_fashion_std, y_train_fashion, epochs, batch_size, showplot=True)
# Out:
# 100%|██████████| 1250/1250 [05:01<00:00,  4.15it/s]

# %%
# Performance on Train dataset
yh_train = mlp_leaky.predict(X_train_fashion_std)
print("Train accuracy:", evaluate_acc(y_train_fashion, yh_train))

# Performance on Test dataset
yh_test = mlp_leaky.predict(X_test_fashion_std)
print("Test accuracy:", evaluate_acc(y_test_fashion, yh_test))
# Out:
# Train accuracy: 0.7700333333333333
# Train accuracy: 0.7491

# %% [markdown]
# ### Tanh activation function

# %%
class TanhLayer(NeuralNetLayer):
    def __init__(self):
        super().__init__()
        
    def forward(self, x):
        tanh = np.tanh(x)
        self.gradient = 1 - (tanh ** 2)
        return tanh

    def backward(self, gradient):
        assert self.gradient is not None, "Must call forward before backward"
        return gradient * self.gradient

# %%
# Number of neurons
K1 = 128    # Layer 1
K2 = 128    # Layer 2

# Hyper-parameters
epochs = 2500
batch_size = 256
lr = 1e-1

mlp_tanh = MLP(
    # First Layer
    LinearLayer(n_features, K1),
    TanhLayer(),
    # Second Layer
    LinearLayer(K1, K2),
    TanhLayer(),
    # Output Layer
    LinearLayer(K2, n_classes),
    SoftmaxOutputLayer()
)
opt_tanh = GradientDescentOptimizer(mlp_tanh, lr)

mlp_tanh.fit(opt_tanh, X_train_fashion_std, y_train_fashion, epochs, batch_size, showplot=True)
# Out:
# 100%|██████████| 2500/2500 [09:27<00:00,  4.40it/s]

# %%
# Performance on Train dataset
yh_train = mlp_tanh.predict(X_train_fashion_std)
print("Train accuracy:", evaluate_acc(y_train_fashion, yh_train))

# Performance on Test dataset
yh_test = mlp_tanh.predict(X_test_fashion_std)
print("Test accuracy:", evaluate_acc(y_test_fashion, yh_test))
# Out:
# Train accuracy: 0.6775333333333333
# Test accuracy: 0.6167

# %% [markdown]
# ## **Implementation 2: Part 2: MLP with 2 hidden layers.**

# %% [markdown]
# ### Tanh activation function

# %%
# Instantiate the model
model = Model()
# Add layers
model.add(Layer_Dense(X_train_fashion_normalized.shape[1], 128))
model.add(Activation_Tanh())
model.add(Layer_Dense(128, 128))
model.add(Activation_Tanh())
model.add(Layer_Dense(128, 10))
model.add(Activation_Softmax())

# Set loss, optimizer and accuracy objects
model.set(
loss=Loss_CategoricalCrossentropy(),
optimizer=Optimizer_SGD(learning_rate=0.1),
accuracy=Accuracy_Categorical()
)

# Finalize the model
model.finalize()
# Train the model
model.train(X_train_fashion_normalized, y_train_fashion, validation_data=(X_test_fashion_normalized, y_test_fashion),
epochs=20, batch_size=128, print_every=100)
model.evaluate(X_test_fashion_normalized, y_test_fashion)

plt.figure(figsize=(8, 8))
plt.title("MLP Implementation 2: Plot of Accuracies as Function of Epochs", fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.plot(model.validation_accuracies, 'g-',label='Test Accuracies')
plt.plot(model.training_accuracies, 'r-',label='Training Accuracies')
plt.legend()
# Out:
# epoch: 1
# step: 0, acc: 0.156, loss: 2.302 (data_loss: 2.302, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.297, loss: 1.803 (data_loss: 1.803, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.586, loss: 1.035 (data_loss: 1.035, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.648, loss: 0.851 (data_loss: 0.851, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.672, loss: 0.813 (data_loss: 0.813, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.750, loss: 0.655 (data_loss: 0.655, reg_loss: 0.000), lr: 0.1
# training, acc: 0.524, loss: 1.270 (data_loss: 1.270, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.726, loss: 0.729
# epoch: 2
# step: 0, acc: 0.781, loss: 0.656 (data_loss: 0.656, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.812, loss: 0.522 (data_loss: 0.522, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.773, loss: 0.527 (data_loss: 0.527, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.820, loss: 0.536 (data_loss: 0.536, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.734, loss: 0.658 (data_loss: 0.658, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.823, loss: 0.493 (data_loss: 0.493, reg_loss: 0.000), lr: 0.1
# training, acc: 0.775, loss: 0.605 (data_loss: 0.605, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.802, loss: 0.548
# epoch: 3
# step: 0, acc: 0.852, loss: 0.447 (data_loss: 0.447, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.812, loss: 0.469 (data_loss: 0.469, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.812, loss: 0.429 (data_loss: 0.429, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.867, loss: 0.456 (data_loss: 0.456, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.750, loss: 0.569 (data_loss: 0.569, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.854, loss: 0.427 (data_loss: 0.427, reg_loss: 0.000), lr: 0.1
# training, acc: 0.817, loss: 0.506 (data_loss: 0.506, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.823, loss: 0.494
# epoch: 4
# step: 0, acc: 0.867, loss: 0.372 (data_loss: 0.372, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.836, loss: 0.473 (data_loss: 0.473, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.844, loss: 0.385 (data_loss: 0.385, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.875, loss: 0.400 (data_loss: 0.400, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.758, loss: 0.528 (data_loss: 0.528, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.885, loss: 0.391 (data_loss: 0.391, reg_loss: 0.000), lr: 0.1
# training, acc: 0.834, loss: 0.460 (data_loss: 0.460, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.835, loss: 0.466
# epoch: 5
# step: 0, acc: 0.883, loss: 0.331 (data_loss: 0.331, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.867, loss: 0.442 (data_loss: 0.442, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.836, loss: 0.362 (data_loss: 0.362, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.883, loss: 0.364 (data_loss: 0.364, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.789, loss: 0.496 (data_loss: 0.496, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.865, loss: 0.367 (data_loss: 0.367, reg_loss: 0.000), lr: 0.1
# training, acc: 0.845, loss: 0.430 (data_loss: 0.430, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.840, loss: 0.448
# epoch: 6
# step: 0, acc: 0.891, loss: 0.304 (data_loss: 0.304, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.875, loss: 0.410 (data_loss: 0.410, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.844, loss: 0.343 (data_loss: 0.343, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.883, loss: 0.340 (data_loss: 0.340, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.812, loss: 0.464 (data_loss: 0.464, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.875, loss: 0.347 (data_loss: 0.347, reg_loss: 0.000), lr: 0.1
# training, acc: 0.853, loss: 0.409 (data_loss: 0.409, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.845, loss: 0.435
# epoch: 7
# step: 0, acc: 0.906, loss: 0.281 (data_loss: 0.281, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.875, loss: 0.381 (data_loss: 0.381, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.844, loss: 0.327 (data_loss: 0.327, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.898, loss: 0.322 (data_loss: 0.322, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.828, loss: 0.437 (data_loss: 0.437, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.896, loss: 0.330 (data_loss: 0.330, reg_loss: 0.000), lr: 0.1
# training, acc: 0.858, loss: 0.392 (data_loss: 0.392, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.850, loss: 0.423
# epoch: 8
# step: 0, acc: 0.922, loss: 0.262 (data_loss: 0.262, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.875, loss: 0.355 (data_loss: 0.355, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.867, loss: 0.314 (data_loss: 0.314, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.898, loss: 0.308 (data_loss: 0.308, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.828, loss: 0.414 (data_loss: 0.414, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.906, loss: 0.315 (data_loss: 0.315, reg_loss: 0.000), lr: 0.1
# training, acc: 0.862, loss: 0.378 (data_loss: 0.378, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.853, loss: 0.414
# epoch: 9
# step: 0, acc: 0.914, loss: 0.247 (data_loss: 0.247, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.875, loss: 0.333 (data_loss: 0.333, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.875, loss: 0.305 (data_loss: 0.305, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.906, loss: 0.296 (data_loss: 0.296, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.836, loss: 0.394 (data_loss: 0.394, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.906, loss: 0.304 (data_loss: 0.304, reg_loss: 0.000), lr: 0.1
# training, acc: 0.866, loss: 0.366 (data_loss: 0.366, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.857, loss: 0.407
# epoch: 10
# step: 0, acc: 0.906, loss: 0.233 (data_loss: 0.233, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.875, loss: 0.315 (data_loss: 0.315, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.883, loss: 0.297 (data_loss: 0.297, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.914, loss: 0.286 (data_loss: 0.286, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.852, loss: 0.376 (data_loss: 0.376, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.906, loss: 0.296 (data_loss: 0.296, reg_loss: 0.000), lr: 0.1
# training, acc: 0.869, loss: 0.355 (data_loss: 0.355, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.860, loss: 0.400
# epoch: 11
# step: 0, acc: 0.906, loss: 0.222 (data_loss: 0.222, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.883, loss: 0.298 (data_loss: 0.298, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.883, loss: 0.292 (data_loss: 0.292, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.898, loss: 0.278 (data_loss: 0.278, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.859, loss: 0.361 (data_loss: 0.361, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.906, loss: 0.289 (data_loss: 0.289, reg_loss: 0.000), lr: 0.1
# training, acc: 0.873, loss: 0.346 (data_loss: 0.346, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.862, loss: 0.394
# epoch: 12
# step: 0, acc: 0.914, loss: 0.212 (data_loss: 0.212, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.891, loss: 0.285 (data_loss: 0.285, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.883, loss: 0.288 (data_loss: 0.288, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.906, loss: 0.271 (data_loss: 0.271, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.867, loss: 0.347 (data_loss: 0.347, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.896, loss: 0.284 (data_loss: 0.284, reg_loss: 0.000), lr: 0.1
# training, acc: 0.876, loss: 0.337 (data_loss: 0.337, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.864, loss: 0.389
# epoch: 13
# step: 0, acc: 0.914, loss: 0.203 (data_loss: 0.203, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.898, loss: 0.273 (data_loss: 0.273, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.875, loss: 0.285 (data_loss: 0.285, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.906, loss: 0.265 (data_loss: 0.265, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.883, loss: 0.336 (data_loss: 0.336, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.896, loss: 0.279 (data_loss: 0.279, reg_loss: 0.000), lr: 0.1
# training, acc: 0.878, loss: 0.329 (data_loss: 0.329, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.866, loss: 0.385
# epoch: 14
# step: 0, acc: 0.914, loss: 0.195 (data_loss: 0.195, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.898, loss: 0.263 (data_loss: 0.263, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.883, loss: 0.282 (data_loss: 0.282, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.906, loss: 0.260 (data_loss: 0.260, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.891, loss: 0.326 (data_loss: 0.326, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.885, loss: 0.276 (data_loss: 0.276, reg_loss: 0.000), lr: 0.1
# training, acc: 0.881, loss: 0.322 (data_loss: 0.322, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.867, loss: 0.381
# epoch: 15
# step: 0, acc: 0.922, loss: 0.189 (data_loss: 0.189, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.906, loss: 0.254 (data_loss: 0.254, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.883, loss: 0.281 (data_loss: 0.281, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.898, loss: 0.257 (data_loss: 0.257, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.906, loss: 0.317 (data_loss: 0.317, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.896, loss: 0.272 (data_loss: 0.272, reg_loss: 0.000), lr: 0.1
# training, acc: 0.884, loss: 0.316 (data_loss: 0.316, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.868, loss: 0.377
# epoch: 16
# step: 0, acc: 0.922, loss: 0.183 (data_loss: 0.183, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.906, loss: 0.247 (data_loss: 0.247, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.883, loss: 0.279 (data_loss: 0.279, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.914, loss: 0.254 (data_loss: 0.254, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.914, loss: 0.309 (data_loss: 0.309, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.896, loss: 0.269 (data_loss: 0.269, reg_loss: 0.000), lr: 0.1
# training, acc: 0.886, loss: 0.310 (data_loss: 0.310, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.870, loss: 0.374
# epoch: 17
# step: 0, acc: 0.922, loss: 0.178 (data_loss: 0.178, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.914, loss: 0.241 (data_loss: 0.241, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.883, loss: 0.278 (data_loss: 0.278, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.914, loss: 0.251 (data_loss: 0.251, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.922, loss: 0.301 (data_loss: 0.301, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.896, loss: 0.266 (data_loss: 0.266, reg_loss: 0.000), lr: 0.1
# training, acc: 0.888, loss: 0.304 (data_loss: 0.304, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.870, loss: 0.372
# epoch: 18
# step: 0, acc: 0.930, loss: 0.174 (data_loss: 0.174, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.914, loss: 0.236 (data_loss: 0.236, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.891, loss: 0.277 (data_loss: 0.277, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.914, loss: 0.249 (data_loss: 0.249, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.914, loss: 0.295 (data_loss: 0.295, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.896, loss: 0.262 (data_loss: 0.262, reg_loss: 0.000), lr: 0.1
# training, acc: 0.890, loss: 0.299 (data_loss: 0.299, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.870, loss: 0.369
# epoch: 19
# step: 0, acc: 0.922, loss: 0.171 (data_loss: 0.171, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.922, loss: 0.232 (data_loss: 0.232, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.891, loss: 0.276 (data_loss: 0.276, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.914, loss: 0.248 (data_loss: 0.248, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.914, loss: 0.288 (data_loss: 0.288, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.896, loss: 0.259 (data_loss: 0.259, reg_loss: 0.000), lr: 0.1
# training, acc: 0.892, loss: 0.294 (data_loss: 0.294, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.871, loss: 0.367
# epoch: 20
# step: 0, acc: 0.938, loss: 0.168 (data_loss: 0.168, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.930, loss: 0.228 (data_loss: 0.228, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.891, loss: 0.276 (data_loss: 0.276, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.922, loss: 0.246 (data_loss: 0.246, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.922, loss: 0.282 (data_loss: 0.282, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.896, loss: 0.255 (data_loss: 0.255, reg_loss: 0.000), lr: 0.1
# training, acc: 0.893, loss: 0.289 (data_loss: 0.289, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.872, loss: 0.365
# validation, acc: 0.872, loss: 0.365

# %% [markdown]
# ### Leaky ReLU activation function

# %%
# Instantiate the model
model = Model()
# Add layers
model.add(Layer_Dense(X_train_fashion_normalized.shape[1], 128))
model.add(Activation_Leaky_ReLU(alpha=0.1))
model.add(Layer_Dense(128, 128))
model.add(Activation_Leaky_ReLU(alpha=0.1))
model.add(Layer_Dense(128, 10))
model.add(Activation_Softmax())

# Set loss, optimizer and accuracy objects
model.set(
    loss=Loss_CategoricalCrossentropy(),
    optimizer=Optimizer_SGD(learning_rate=0.1),
    accuracy=Accuracy_Categorical()
)

# Finalize the model
model.finalize()
# Train the model
model.train(X_train_fashion_normalized, y_train_fashion, validation_data=(X_test_fashion_normalized, y_test_fashion),
epochs=20, batch_size=128, print_every=100)
model.evaluate(X_test_fashion_normalized, y_test_fashion)

plt.figure(figsize=(8, 8))
plt.title("MLP Implementation 2: Plot of Accuracies as Function of Epochs", fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.plot(model.validation_accuracies, 'g-',label='Test Accuracies')
plt.plot(model.training_accuracies, 'r-',label='Training Accuracies')
plt.legend()
# Out:
# epoch: 1
# step: 0, acc: 0.039, loss: 2.303 (data_loss: 2.303, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.109, loss: 2.290 (data_loss: 2.290, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.414, loss: 1.316 (data_loss: 1.316, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.547, loss: 1.212 (data_loss: 1.212, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.625, loss: 0.867 (data_loss: 0.867, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.740, loss: 0.807 (data_loss: 0.807, reg_loss: 0.000), lr: 0.1
# training, acc: 0.443, loss: 1.483 (data_loss: 1.483, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.699, loss: 0.821
# epoch: 2
# step: 0, acc: 0.758, loss: 0.687 (data_loss: 0.687, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.734, loss: 0.644 (data_loss: 0.644, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.750, loss: 0.618 (data_loss: 0.618, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.766, loss: 0.594 (data_loss: 0.594, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.742, loss: 0.660 (data_loss: 0.660, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.812, loss: 0.561 (data_loss: 0.561, reg_loss: 0.000), lr: 0.1
# training, acc: 0.750, loss: 0.681 (data_loss: 0.681, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.795, loss: 0.595
# epoch: 3
# step: 0, acc: 0.875, loss: 0.446 (data_loss: 0.446, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.805, loss: 0.525 (data_loss: 0.525, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.773, loss: 0.491 (data_loss: 0.491, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.852, loss: 0.466 (data_loss: 0.466, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.727, loss: 0.626 (data_loss: 0.626, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.854, loss: 0.534 (data_loss: 0.534, reg_loss: 0.000), lr: 0.1
# training, acc: 0.809, loss: 0.540 (data_loss: 0.540, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.810, loss: 0.533
# epoch: 4
# step: 0, acc: 0.891, loss: 0.348 (data_loss: 0.348, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.820, loss: 0.473 (data_loss: 0.473, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.805, loss: 0.412 (data_loss: 0.412, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.844, loss: 0.405 (data_loss: 0.405, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.766, loss: 0.570 (data_loss: 0.570, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.875, loss: 0.475 (data_loss: 0.475, reg_loss: 0.000), lr: 0.1
# training, acc: 0.831, loss: 0.473 (data_loss: 0.473, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.827, loss: 0.487
# epoch: 5
# step: 0, acc: 0.898, loss: 0.304 (data_loss: 0.304, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.844, loss: 0.451 (data_loss: 0.451, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.828, loss: 0.364 (data_loss: 0.364, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.859, loss: 0.370 (data_loss: 0.370, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.773, loss: 0.528 (data_loss: 0.528, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.875, loss: 0.421 (data_loss: 0.421, reg_loss: 0.000), lr: 0.1
# training, acc: 0.844, loss: 0.435 (data_loss: 0.435, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.836, loss: 0.456
# epoch: 6
# step: 0, acc: 0.898, loss: 0.280 (data_loss: 0.280, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.844, loss: 0.425 (data_loss: 0.425, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.875, loss: 0.329 (data_loss: 0.329, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.867, loss: 0.351 (data_loss: 0.351, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.789, loss: 0.489 (data_loss: 0.489, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.875, loss: 0.373 (data_loss: 0.373, reg_loss: 0.000), lr: 0.1
# training, acc: 0.852, loss: 0.410 (data_loss: 0.410, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.845, loss: 0.435
# epoch: 7
# step: 0, acc: 0.914, loss: 0.265 (data_loss: 0.265, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.852, loss: 0.393 (data_loss: 0.393, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.867, loss: 0.310 (data_loss: 0.310, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.867, loss: 0.337 (data_loss: 0.337, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.812, loss: 0.447 (data_loss: 0.447, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.906, loss: 0.336 (data_loss: 0.336, reg_loss: 0.000), lr: 0.1
# training, acc: 0.859, loss: 0.390 (data_loss: 0.390, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.852, loss: 0.419
# epoch: 8
# step: 0, acc: 0.914, loss: 0.252 (data_loss: 0.252, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.852, loss: 0.367 (data_loss: 0.367, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.883, loss: 0.295 (data_loss: 0.295, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.875, loss: 0.327 (data_loss: 0.327, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.805, loss: 0.428 (data_loss: 0.428, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.917, loss: 0.313 (data_loss: 0.313, reg_loss: 0.000), lr: 0.1
# training, acc: 0.863, loss: 0.374 (data_loss: 0.374, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.854, loss: 0.407
# epoch: 9
# step: 0, acc: 0.922, loss: 0.239 (data_loss: 0.239, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.883, loss: 0.349 (data_loss: 0.349, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.883, loss: 0.291 (data_loss: 0.291, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.883, loss: 0.320 (data_loss: 0.320, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.820, loss: 0.401 (data_loss: 0.401, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.917, loss: 0.293 (data_loss: 0.293, reg_loss: 0.000), lr: 0.1
# training, acc: 0.868, loss: 0.360 (data_loss: 0.360, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.859, loss: 0.393
# epoch: 10
# step: 0, acc: 0.922, loss: 0.218 (data_loss: 0.218, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.891, loss: 0.327 (data_loss: 0.327, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.883, loss: 0.283 (data_loss: 0.283, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.883, loss: 0.314 (data_loss: 0.314, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.812, loss: 0.381 (data_loss: 0.381, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.906, loss: 0.277 (data_loss: 0.277, reg_loss: 0.000), lr: 0.1
# training, acc: 0.872, loss: 0.348 (data_loss: 0.348, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.861, loss: 0.385
# epoch: 11
# step: 0, acc: 0.906, loss: 0.213 (data_loss: 0.213, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.891, loss: 0.316 (data_loss: 0.316, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.883, loss: 0.282 (data_loss: 0.282, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.891, loss: 0.309 (data_loss: 0.309, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.844, loss: 0.354 (data_loss: 0.354, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.906, loss: 0.267 (data_loss: 0.267, reg_loss: 0.000), lr: 0.1
# training, acc: 0.876, loss: 0.337 (data_loss: 0.337, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.863, loss: 0.380
# epoch: 12
# step: 0, acc: 0.906, loss: 0.208 (data_loss: 0.208, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.906, loss: 0.289 (data_loss: 0.289, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.883, loss: 0.282 (data_loss: 0.282, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.883, loss: 0.306 (data_loss: 0.306, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.859, loss: 0.337 (data_loss: 0.337, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.917, loss: 0.254 (data_loss: 0.254, reg_loss: 0.000), lr: 0.1
# training, acc: 0.879, loss: 0.328 (data_loss: 0.328, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.865, loss: 0.372
# epoch: 13
# step: 0, acc: 0.914, loss: 0.200 (data_loss: 0.200, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.906, loss: 0.281 (data_loss: 0.281, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.891, loss: 0.283 (data_loss: 0.283, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.891, loss: 0.302 (data_loss: 0.302, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.859, loss: 0.322 (data_loss: 0.322, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.906, loss: 0.248 (data_loss: 0.248, reg_loss: 0.000), lr: 0.1
# training, acc: 0.882, loss: 0.319 (data_loss: 0.319, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.866, loss: 0.368
# epoch: 14
# step: 0, acc: 0.906, loss: 0.197 (data_loss: 0.197, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.906, loss: 0.274 (data_loss: 0.274, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.875, loss: 0.281 (data_loss: 0.281, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.891, loss: 0.296 (data_loss: 0.296, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.867, loss: 0.313 (data_loss: 0.313, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.917, loss: 0.240 (data_loss: 0.240, reg_loss: 0.000), lr: 0.1
# training, acc: 0.885, loss: 0.312 (data_loss: 0.312, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.868, loss: 0.365
# epoch: 15
# step: 0, acc: 0.906, loss: 0.195 (data_loss: 0.195, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.922, loss: 0.244 (data_loss: 0.244, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.867, loss: 0.287 (data_loss: 0.287, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.891, loss: 0.293 (data_loss: 0.293, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.883, loss: 0.302 (data_loss: 0.302, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.906, loss: 0.239 (data_loss: 0.239, reg_loss: 0.000), lr: 0.1
# training, acc: 0.887, loss: 0.305 (data_loss: 0.305, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.867, loss: 0.364
# epoch: 16
# step: 0, acc: 0.914, loss: 0.193 (data_loss: 0.193, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.922, loss: 0.243 (data_loss: 0.243, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.875, loss: 0.285 (data_loss: 0.285, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.891, loss: 0.290 (data_loss: 0.290, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.891, loss: 0.301 (data_loss: 0.301, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.917, loss: 0.232 (data_loss: 0.232, reg_loss: 0.000), lr: 0.1
# training, acc: 0.890, loss: 0.298 (data_loss: 0.298, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.870, loss: 0.360
# epoch: 17
# step: 0, acc: 0.914, loss: 0.189 (data_loss: 0.189, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.922, loss: 0.237 (data_loss: 0.237, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.867, loss: 0.285 (data_loss: 0.285, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.898, loss: 0.287 (data_loss: 0.287, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.891, loss: 0.292 (data_loss: 0.292, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.917, loss: 0.223 (data_loss: 0.223, reg_loss: 0.000), lr: 0.1
# training, acc: 0.892, loss: 0.292 (data_loss: 0.292, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.871, loss: 0.355
# epoch: 18
# step: 0, acc: 0.922, loss: 0.183 (data_loss: 0.183, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.930, loss: 0.231 (data_loss: 0.231, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.867, loss: 0.281 (data_loss: 0.281, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.906, loss: 0.282 (data_loss: 0.282, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.898, loss: 0.290 (data_loss: 0.290, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.917, loss: 0.218 (data_loss: 0.218, reg_loss: 0.000), lr: 0.1
# training, acc: 0.893, loss: 0.286 (data_loss: 0.286, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.875, loss: 0.351
# epoch: 19
# step: 0, acc: 0.930, loss: 0.178 (data_loss: 0.178, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.938, loss: 0.227 (data_loss: 0.227, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.875, loss: 0.284 (data_loss: 0.284, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.906, loss: 0.277 (data_loss: 0.277, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.906, loss: 0.281 (data_loss: 0.281, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.917, loss: 0.214 (data_loss: 0.214, reg_loss: 0.000), lr: 0.1
# training, acc: 0.896, loss: 0.280 (data_loss: 0.280, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.875, loss: 0.349
# epoch: 20
# step: 0, acc: 0.938, loss: 0.173 (data_loss: 0.173, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.930, loss: 0.226 (data_loss: 0.226, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.875, loss: 0.282 (data_loss: 0.282, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.906, loss: 0.276 (data_loss: 0.276, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.906, loss: 0.271 (data_loss: 0.271, reg_loss: 0.000), lr: 0.1
# step: 468, acc: 0.917, loss: 0.214 (data_loss: 0.214, reg_loss: 0.000), lr: 0.1
# training, acc: 0.898, loss: 0.275 (data_loss: 0.275, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.876, loss: 0.348
# validation, acc: 0.876, loss: 0.348

# %% [markdown]
# ## **Implementation 1 and 2: Part 3 - MLP with 2 hidden layers, ReLU activations, and L2 regularization.**

# %% [markdown]
# ### MLP Implementation 1

# %%
# Number of features & classes
n_features = 784
n_classes = 10

# Hyper-parameters
batch_size = 256
lr = 1e-2

# Number of neurons
K1 = 128    # Layer 1
K2 = 128    # Layer 2

# %%
train_acc_relu_no_l2 = []
test_acc_relu_no_l2 = []
epoch_value = []

for epoch_selected in range(100, 501, 100):
  mlp_relu = MLP(
      # First Layer
      LinearLayer(n_features, K1),
      ReLULayer(),
      # Second Layer
      LinearLayer(K1, K2),
      ReLULayer(),
      # Output Layer
      LinearLayer(K2, n_classes),
      SoftmaxOutputLayer()
  )

  opt_relu = GradientDescentOptimizer(mlp_relu, lr)

  mlp_relu.fit(opt_relu, X_train_fashion_normalized, y_train_fashion, epoch_selected, batch_size, showplot=False)

  # Performance on Train dataset
  yh_train_data = mlp_relu.predict(X_train_fashion_normalized)
  train_acc = evaluate_acc(y_train_fashion, yh_train_data)

  # Performance on Test dataset
  yh_test_data = mlp_relu.predict(X_test_fashion_normalized)
  test_acc = evaluate_acc(y_test_fashion, yh_test_data)

  train_acc_relu_no_l2.append(train_acc)
  test_acc_relu_no_l2.append(test_acc)
  epoch_value.append(epoch_selected)
# Out:
# 100%|██████████| 100/100 [00:25<00:00,  3.93it/s]
# 100%|██████████| 200/200 [00:54<00:00,  3.66it/s]
# 100%|██████████| 300/300 [01:24<00:00,  3.55it/s]
# 100%|██████████| 400/400 [01:42<00:00,  3.89it/s]
# 100%|██████████| 500/500 [02:02<00:00,  4.07it/s]

# %%
plt.plot(epoch_value, train_acc_relu_no_l2)
plt.plot(epoch_value, test_acc_relu_no_l2)
plt.suptitle('MLP Implementation 1: Plot of Accuracies as Function of Epochs 2 Hidden Layers ')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
epochs = 350
mlp_relu_without_l2 = MLP(
    # First Layer
    LinearLayer(n_features, K1),
    ReLULayer(),
    # Second Layer
    LinearLayer(K1, K2),
    ReLULayer(),
    # Output Layer
    LinearLayer(K2, n_classes),
    SoftmaxOutputLayer()
)

opt_relu_without_l2 = GradientDescentOptimizer(mlp_relu_without_l2, lr)

mlp_relu_without_l2.fit(opt_relu_without_l2, X_train_fashion_normalized, y_train_fashion, epochs, batch_size, showplot=True)
# Out:
# 100%|██████████| 350/350 [01:27<00:00,  3.99it/s]

# %%
# Performance on Train dataset
yh_train = mlp_relu_without_l2.predict(X_train_fashion_normalized)
print("Train accuracy:", evaluate_acc(y_train_fashion, yh_train))

# Performance on Test dataset
yh_test = mlp_relu_without_l2.predict(X_test_fashion_normalized)
print("Test accuracy:", evaluate_acc(y_test_fashion, yh_test))
# Out:
# Train accuracy: 0.6954833333333333
# Test accuracy: 0.6805

# %%
# Optimizing L2 Lambda
train_acc_relu = []
test_acc_relu = []
l2_value = []
epoch_selected = 350

for l2 in range(10, 101, 10):
  l2_regularization_weight_value = l2/100

  mlp_relu_l2_opt = MLP(
      # First Layer
      LinearLayer(n_features, K1, l2_regularization_weight=l2_regularization_weight_value),
      ReLULayer(),
      # Second Layer
      LinearLayer(K1, K2, l2_regularization_weight=l2_regularization_weight_value),
      ReLULayer(),
      # Output Layer
      LinearLayer(K2, n_classes, l2_regularization_weight=l2_regularization_weight_value),
      SoftmaxOutputLayer()
  )

  opt_relu_l2_opt = GradientDescentOptimizer(mlp_relu_l2_opt, lr)

  mlp_relu_l2_opt.fit(opt_relu_l2_opt, X_train_fashion_normalized, y_train_fashion, epoch_selected, batch_size, showplot=False)

  # Performance on Train dataset
  yh_train_data = mlp_relu_l2_opt.predict(X_train_fashion_normalized)
  train_acc = evaluate_acc(y_train_fashion, yh_train_data)

  # Performance on Test dataset
  yh_test_data = mlp_relu_l2_opt.predict(X_test_fashion_normalized)
  test_acc = evaluate_acc(y_test_fashion, yh_test_data)

  train_acc_relu.append(train_acc)
  test_acc_relu.append(test_acc)
  l2_value.append(l2_regularization_weight_value)
# Out:
# 100%|██████████| 350/350 [01:34<00:00,  3.69it/s]
# 100%|██████████| 350/350 [01:31<00:00,  3.85it/s]
# 100%|██████████| 350/350 [01:30<00:00,  3.86it/s]
# 100%|██████████| 350/350 [01:38<00:00,  3.57it/s]
# 100%|██████████| 350/350 [01:30<00:00,  3.87it/s]
# 100%|██████████| 350/350 [01:31<00:00,  3.81it/s]
# 100%|██████████| 350/350 [01:33<00:00,  3.76it/s]
# 100%|██████████| 350/350 [01:30<00:00,  3.87it/s]
# 100%|██████████| 350/350 [01:30<00:00,  3.85it/s]
# 100%|██████████| 350/350 [01:33<00:00,  3.76it/s]

# %%
plt.xticks(np.arange(0, 1, 0.1))
plt.plot(l2_value, train_acc_relu)
plt.plot(l2_value, test_acc_relu)
plt.suptitle('MLP Implementation 1: Accuracy over Various L2 Lambda Values')
plt.xlabel('L2 Regularization Lambda Value')
plt.ylabel('Accuracy')
plt.show()

# %%
train_acc_relu_with_l2 = []
test_acc_relu_with_l2 = []
epoch_value = []

l2_regularization_weight_value = 0.4

for epoch_selected in range(100, 501, 100):
  mlp_relu = MLP(
      # First Layer
      LinearLayer(n_features, K1, l2_regularization_weight=l2_regularization_weight_value),
      ReLULayer(),
      # Second Layer
      LinearLayer(K1, K2, l2_regularization_weight=l2_regularization_weight_value),
      ReLULayer(),
      # Output Layer
      LinearLayer(K2, n_classes, l2_regularization_weight=l2_regularization_weight_value),
      SoftmaxOutputLayer()
  )

  opt_relu = GradientDescentOptimizer(mlp_relu, lr)

  mlp_relu.fit(opt_relu, X_train_fashion_normalized, y_train_fashion, epoch_selected, batch_size, showplot=False)

  # Performance on Train dataset
  yh_train_data = mlp_relu.predict(X_train_fashion_normalized)
  train_acc = evaluate_acc(y_train_fashion, yh_train_data)

  # Performance on Test dataset
  yh_test_data = mlp_relu.predict(X_test_fashion_normalized)
  test_acc = evaluate_acc(y_test_fashion, yh_test_data)

  train_acc_relu_with_l2.append(train_acc)
  test_acc_relu_with_l2.append(test_acc)
  epoch_value.append(epoch_selected)
# Out:
# 100%|██████████| 100/100 [00:25<00:00,  3.97it/s]
# 100%|██████████| 200/200 [00:54<00:00,  3.65it/s]
# 100%|██████████| 300/300 [01:15<00:00,  3.98it/s]
# 100%|██████████| 400/400 [01:54<00:00,  3.50it/s]
# 100%|██████████| 500/500 [02:10<00:00,  3.83it/s]

# %%
plt.plot(epoch_value, train_acc_relu_with_l2)
plt.plot(epoch_value, test_acc_relu_with_l2)
plt.suptitle('MLP Implementation 1: Plot of Accuracies as Function of Epochs 2 Hidden Layers with L2 Regularization')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
epochs = 400

mlp_relu_with_l2 = MLP(
    # First Layer
    LinearLayer(n_features, K1, l2_regularization_weight=l2_regularization_weight_value),
    ReLULayer(),
    # Second Layer
    LinearLayer(K1, K2, l2_regularization_weight=l2_regularization_weight_value),
    ReLULayer(),
    # Output Layer
    LinearLayer(K2, n_classes, l2_regularization_weight=l2_regularization_weight_value),
    SoftmaxOutputLayer()
)

opt_relu_with_l2 = GradientDescentOptimizer(mlp_relu_with_l2, lr)

mlp_relu_with_l2.fit(opt_relu_with_l2, X_train_fashion_normalized, y_train_fashion, epochs, batch_size, showplot=True)
# Out:
# 100%|██████████| 400/400 [01:48<00:00,  3.69it/s]

# %%
# Performance on Train dataset
yh_train = mlp_relu_with_l2.predict(X_train_fashion_normalized)
print("Train accuracy:", evaluate_acc(y_train_fashion, yh_train))

# Performance on Test dataset
yh_test = mlp_relu_with_l2.predict(X_test_fashion_normalized)
print("Test accuracy:", evaluate_acc(y_test_fashion, yh_test))
# Out:
# Train accuracy: 0.7283833333333334
# Test accuracy: 0.7227

# %% [markdown]
# ### MLP Implementation 2

# %%
# Instantiate the model
model = Model()
# Add layers
model.add(Layer_Dense(X_train_fashion_normalized.shape[1], 128))
model.add(Activation_ReLU())
model.add(Layer_Dense(128, 128, weight_regularizer_l2=0.01, bias_regularizer_l2=0.01))
model.add(Activation_ReLU())
model.add(Layer_Dense(128, 10, weight_regularizer_l2=0.01, bias_regularizer_l2=0.01))
model.add(Activation_Softmax())

# Set loss, optimizer and accuracy objects
model.set(
loss=Loss_CategoricalCrossentropy(),
optimizer=Optimizer_SGD(learning_rate=0.1),
accuracy=Accuracy_Categorical()
)

# Finalize the model
model.finalize()
# Train the model
model.train(X_train_fashion_normalized, y_train_fashion, validation_data=(X_test_fashion_normalized, y_test_fashion),
epochs=20, batch_size=128, print_every=100)
model.evaluate(X_test_fashion_normalized, y_test_fashion)

plt.figure(figsize=(8, 8))
plt.title("MLP Implementation 2: Plot of Accuracies as Function of Epochs", fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.plot(model.validation_accuracies, 'g-',label='Test Accuracies')
plt.plot(model.training_accuracies, 'r-',label='Training Accuracies')
plt.legend()
# Out:
# epoch: 1
# step: 0, acc: 0.047, loss: 2.320 (data_loss: 2.303, reg_loss: 0.018), lr: 0.1
# step: 100, acc: 0.094, loss: 2.309 (data_loss: 2.297, reg_loss: 0.013), lr: 0.1
# step: 200, acc: 0.281, loss: 1.546 (data_loss: 1.498, reg_loss: 0.049), lr: 0.1
# step: 300, acc: 0.594, loss: 1.187 (data_loss: 1.089, reg_loss: 0.098), lr: 0.1
# step: 400, acc: 0.586, loss: 1.136 (data_loss: 1.013, reg_loss: 0.123), lr: 0.1
# step: 468, acc: 0.562, loss: 1.165 (data_loss: 1.035, reg_loss: 0.130), lr: 0.1
# training, acc: 0.386, loss: 1.735 (data_loss: 1.604, reg_loss: 0.130), lr: 0.1
# validation, acc: 0.654, loss: 0.953
# epoch: 2
# step: 0, acc: 0.719, loss: 0.986 (data_loss: 0.856, reg_loss: 0.130), lr: 0.1
# step: 100, acc: 0.703, loss: 0.896 (data_loss: 0.761, reg_loss: 0.135), lr: 0.1
# step: 200, acc: 0.578, loss: 0.970 (data_loss: 0.833, reg_loss: 0.137), lr: 0.1
# step: 300, acc: 0.703, loss: 0.911 (data_loss: 0.771, reg_loss: 0.140), lr: 0.1
# step: 400, acc: 0.734, loss: 0.879 (data_loss: 0.735, reg_loss: 0.144), lr: 0.1
# step: 468, acc: 0.802, loss: 0.877 (data_loss: 0.732, reg_loss: 0.144), lr: 0.1
# training, acc: 0.684, loss: 0.996 (data_loss: 0.852, reg_loss: 0.145), lr: 0.1
# validation, acc: 0.720, loss: 0.757
# epoch: 3
# step: 0, acc: 0.789, loss: 0.765 (data_loss: 0.620, reg_loss: 0.145), lr: 0.1
# step: 100, acc: 0.766, loss: 0.757 (data_loss: 0.610, reg_loss: 0.147), lr: 0.1
# step: 200, acc: 0.742, loss: 0.783 (data_loss: 0.637, reg_loss: 0.146), lr: 0.1
# step: 300, acc: 0.789, loss: 0.820 (data_loss: 0.674, reg_loss: 0.146), lr: 0.1
# step: 400, acc: 0.742, loss: 0.798 (data_loss: 0.651, reg_loss: 0.147), lr: 0.1
# step: 468, acc: 0.781, loss: 0.807 (data_loss: 0.661, reg_loss: 0.146), lr: 0.1
# training, acc: 0.744, loss: 0.852 (data_loss: 0.706, reg_loss: 0.146), lr: 0.1
# validation, acc: 0.759, loss: 0.664
# epoch: 4
# step: 0, acc: 0.820, loss: 0.676 (data_loss: 0.530, reg_loss: 0.146), lr: 0.1
# step: 100, acc: 0.805, loss: 0.691 (data_loss: 0.544, reg_loss: 0.147), lr: 0.1
# step: 200, acc: 0.750, loss: 0.730 (data_loss: 0.586, reg_loss: 0.145), lr: 0.1
# step: 300, acc: 0.820, loss: 0.735 (data_loss: 0.592, reg_loss: 0.144), lr: 0.1
# step: 400, acc: 0.750, loss: 0.766 (data_loss: 0.622, reg_loss: 0.144), lr: 0.1
# step: 468, acc: 0.833, loss: 0.733 (data_loss: 0.591, reg_loss: 0.142), lr: 0.1
# training, acc: 0.776, loss: 0.771 (data_loss: 0.628, reg_loss: 0.142), lr: 0.1
# validation, acc: 0.788, loss: 0.611
# epoch: 5
# step: 0, acc: 0.852, loss: 0.620 (data_loss: 0.477, reg_loss: 0.142), lr: 0.1
# step: 100, acc: 0.820, loss: 0.663 (data_loss: 0.519, reg_loss: 0.144), lr: 0.1
# step: 200, acc: 0.750, loss: 0.679 (data_loss: 0.538, reg_loss: 0.142), lr: 0.1
# step: 300, acc: 0.805, loss: 0.691 (data_loss: 0.551, reg_loss: 0.140), lr: 0.1
# step: 400, acc: 0.758, loss: 0.742 (data_loss: 0.602, reg_loss: 0.141), lr: 0.1
# step: 468, acc: 0.854, loss: 0.669 (data_loss: 0.529, reg_loss: 0.139), lr: 0.1
# training, acc: 0.796, loss: 0.720 (data_loss: 0.581, reg_loss: 0.139), lr: 0.1
# validation, acc: 0.804, loss: 0.576
# epoch: 6
# step: 0, acc: 0.875, loss: 0.576 (data_loss: 0.436, reg_loss: 0.139), lr: 0.1
# step: 100, acc: 0.820, loss: 0.653 (data_loss: 0.512, reg_loss: 0.141), lr: 0.1
# step: 200, acc: 0.758, loss: 0.645 (data_loss: 0.507, reg_loss: 0.138), lr: 0.1
# step: 300, acc: 0.844, loss: 0.668 (data_loss: 0.530, reg_loss: 0.137), lr: 0.1
# step: 400, acc: 0.773, loss: 0.720 (data_loss: 0.583, reg_loss: 0.137), lr: 0.1
# step: 468, acc: 0.885, loss: 0.634 (data_loss: 0.498, reg_loss: 0.136), lr: 0.1
# training, acc: 0.808, loss: 0.687 (data_loss: 0.551, reg_loss: 0.136), lr: 0.1
# validation, acc: 0.811, loss: 0.554
# epoch: 7
# step: 0, acc: 0.875, loss: 0.547 (data_loss: 0.410, reg_loss: 0.136), lr: 0.1
# step: 100, acc: 0.820, loss: 0.636 (data_loss: 0.498, reg_loss: 0.137), lr: 0.1
# step: 200, acc: 0.766, loss: 0.623 (data_loss: 0.488, reg_loss: 0.135), lr: 0.1
# step: 300, acc: 0.844, loss: 0.652 (data_loss: 0.518, reg_loss: 0.134), lr: 0.1
# step: 400, acc: 0.758, loss: 0.703 (data_loss: 0.569, reg_loss: 0.134), lr: 0.1
# step: 468, acc: 0.875, loss: 0.613 (data_loss: 0.480, reg_loss: 0.133), lr: 0.1
# training, acc: 0.815, loss: 0.663 (data_loss: 0.530, reg_loss: 0.133), lr: 0.1
# validation, acc: 0.815, loss: 0.539
# epoch: 8
# step: 0, acc: 0.883, loss: 0.526 (data_loss: 0.393, reg_loss: 0.133), lr: 0.1
# step: 100, acc: 0.828, loss: 0.617 (data_loss: 0.483, reg_loss: 0.134), lr: 0.1
# step: 200, acc: 0.766, loss: 0.607 (data_loss: 0.475, reg_loss: 0.132), lr: 0.1
# step: 300, acc: 0.844, loss: 0.639 (data_loss: 0.507, reg_loss: 0.131), lr: 0.1
# step: 400, acc: 0.766, loss: 0.688 (data_loss: 0.557, reg_loss: 0.131), lr: 0.1
# step: 468, acc: 0.865, loss: 0.595 (data_loss: 0.465, reg_loss: 0.131), lr: 0.1
# training, acc: 0.821, loss: 0.646 (data_loss: 0.515, reg_loss: 0.131), lr: 0.1
# validation, acc: 0.819, loss: 0.527
# epoch: 9
# step: 0, acc: 0.898, loss: 0.509 (data_loss: 0.378, reg_loss: 0.131), lr: 0.1
# step: 100, acc: 0.836, loss: 0.603 (data_loss: 0.471, reg_loss: 0.132), lr: 0.1
# step: 200, acc: 0.766, loss: 0.592 (data_loss: 0.462, reg_loss: 0.130), lr: 0.1
# step: 300, acc: 0.844, loss: 0.626 (data_loss: 0.497, reg_loss: 0.129), lr: 0.1
# step: 400, acc: 0.766, loss: 0.677 (data_loss: 0.548, reg_loss: 0.129), lr: 0.1
# step: 468, acc: 0.865, loss: 0.582 (data_loss: 0.453, reg_loss: 0.129), lr: 0.1
# training, acc: 0.825, loss: 0.631 (data_loss: 0.503, reg_loss: 0.129), lr: 0.1
# validation, acc: 0.823, loss: 0.517
# epoch: 10
# step: 0, acc: 0.898, loss: 0.495 (data_loss: 0.367, reg_loss: 0.129), lr: 0.1
# step: 100, acc: 0.844, loss: 0.589 (data_loss: 0.459, reg_loss: 0.130), lr: 0.1
# step: 200, acc: 0.789, loss: 0.581 (data_loss: 0.453, reg_loss: 0.128), lr: 0.1
# step: 300, acc: 0.844, loss: 0.615 (data_loss: 0.488, reg_loss: 0.127), lr: 0.1
# step: 400, acc: 0.766, loss: 0.667 (data_loss: 0.540, reg_loss: 0.127), lr: 0.1
# step: 468, acc: 0.865, loss: 0.570 (data_loss: 0.444, reg_loss: 0.127), lr: 0.1
# training, acc: 0.828, loss: 0.620 (data_loss: 0.493, reg_loss: 0.127), lr: 0.1
# validation, acc: 0.826, loss: 0.509
# epoch: 11
# step: 0, acc: 0.891, loss: 0.485 (data_loss: 0.358, reg_loss: 0.127), lr: 0.1
# step: 100, acc: 0.859, loss: 0.576 (data_loss: 0.448, reg_loss: 0.128), lr: 0.1
# step: 200, acc: 0.789, loss: 0.572 (data_loss: 0.445, reg_loss: 0.126), lr: 0.1
# step: 300, acc: 0.844, loss: 0.605 (data_loss: 0.480, reg_loss: 0.126), lr: 0.1
# step: 400, acc: 0.773, loss: 0.657 (data_loss: 0.532, reg_loss: 0.126), lr: 0.1
# step: 468, acc: 0.875, loss: 0.561 (data_loss: 0.436, reg_loss: 0.125), lr: 0.1
# training, acc: 0.831, loss: 0.609 (data_loss: 0.484, reg_loss: 0.125), lr: 0.1
# validation, acc: 0.828, loss: 0.501
# epoch: 12
# step: 0, acc: 0.898, loss: 0.475 (data_loss: 0.350, reg_loss: 0.125), lr: 0.1
# step: 100, acc: 0.867, loss: 0.566 (data_loss: 0.440, reg_loss: 0.126), lr: 0.1
# step: 200, acc: 0.789, loss: 0.561 (data_loss: 0.437, reg_loss: 0.125), lr: 0.1
# step: 300, acc: 0.844, loss: 0.596 (data_loss: 0.472, reg_loss: 0.124), lr: 0.1
# step: 400, acc: 0.773, loss: 0.650 (data_loss: 0.525, reg_loss: 0.124), lr: 0.1
# step: 468, acc: 0.875, loss: 0.552 (data_loss: 0.428, reg_loss: 0.124), lr: 0.1
# training, acc: 0.834, loss: 0.601 (data_loss: 0.477, reg_loss: 0.124), lr: 0.1
# validation, acc: 0.829, loss: 0.495
# epoch: 13
# step: 0, acc: 0.906, loss: 0.468 (data_loss: 0.344, reg_loss: 0.124), lr: 0.1
# step: 100, acc: 0.859, loss: 0.556 (data_loss: 0.431, reg_loss: 0.125), lr: 0.1
# step: 200, acc: 0.812, loss: 0.553 (data_loss: 0.430, reg_loss: 0.124), lr: 0.1
# step: 300, acc: 0.852, loss: 0.587 (data_loss: 0.464, reg_loss: 0.123), lr: 0.1
# step: 400, acc: 0.781, loss: 0.641 (data_loss: 0.518, reg_loss: 0.123), lr: 0.1
# step: 468, acc: 0.875, loss: 0.544 (data_loss: 0.422, reg_loss: 0.123), lr: 0.1
# training, acc: 0.836, loss: 0.593 (data_loss: 0.470, reg_loss: 0.123), lr: 0.1
# validation, acc: 0.831, loss: 0.489
# epoch: 14
# step: 0, acc: 0.906, loss: 0.461 (data_loss: 0.338, reg_loss: 0.123), lr: 0.1
# step: 100, acc: 0.867, loss: 0.547 (data_loss: 0.423, reg_loss: 0.124), lr: 0.1
# step: 200, acc: 0.812, loss: 0.545 (data_loss: 0.423, reg_loss: 0.122), lr: 0.1
# step: 300, acc: 0.852, loss: 0.579 (data_loss: 0.457, reg_loss: 0.122), lr: 0.1
# step: 400, acc: 0.781, loss: 0.636 (data_loss: 0.514, reg_loss: 0.122), lr: 0.1
# step: 468, acc: 0.885, loss: 0.538 (data_loss: 0.416, reg_loss: 0.121), lr: 0.1
# training, acc: 0.838, loss: 0.585 (data_loss: 0.464, reg_loss: 0.122), lr: 0.1
# validation, acc: 0.832, loss: 0.484
# epoch: 15
# step: 0, acc: 0.906, loss: 0.455 (data_loss: 0.333, reg_loss: 0.122), lr: 0.1
# step: 100, acc: 0.867, loss: 0.537 (data_loss: 0.415, reg_loss: 0.123), lr: 0.1
# step: 200, acc: 0.812, loss: 0.538 (data_loss: 0.417, reg_loss: 0.121), lr: 0.1
# step: 300, acc: 0.852, loss: 0.572 (data_loss: 0.451, reg_loss: 0.121), lr: 0.1
# step: 400, acc: 0.781, loss: 0.630 (data_loss: 0.510, reg_loss: 0.121), lr: 0.1
# step: 468, acc: 0.885, loss: 0.532 (data_loss: 0.412, reg_loss: 0.120), lr: 0.1
# training, acc: 0.840, loss: 0.579 (data_loss: 0.458, reg_loss: 0.120), lr: 0.1
# validation, acc: 0.834, loss: 0.480
# epoch: 16
# step: 0, acc: 0.906, loss: 0.449 (data_loss: 0.328, reg_loss: 0.120), lr: 0.1
# step: 100, acc: 0.859, loss: 0.529 (data_loss: 0.408, reg_loss: 0.122), lr: 0.1
# step: 200, acc: 0.812, loss: 0.531 (data_loss: 0.410, reg_loss: 0.120), lr: 0.1
# step: 300, acc: 0.852, loss: 0.566 (data_loss: 0.446, reg_loss: 0.120), lr: 0.1
# step: 400, acc: 0.789, loss: 0.624 (data_loss: 0.504, reg_loss: 0.120), lr: 0.1
# step: 468, acc: 0.885, loss: 0.527 (data_loss: 0.407, reg_loss: 0.119), lr: 0.1
# training, acc: 0.842, loss: 0.573 (data_loss: 0.453, reg_loss: 0.120), lr: 0.1
# validation, acc: 0.835, loss: 0.475
# epoch: 17
# step: 0, acc: 0.906, loss: 0.443 (data_loss: 0.323, reg_loss: 0.120), lr: 0.1
# step: 100, acc: 0.859, loss: 0.522 (data_loss: 0.401, reg_loss: 0.121), lr: 0.1
# step: 200, acc: 0.812, loss: 0.525 (data_loss: 0.405, reg_loss: 0.120), lr: 0.1
# step: 300, acc: 0.859, loss: 0.560 (data_loss: 0.441, reg_loss: 0.119), lr: 0.1
# step: 400, acc: 0.789, loss: 0.618 (data_loss: 0.499, reg_loss: 0.119), lr: 0.1
# step: 468, acc: 0.885, loss: 0.523 (data_loss: 0.404, reg_loss: 0.119), lr: 0.1
# training, acc: 0.844, loss: 0.567 (data_loss: 0.448, reg_loss: 0.119), lr: 0.1
# validation, acc: 0.837, loss: 0.471
# epoch: 18
# step: 0, acc: 0.906, loss: 0.438 (data_loss: 0.319, reg_loss: 0.119), lr: 0.1
# step: 100, acc: 0.867, loss: 0.515 (data_loss: 0.395, reg_loss: 0.120), lr: 0.1
# step: 200, acc: 0.820, loss: 0.519 (data_loss: 0.400, reg_loss: 0.119), lr: 0.1
# step: 300, acc: 0.859, loss: 0.553 (data_loss: 0.435, reg_loss: 0.118), lr: 0.1
# step: 400, acc: 0.789, loss: 0.611 (data_loss: 0.493, reg_loss: 0.118), lr: 0.1
# step: 468, acc: 0.885, loss: 0.519 (data_loss: 0.401, reg_loss: 0.118), lr: 0.1
# training, acc: 0.845, loss: 0.562 (data_loss: 0.444, reg_loss: 0.118), lr: 0.1
# validation, acc: 0.839, loss: 0.467
# epoch: 19
# step: 0, acc: 0.906, loss: 0.433 (data_loss: 0.315, reg_loss: 0.118), lr: 0.1
# step: 100, acc: 0.867, loss: 0.509 (data_loss: 0.389, reg_loss: 0.119), lr: 0.1
# step: 200, acc: 0.828, loss: 0.513 (data_loss: 0.395, reg_loss: 0.118), lr: 0.1
# step: 300, acc: 0.859, loss: 0.547 (data_loss: 0.430, reg_loss: 0.118), lr: 0.1
# step: 400, acc: 0.789, loss: 0.605 (data_loss: 0.488, reg_loss: 0.118), lr: 0.1
# step: 468, acc: 0.885, loss: 0.515 (data_loss: 0.398, reg_loss: 0.117), lr: 0.1
# training, acc: 0.846, loss: 0.557 (data_loss: 0.440, reg_loss: 0.117), lr: 0.1
# validation, acc: 0.841, loss: 0.463
# epoch: 20
# step: 0, acc: 0.906, loss: 0.428 (data_loss: 0.311, reg_loss: 0.117), lr: 0.1
# step: 100, acc: 0.867, loss: 0.503 (data_loss: 0.384, reg_loss: 0.118), lr: 0.1
# step: 200, acc: 0.828, loss: 0.508 (data_loss: 0.391, reg_loss: 0.117), lr: 0.1
# step: 300, acc: 0.859, loss: 0.541 (data_loss: 0.425, reg_loss: 0.117), lr: 0.1
# step: 400, acc: 0.797, loss: 0.599 (data_loss: 0.482, reg_loss: 0.117), lr: 0.1
# step: 468, acc: 0.885, loss: 0.511 (data_loss: 0.395, reg_loss: 0.116), lr: 0.1
# training, acc: 0.848, loss: 0.553 (data_loss: 0.436, reg_loss: 0.117), lr: 0.1
# validation, acc: 0.842, loss: 0.460
# validation, acc: 0.842, loss: 0.460

# %% [markdown]
# ## **Main Implementation 1: Part 4 - MLP with 2 hidden layers, ReLU activation, on unnormalized dataset.**

# %%
train_acc_relu_unnormalized = []
test_acc_relu_unnormalized = []
epoch_value = []

for epoch_selected in range(100, 501, 100):
  mlp_relu = MLP(
      # First Layer
      LinearLayer(n_features, K1),
      ReLULayer(),
      # Second Layer
      LinearLayer(K1, K2),
      ReLULayer(),
      # Output Layer
      LinearLayer(K2, n_classes),
      SoftmaxOutputLayer()
  )

  opt_relu = GradientDescentOptimizer(mlp_relu, lr=1e-6)

  mlp_relu.fit(opt_relu, X_train_fashion, y_train_fashion, epoch_selected, batch_size, showplot=False)

  # Performance on Train dataset
  yh_train_data = mlp_relu.predict(X_train_fashion)
  train_acc = evaluate_acc(y_train_fashion, yh_train_data)

  # Performance on Test dataset
  yh_test_data = mlp_relu.predict(X_test_fashion)
  test_acc = evaluate_acc(y_test_fashion, yh_test_data)

  train_acc_relu_unnormalized.append(train_acc)
  test_acc_relu_unnormalized.append(test_acc)
  epoch_value.append(epoch_selected)
# Out:
# 100%|██████████| 100/100 [00:25<00:00,  3.92it/s]
# 100%|██████████| 200/200 [00:43<00:00,  4.57it/s]
# 100%|██████████| 300/300 [01:07<00:00,  4.46it/s]
# 100%|██████████| 400/400 [01:28<00:00,  4.50it/s]
# 100%|██████████| 500/500 [01:52<00:00,  4.44it/s]

# %%
plt.plot(epoch_value, train_acc_relu_unnormalized)
plt.plot(epoch_value, test_acc_relu_unnormalized)
plt.suptitle('MLP Implementation 1: Plot of Accuracies as Function of Epochs 2 Hidden Layers on Unnormalized Dataset')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
epochs = 500

mlp_relu_unnormalized = MLP(
    # First Layer
    LinearLayer(n_features, K1),
    ReLULayer(),
    # Second Layer
    LinearLayer(K1, K2),
    ReLULayer(),
    # Output Layer
    LinearLayer(K2, n_classes),
    SoftmaxOutputLayer()
)

opt_relu_unnormalized = GradientDescentOptimizer(mlp_relu_unnormalized, lr=1e-6)

mlp_relu_unnormalized.fit(opt_relu_unnormalized, X_train_fashion, y_train_fashion, epochs, batch_size, showplot=True)
# Out:
# 100%|██████████| 500/500 [01:54<00:00,  4.35it/s]

# %%
# Performance on Train dataset
yh_train_unnormalized = mlp_relu_unnormalized.predict(X_train_fashion)
print("Train accuracy:", evaluate_acc(y_train_fashion, yh_train_unnormalized))

# Performance on Test dataset
yh_test_unnormalized = mlp_relu_unnormalized.predict(X_test_fashion)
print("Test accuracy:", evaluate_acc(y_test_fashion, yh_test_unnormalized))
# Out:
# Train accuracy: 0.59765
# Test accuracy: 0.5939

# %% [markdown]
# ## **Implementation 2: Part 4 - MLP with 2 hidden layers, ReLU activation, on unnormalized dataset.**

# %%
# Instantiate the model
model = Model()
# Add layers
model.add(Layer_Dense(X_train_fashion.shape[1], 128))
model.add(Activation_ReLU())
model.add(Layer_Dense(128, 128))
model.add(Activation_ReLU())
model.add(Layer_Dense(128, 10))
model.add(Activation_Softmax())

# Set loss, optimizer and accuracy objects
model.set(
loss=Loss_CategoricalCrossentropy(),
    optimizer=Optimizer_SGD(learning_rate=0.01),
    accuracy=Accuracy_Categorical()
)

# Finalize the model
model.finalize()
# Train the model
model.train(X_train_fashion, y_train_fashion, validation_data=(X_test_fashion, y_test_fashion),
epochs=20, batch_size=128, print_every=100)
model.evaluate(X_test_fashion, y_test_fashion)

plt.figure(figsize=(8, 8))
plt.title("MLP Implementation 2: Plot of Accuracies as Function of Epochs", fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.plot(model.validation_accuracies, 'g-',label='Test Accuracies')
plt.plot(model.training_accuracies, 'r-',label='Training Accuracies')
plt.legend()
# Out:
# epoch: 1
# step: 0, acc: 0.070, loss: 2.347 (data_loss: 2.347, reg_loss: 0.000), lr: 0.01
# step: 100, acc: 0.766, loss: 0.542 (data_loss: 0.542, reg_loss: 0.000), lr: 0.01
# step: 200, acc: 0.766, loss: 0.532 (data_loss: 0.532, reg_loss: 0.000), lr: 0.01
# step: 300, acc: 0.836, loss: 0.432 (data_loss: 0.432, reg_loss: 0.000), lr: 0.01
# step: 400, acc: 0.773, loss: 0.608 (data_loss: 0.608, reg_loss: 0.000), lr: 0.01
# step: 468, acc: 0.854, loss: 0.528 (data_loss: 0.528, reg_loss: 0.000), lr: 0.01
# training, acc: 0.752, loss: 0.666 (data_loss: 0.666, reg_loss: 0.000), lr: 0.01
# validation, acc: 0.817, loss: 0.513
# epoch: 2
# step: 0, acc: 0.844, loss: 0.383 (data_loss: 0.383, reg_loss: 0.000), lr: 0.01
# step: 100, acc: 0.828, loss: 0.421 (data_loss: 0.421, reg_loss: 0.000), lr: 0.01
# step: 200, acc: 0.812, loss: 0.375 (data_loss: 0.375, reg_loss: 0.000), lr: 0.01
# step: 300, acc: 0.852, loss: 0.378 (data_loss: 0.378, reg_loss: 0.000), lr: 0.01
# step: 400, acc: 0.797, loss: 0.499 (data_loss: 0.499, reg_loss: 0.000), lr: 0.01
# step: 468, acc: 0.865, loss: 0.413 (data_loss: 0.413, reg_loss: 0.000), lr: 0.01
# training, acc: 0.841, loss: 0.429 (data_loss: 0.429, reg_loss: 0.000), lr: 0.01
# validation, acc: 0.812, loss: 0.523
# epoch: 3
# step: 0, acc: 0.867, loss: 0.379 (data_loss: 0.379, reg_loss: 0.000), lr: 0.01
# step: 100, acc: 0.859, loss: 0.369 (data_loss: 0.369, reg_loss: 0.000), lr: 0.01
# step: 200, acc: 0.844, loss: 0.353 (data_loss: 0.353, reg_loss: 0.000), lr: 0.01
# step: 300, acc: 0.859, loss: 0.323 (data_loss: 0.323, reg_loss: 0.000), lr: 0.01
# step: 400, acc: 0.820, loss: 0.472 (data_loss: 0.472, reg_loss: 0.000), lr: 0.01
# step: 468, acc: 0.865, loss: 0.353 (data_loss: 0.353, reg_loss: 0.000), lr: 0.01
# training, acc: 0.861, loss: 0.377 (data_loss: 0.377, reg_loss: 0.000), lr: 0.01
# validation, acc: 0.834, loss: 0.476
# epoch: 4
# step: 0, acc: 0.883, loss: 0.321 (data_loss: 0.321, reg_loss: 0.000), lr: 0.01
# step: 100, acc: 0.883, loss: 0.364 (data_loss: 0.364, reg_loss: 0.000), lr: 0.01
# step: 200, acc: 0.883, loss: 0.309 (data_loss: 0.309, reg_loss: 0.000), lr: 0.01
# step: 300, acc: 0.883, loss: 0.317 (data_loss: 0.317, reg_loss: 0.000), lr: 0.01
# step: 400, acc: 0.844, loss: 0.374 (data_loss: 0.374, reg_loss: 0.000), lr: 0.01
# step: 468, acc: 0.885, loss: 0.303 (data_loss: 0.303, reg_loss: 0.000), lr: 0.01
# training, acc: 0.872, loss: 0.346 (data_loss: 0.346, reg_loss: 0.000), lr: 0.01
# validation, acc: 0.860, loss: 0.395
# epoch: 5
# step: 0, acc: 0.898, loss: 0.254 (data_loss: 0.254, reg_loss: 0.000), lr: 0.01
# step: 100, acc: 0.898, loss: 0.299 (data_loss: 0.299, reg_loss: 0.000), lr: 0.01
# step: 200, acc: 0.883, loss: 0.293 (data_loss: 0.293, reg_loss: 0.000), lr: 0.01
# step: 300, acc: 0.906, loss: 0.305 (data_loss: 0.305, reg_loss: 0.000), lr: 0.01
# step: 400, acc: 0.836, loss: 0.375 (data_loss: 0.375, reg_loss: 0.000), lr: 0.01
# step: 468, acc: 0.896, loss: 0.272 (data_loss: 0.272, reg_loss: 0.000), lr: 0.01
# training, acc: 0.880, loss: 0.324 (data_loss: 0.324, reg_loss: 0.000), lr: 0.01
# validation, acc: 0.862, loss: 0.382
# epoch: 6
# step: 0, acc: 0.930, loss: 0.233 (data_loss: 0.233, reg_loss: 0.000), lr: 0.01
# step: 100, acc: 0.898, loss: 0.273 (data_loss: 0.273, reg_loss: 0.000), lr: 0.01
# step: 200, acc: 0.891, loss: 0.281 (data_loss: 0.281, reg_loss: 0.000), lr: 0.01
# step: 300, acc: 0.883, loss: 0.347 (data_loss: 0.347, reg_loss: 0.000), lr: 0.01
# step: 400, acc: 0.867, loss: 0.378 (data_loss: 0.378, reg_loss: 0.000), lr: 0.01
# step: 468, acc: 0.906, loss: 0.260 (data_loss: 0.260, reg_loss: 0.000), lr: 0.01
# training, acc: 0.886, loss: 0.307 (data_loss: 0.307, reg_loss: 0.000), lr: 0.01
# validation, acc: 0.868, loss: 0.367
# epoch: 7
# step: 0, acc: 0.914, loss: 0.218 (data_loss: 0.218, reg_loss: 0.000), lr: 0.01
# step: 100, acc: 0.922, loss: 0.226 (data_loss: 0.226, reg_loss: 0.000), lr: 0.01
# step: 200, acc: 0.883, loss: 0.271 (data_loss: 0.271, reg_loss: 0.000), lr: 0.01
# step: 300, acc: 0.875, loss: 0.323 (data_loss: 0.323, reg_loss: 0.000), lr: 0.01
# step: 400, acc: 0.859, loss: 0.363 (data_loss: 0.363, reg_loss: 0.000), lr: 0.01
# step: 468, acc: 0.896, loss: 0.260 (data_loss: 0.260, reg_loss: 0.000), lr: 0.01
# training, acc: 0.891, loss: 0.293 (data_loss: 0.293, reg_loss: 0.000), lr: 0.01
# validation, acc: 0.871, loss: 0.363
# epoch: 8
# step: 0, acc: 0.922, loss: 0.199 (data_loss: 0.199, reg_loss: 0.000), lr: 0.01
# step: 100, acc: 0.898, loss: 0.217 (data_loss: 0.217, reg_loss: 0.000), lr: 0.01
# step: 200, acc: 0.891, loss: 0.279 (data_loss: 0.279, reg_loss: 0.000), lr: 0.01
# step: 300, acc: 0.875, loss: 0.294 (data_loss: 0.294, reg_loss: 0.000), lr: 0.01
# step: 400, acc: 0.852, loss: 0.343 (data_loss: 0.343, reg_loss: 0.000), lr: 0.01
# step: 468, acc: 0.906, loss: 0.241 (data_loss: 0.241, reg_loss: 0.000), lr: 0.01
# training, acc: 0.895, loss: 0.283 (data_loss: 0.283, reg_loss: 0.000), lr: 0.01
# validation, acc: 0.869, loss: 0.368
# epoch: 9
# step: 0, acc: 0.914, loss: 0.207 (data_loss: 0.207, reg_loss: 0.000), lr: 0.01
# step: 100, acc: 0.914, loss: 0.203 (data_loss: 0.203, reg_loss: 0.000), lr: 0.01
# step: 200, acc: 0.883, loss: 0.277 (data_loss: 0.277, reg_loss: 0.000), lr: 0.01
# step: 300, acc: 0.898, loss: 0.268 (data_loss: 0.268, reg_loss: 0.000), lr: 0.01
# step: 400, acc: 0.898, loss: 0.307 (data_loss: 0.307, reg_loss: 0.000), lr: 0.01
# step: 468, acc: 0.885, loss: 0.254 (data_loss: 0.254, reg_loss: 0.000), lr: 0.01
# training, acc: 0.898, loss: 0.271 (data_loss: 0.271, reg_loss: 0.000), lr: 0.01
# validation, acc: 0.871, loss: 0.364
# epoch: 10
# step: 0, acc: 0.930, loss: 0.201 (data_loss: 0.201, reg_loss: 0.000), lr: 0.01
# step: 100, acc: 0.898, loss: 0.214 (data_loss: 0.214, reg_loss: 0.000), lr: 0.01
# step: 200, acc: 0.883, loss: 0.292 (data_loss: 0.292, reg_loss: 0.000), lr: 0.01
# step: 300, acc: 0.898, loss: 0.260 (data_loss: 0.260, reg_loss: 0.000), lr: 0.01
# step: 400, acc: 0.883, loss: 0.282 (data_loss: 0.282, reg_loss: 0.000), lr: 0.01
# step: 468, acc: 0.875, loss: 0.248 (data_loss: 0.248, reg_loss: 0.000), lr: 0.01
# training, acc: 0.903, loss: 0.260 (data_loss: 0.260, reg_loss: 0.000), lr: 0.01
# validation, acc: 0.866, loss: 0.385
# epoch: 11
# step: 0, acc: 0.922, loss: 0.218 (data_loss: 0.218, reg_loss: 0.000), lr: 0.01
# step: 100, acc: 0.922, loss: 0.203 (data_loss: 0.203, reg_loss: 0.000), lr: 0.01
# step: 200, acc: 0.875, loss: 0.290 (data_loss: 0.290, reg_loss: 0.000), lr: 0.01
# step: 300, acc: 0.914, loss: 0.246 (data_loss: 0.246, reg_loss: 0.000), lr: 0.01
# step: 400, acc: 0.898, loss: 0.280 (data_loss: 0.280, reg_loss: 0.000), lr: 0.01
# step: 468, acc: 0.906, loss: 0.227 (data_loss: 0.227, reg_loss: 0.000), lr: 0.01
# training, acc: 0.903, loss: 0.263 (data_loss: 0.263, reg_loss: 0.000), lr: 0.01
# validation, acc: 0.872, loss: 0.363
# epoch: 12
# step: 0, acc: 0.930, loss: 0.196 (data_loss: 0.196, reg_loss: 0.000), lr: 0.01
# step: 100, acc: 0.914, loss: 0.212 (data_loss: 0.212, reg_loss: 0.000), lr: 0.01
# step: 200, acc: 0.891, loss: 0.268 (data_loss: 0.268, reg_loss: 0.000), lr: 0.01
# step: 300, acc: 0.930, loss: 0.229 (data_loss: 0.229, reg_loss: 0.000), lr: 0.01
# step: 400, acc: 0.914, loss: 0.263 (data_loss: 0.263, reg_loss: 0.000), lr: 0.01
# step: 468, acc: 0.906, loss: 0.215 (data_loss: 0.215, reg_loss: 0.000), lr: 0.01
# training, acc: 0.904, loss: 0.254 (data_loss: 0.254, reg_loss: 0.000), lr: 0.01
# validation, acc: 0.876, loss: 0.358
# epoch: 13
# step: 0, acc: 0.938, loss: 0.190 (data_loss: 0.190, reg_loss: 0.000), lr: 0.01
# step: 100, acc: 0.906, loss: 0.219 (data_loss: 0.219, reg_loss: 0.000), lr: 0.01
# step: 200, acc: 0.883, loss: 0.291 (data_loss: 0.291, reg_loss: 0.000), lr: 0.01
# step: 300, acc: 0.922, loss: 0.208 (data_loss: 0.208, reg_loss: 0.000), lr: 0.01
# step: 400, acc: 0.930, loss: 0.248 (data_loss: 0.248, reg_loss: 0.000), lr: 0.01
# step: 468, acc: 0.927, loss: 0.191 (data_loss: 0.191, reg_loss: 0.000), lr: 0.01
# training, acc: 0.910, loss: 0.239 (data_loss: 0.239, reg_loss: 0.000), lr: 0.01
# validation, acc: 0.877, loss: 0.359
# epoch: 14
# step: 0, acc: 0.938, loss: 0.175 (data_loss: 0.175, reg_loss: 0.000), lr: 0.01
# step: 100, acc: 0.906, loss: 0.227 (data_loss: 0.227, reg_loss: 0.000), lr: 0.01
# step: 200, acc: 0.906, loss: 0.238 (data_loss: 0.238, reg_loss: 0.000), lr: 0.01
# step: 300, acc: 0.922, loss: 0.216 (data_loss: 0.216, reg_loss: 0.000), lr: 0.01
# step: 400, acc: 0.945, loss: 0.215 (data_loss: 0.215, reg_loss: 0.000), lr: 0.01
# step: 468, acc: 0.906, loss: 0.186 (data_loss: 0.186, reg_loss: 0.000), lr: 0.01
# training, acc: 0.913, loss: 0.230 (data_loss: 0.230, reg_loss: 0.000), lr: 0.01
# validation, acc: 0.878, loss: 0.360
# epoch: 15
# step: 0, acc: 0.953, loss: 0.163 (data_loss: 0.163, reg_loss: 0.000), lr: 0.01
# step: 100, acc: 0.906, loss: 0.214 (data_loss: 0.214, reg_loss: 0.000), lr: 0.01
# step: 200, acc: 0.891, loss: 0.258 (data_loss: 0.258, reg_loss: 0.000), lr: 0.01
# step: 300, acc: 0.922, loss: 0.199 (data_loss: 0.199, reg_loss: 0.000), lr: 0.01
# step: 400, acc: 0.922, loss: 0.243 (data_loss: 0.243, reg_loss: 0.000), lr: 0.01
# step: 468, acc: 0.927, loss: 0.185 (data_loss: 0.185, reg_loss: 0.000), lr: 0.01
# training, acc: 0.915, loss: 0.225 (data_loss: 0.225, reg_loss: 0.000), lr: 0.01
# validation, acc: 0.878, loss: 0.360
# epoch: 16
# step: 0, acc: 0.961, loss: 0.136 (data_loss: 0.136, reg_loss: 0.000), lr: 0.01
# step: 100, acc: 0.914, loss: 0.208 (data_loss: 0.208, reg_loss: 0.000), lr: 0.01
# step: 200, acc: 0.906, loss: 0.236 (data_loss: 0.236, reg_loss: 0.000), lr: 0.01
# step: 300, acc: 0.914, loss: 0.198 (data_loss: 0.198, reg_loss: 0.000), lr: 0.01
# step: 400, acc: 0.953, loss: 0.209 (data_loss: 0.209, reg_loss: 0.000), lr: 0.01
# step: 468, acc: 0.927, loss: 0.164 (data_loss: 0.164, reg_loss: 0.000), lr: 0.01
# training, acc: 0.917, loss: 0.218 (data_loss: 0.218, reg_loss: 0.000), lr: 0.01
# validation, acc: 0.872, loss: 0.388
# epoch: 17
# step: 0, acc: 0.953, loss: 0.137 (data_loss: 0.137, reg_loss: 0.000), lr: 0.01
# step: 100, acc: 0.922, loss: 0.221 (data_loss: 0.221, reg_loss: 0.000), lr: 0.01
# step: 200, acc: 0.875, loss: 0.269 (data_loss: 0.269, reg_loss: 0.000), lr: 0.01
# step: 300, acc: 0.930, loss: 0.193 (data_loss: 0.193, reg_loss: 0.000), lr: 0.01
# step: 400, acc: 0.914, loss: 0.260 (data_loss: 0.260, reg_loss: 0.000), lr: 0.01
# step: 468, acc: 0.948, loss: 0.144 (data_loss: 0.144, reg_loss: 0.000), lr: 0.01
# training, acc: 0.921, loss: 0.211 (data_loss: 0.211, reg_loss: 0.000), lr: 0.01
# validation, acc: 0.875, loss: 0.383
# epoch: 18
# step: 0, acc: 0.961, loss: 0.139 (data_loss: 0.139, reg_loss: 0.000), lr: 0.01
# step: 100, acc: 0.930, loss: 0.208 (data_loss: 0.208, reg_loss: 0.000), lr: 0.01
# step: 200, acc: 0.906, loss: 0.247 (data_loss: 0.247, reg_loss: 0.000), lr: 0.01
# step: 300, acc: 0.930, loss: 0.203 (data_loss: 0.203, reg_loss: 0.000), lr: 0.01
# step: 400, acc: 0.922, loss: 0.221 (data_loss: 0.221, reg_loss: 0.000), lr: 0.01
# step: 468, acc: 0.938, loss: 0.155 (data_loss: 0.155, reg_loss: 0.000), lr: 0.01
# training, acc: 0.919, loss: 0.215 (data_loss: 0.215, reg_loss: 0.000), lr: 0.01
# validation, acc: 0.876, loss: 0.380
# epoch: 19
# step: 0, acc: 0.953, loss: 0.131 (data_loss: 0.131, reg_loss: 0.000), lr: 0.01
# step: 100, acc: 0.930, loss: 0.230 (data_loss: 0.230, reg_loss: 0.000), lr: 0.01
# step: 200, acc: 0.898, loss: 0.207 (data_loss: 0.207, reg_loss: 0.000), lr: 0.01
# step: 300, acc: 0.922, loss: 0.196 (data_loss: 0.196, reg_loss: 0.000), lr: 0.01
# step: 400, acc: 0.922, loss: 0.251 (data_loss: 0.251, reg_loss: 0.000), lr: 0.01
# step: 468, acc: 0.938, loss: 0.168 (data_loss: 0.168, reg_loss: 0.000), lr: 0.01
# training, acc: 0.922, loss: 0.206 (data_loss: 0.206, reg_loss: 0.000), lr: 0.01
# validation, acc: 0.878, loss: 0.377
# epoch: 20
# step: 0, acc: 0.969, loss: 0.114 (data_loss: 0.114, reg_loss: 0.000), lr: 0.01
# step: 100, acc: 0.922, loss: 0.200 (data_loss: 0.200, reg_loss: 0.000), lr: 0.01
# step: 200, acc: 0.883, loss: 0.281 (data_loss: 0.281, reg_loss: 0.000), lr: 0.01
# step: 300, acc: 0.930, loss: 0.183 (data_loss: 0.183, reg_loss: 0.000), lr: 0.01
# step: 400, acc: 0.891, loss: 0.251 (data_loss: 0.251, reg_loss: 0.000), lr: 0.01
# step: 468, acc: 0.948, loss: 0.165 (data_loss: 0.165, reg_loss: 0.000), lr: 0.01
# training, acc: 0.923, loss: 0.201 (data_loss: 0.201, reg_loss: 0.000), lr: 0.01
# validation, acc: 0.871, loss: 0.398
# validation, acc: 0.871, loss: 0.398

# %% [markdown]
# ## **Part 5 - CNN with 2 convolutional, 2 fully connected layers, and ReLU activations.**

# %%
# Normalizing and reshaping the data
# First, we normalize the image pixel values from [0, 255] to [-0.5, 0.5]. 
# Second, we reshape the images from (28, 28) to (28, 28, 1) to add the third dimension required by Keras

# Normalize the images
X_train_fashion_normalized_cnn = (X_train_fashion_original / 255) - 0.5
X_test_fashion_normalized_cnn = (X_test_fashion_original / 255) - 0.5

print(X_train_fashion_normalized_cnn.shape) # (60000, 28, 28)
print(X_test_fashion_normalized_cnn.shape)  # (10000, 28, 28)

# Reshape the images.
X_train_fashion_normalized_cnn = np.expand_dims(X_train_fashion_normalized_cnn, axis=3)
X_test_fashion_normalized_cnn = np.expand_dims(X_test_fashion_normalized_cnn, axis=3)

print(X_train_fashion_normalized_cnn.shape) # (60000, 28, 28, 1)
print(X_test_fashion_normalized_cnn.shape)  # (10000, 28, 28, 1)

y_train_fashion_cnn = keras.utils.np_utils.to_categorical(y_train_fashion_original)
y_test_fashion_cnn = keras.utils.np_utils.to_categorical(y_test_fashion_original)
print(y_train_fashion_cnn.shape) # (60000, 10)
print(y_test_fashion_cnn.shape)  # (10000, 10)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)
# (60000, 10)
# (10000, 10)

# %% [markdown]
# ### CNN Experiment

# %%
num_filters = 8
filter_size = 3
pool_size   = 2
num_classes = len(set(y_test_fashion_original))
input_shape = (X_train_fashion_normalized_cnn.shape[1:]) # (28, 28, 1)
batch_size  = 64
strides     = 1
padding     = 'valid' # valid: no padding, same: for zeros evenly right/left and up/down
                      # when padding="same" and strides=1, the output has the same size as the input
optimizer = keras.optimizers.SGD(lr=0.1)
cnn_model = Sequential()
cnn_model.add(Conv2D(filters = 4 * num_filters, # 8 filters 
                 kernel_size = filter_size,
                 strides     = strides,
                 input_shape = input_shape,
                 padding     = padding,
                 activation  = 'relu')) # Sequential model needs the input shape
# model.add(MaxPooling2D(pool_size=pool_size)) # Keras automatically infers the shapes of inputs of later layers
cnn_model.add(Conv2D(filters = 8 * num_filters, kernel_size = (filter_size, filter_size)))
# model.add(MaxPooling2D(pool_size=(pool_size, pool_size)))
cnn_model.add(Dropout(0.25)) # randomly sets input units to 0 with a frequency of rate at each step during training time, to avoid overfitting
cnn_model.add(Flatten()) # Flatten serves as a connection between the convolution and dense layers
cnn_model.add(Dense(128, activation='relu')) # fully connected layer
cnn_model.add(Dense(num_classes, activation='softmax')) # output layer

# %%
# Summary of the model 
cnn_model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 26, 26, 32)        320
#
#  conv2d_17 (Conv2D)          (None, 24, 24, 64)        18496
#
#  dropout_8 (Dropout)         (None, 24, 24, 64)        0
#
#  flatten_8 (Flatten)         (None, 36864)             0
#
#  dense_16 (Dense)            (None, 128)               4718720
#
#  dense_17 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 4,738,826
# Trainable params: 4,738,826
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Plot model 
keras.utils.plot_model(cnn_model, "my_mnist_model.png", show_shapes=True)

# %%
# Compile the model
cnn_model.compile(
  optimizer=optimizer,                              # Optimizer: SGD for gradient descent-based: https://keras.io/api/optimizers/
  loss='categorical_crossentropy',    # Loss function: Categorical for 10 classes: https://keras.io/api/losses/
  metrics=['accuracy'],               # accuracy metric, can choose from keras metrics: https://keras.io/api/metrics/
)

# %%
# Train the mdoel
# https://keras.io/api/callbacks/

epochs = 20

# Saving the model during training to be used later
checkpoint = ModelCheckpoint("mnist_best_model.hdf5",  # saving the best model
                            monitor='val_loss', verbose=1,
                            save_weights_only = False, # if True, then only the model's weights will be saved (model.save_weights(filepath)), else the full model is saved (model.save(filepath)). 
                            save_best_only=True,       # only saves when the model is considered the "best" and the latest best model according to the quantity monitored will not be overwritten.
                            mode='auto',               # the decision to overwrite the current save file is made based on either the maximization or the minimization of the monitored quantity. For val_acc, this should be max, for val_loss this should be min,
                            save_freq = 'epoch')       # When using 'epoch', the callback saves the model after each epoch. When using integer, the callback saves the model at end of this many batches.

# %%
# Fitting the model
history = cnn_model.fit(
  X_train_fashion_normalized_cnn,
  y_train_fashion_cnn, 
  epochs=epochs,                # number of training epochs
  batch_size=batch_size,
  verbose = 1,
  validation_data=(X_test_fashion_normalized_cnn, y_test_fashion_cnn), # validation data
  callbacks=[checkpoint]      # callback to save the model during trainings 
)
# Out:
# Epoch 1/20
# 938/938 [==============================] - ETA: 0s - loss: 0.4612 - accuracy: 0.8312
# Epoch 1: val_loss improved from inf to 0.37872, saving model to mnist_best_model.hdf5
# 938/938 [==============================] - 186s 198ms/step - loss: 0.4612 - accuracy: 0.8312 - val_loss: 0.3787 - val_accuracy: 0.8587
# Epoch 2/20
# 938/938 [==============================] - ETA: 0s - loss: 0.3008 - accuracy: 0.8895
# Epoch 2: val_loss improved from 0.37872 to 0.33805, saving model to mnist_best_model.hdf5
# 938/938 [==============================] - 179s 190ms/step - loss: 0.3008 - accuracy: 0.8895 - val_loss: 0.3381 - val_accuracy: 0.8757
# Epoch 3/20
# 938/938 [==============================] - ETA: 0s - loss: 0.2540 - accuracy: 0.9062
# Epoch 3: val_loss improved from 0.33805 to 0.30352, saving model to mnist_best_model.hdf5
# 938/938 [==============================] - 183s 195ms/step - loss: 0.2540 - accuracy: 0.9062 - val_loss: 0.3035 - val_accuracy: 0.8865
# Epoch 4/20
# 938/938 [==============================] - ETA: 0s - loss: 0.2228 - accuracy: 0.9165
# Epoch 4: val_loss improved from 0.30352 to 0.28389, saving model to mnist_best_model.hdf5
# 938/938 [==============================] - 182s 194ms/step - loss: 0.2228 - accuracy: 0.9165 - val_loss: 0.2839 - val_accuracy: 0.8983
# Epoch 5/20
# 938/938 [==============================] - ETA: 0s - loss: 0.1961 - accuracy: 0.9272
# Epoch 5: val_loss did not improve from 0.28389
# 938/938 [==============================] - 184s 196ms/step - loss: 0.1961 - accuracy: 0.9272 - val_loss: 0.2907 - val_accuracy: 0.8952
# Epoch 6/20
# 938/938 [==============================] - ETA: 0s - loss: 0.1730 - accuracy: 0.9351
# Epoch 6: val_loss improved from 0.28389 to 0.28023, saving model to mnist_best_model.hdf5
# 938/938 [==============================] - 183s 195ms/step - loss: 0.1730 - accuracy: 0.9351 - val_loss: 0.2802 - val_accuracy: 0.9015
# Epoch 7/20
# 938/938 [==============================] - ETA: 0s - loss: 0.1507 - accuracy: 0.9433
# Epoch 7: val_loss did not improve from 0.28023
# 938/938 [==============================] - 181s 193ms/step - loss: 0.1507 - accuracy: 0.9433 - val_loss: 0.2948 - val_accuracy: 0.9028
# Epoch 8/20
# 938/938 [==============================] - ETA: 0s - loss: 0.1321 - accuracy: 0.9506
# Epoch 8: val_loss did not improve from 0.28023
# 938/938 [==============================] - 183s 195ms/step - loss: 0.1321 - accuracy: 0.9506 - val_loss: 0.3008 - val_accuracy: 0.9036
# Epoch 9/20
# 938/938 [==============================] - ETA: 0s - loss: 0.1126 - accuracy: 0.9578
# Epoch 9: val_loss did not improve from 0.28023
# 938/938 [==============================] - 181s 193ms/step - loss: 0.1126 - accuracy: 0.9578 - val_loss: 0.3105 - val_accuracy: 0.9058
# Epoch 10/20
# 938/938 [==============================] - ETA: 0s - loss: 0.0965 - accuracy: 0.9648
# Epoch 10: val_loss did not improve from 0.28023
# 938/938 [==============================] - 183s 195ms/step - loss: 0.0965 - accuracy: 0.9648 - val_loss: 0.3690 - val_accuracy: 0.8917
# Epoch 11/20
# 938/938 [==============================] - ETA: 0s - loss: 0.0837 - accuracy: 0.9690
# Epoch 11: val_loss did not improve from 0.28023
# 938/938 [==============================] - 184s 196ms/step - loss: 0.0837 - accuracy: 0.9690 - val_loss: 0.3309 - val_accuracy: 0.9071
# Epoch 12/20
# 938/938 [==============================] - ETA: 0s - loss: 0.0714 - accuracy: 0.9732
# Epoch 12: val_loss did not improve from 0.28023
# 938/938 [==============================] - 183s 195ms/step - loss: 0.0714 - accuracy: 0.9732 - val_loss: 0.3591 - val_accuracy: 0.9065
# Epoch 13/20
# 938/938 [==============================] - ETA: 0s - loss: 0.0592 - accuracy: 0.9787
# Epoch 13: val_loss did not improve from 0.28023
# 938/938 [==============================] - 185s 198ms/step - loss: 0.0592 - accuracy: 0.9787 - val_loss: 0.4269 - val_accuracy: 0.9002
# Epoch 14/20
# 938/938 [==============================] - ETA: 0s - loss: 0.0517 - accuracy: 0.9811
# Epoch 14: val_loss did not improve from 0.28023
# 938/938 [==============================] - 186s 198ms/step - loss: 0.0517 - accuracy: 0.9811 - val_loss: 0.4432 - val_accuracy: 0.9034
# Epoch 15/20
# 938/938 [==============================] - ETA: 0s - loss: 0.0429 - accuracy: 0.9843
# Epoch 15: val_loss did not improve from 0.28023
# 938/938 [==============================] - 183s 195ms/step - loss: 0.0429 - accuracy: 0.9843 - val_loss: 0.4384 - val_accuracy: 0.9034
# Epoch 16/20
# 938/938 [==============================] - ETA: 0s - loss: 0.0376 - accuracy: 0.9863
# Epoch 16: val_loss did not improve from 0.28023
# 938/938 [==============================] - 191s 204ms/step - loss: 0.0376 - accuracy: 0.9863 - val_loss: 0.4872 - val_accuracy: 0.9015
# Epoch 17/20
# 938/938 [==============================] - ETA: 0s - loss: 0.0314 - accuracy: 0.9887
# Epoch 17: val_loss did not improve from 0.28023
# 938/938 [==============================] - 235s 250ms/step - loss: 0.0314 - accuracy: 0.9887 - val_loss: 0.4981 - val_accuracy: 0.9050
# Epoch 18/20
# 938/938 [==============================] - ETA: 0s - loss: 0.0268 - accuracy: 0.9904
# Epoch 18: val_loss did not improve from 0.28023
# 938/938 [==============================] - 185s 197ms/step - loss: 0.0268 - accuracy: 0.9904 - val_loss: 0.5390 - val_accuracy: 0.9054
# Epoch 19/20
# 938/938 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9917
# Epoch 19: val_loss did not improve from 0.28023
# 938/938 [==============================] - 186s 198ms/step - loss: 0.0239 - accuracy: 0.9917 - val_loss: 0.5429 - val_accuracy: 0.9006
# Epoch 20/20
# 938/938 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 0.9907
# Epoch 20: val_loss did not improve from 0.28023
# 938/938 [==============================] - 186s 198ms/step - loss: 0.0261 - accuracy: 0.9907 - val_loss: 0.6799 - val_accuracy: 0.8865

# %%
# plot training history
plt.figure(figsize=(10,10))

# History for accuracy
plt.subplot(211)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('cnn_model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

# %%
plt.figure(figsize=(10, 10))

# History for loss
plt.subplot(212)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Define confusion matrix
def calc_error(predictions, labels):
    """Return the error rate and confusions."""
    correct = np.sum(predictions == labels)
    total = predictions.shape[0]

    error = 100.0 - (100 * float(correct) / float(total))

    confusions = np.zeros([10, 10], np.float32)
    bundled = zip(predictions, labels)
    for predicted, actual in bundled:
        confusions[predicted, actual] += 1
    
    return error, confusions

# %%
# Model predictions and confusion matrix
test_predictions          = np.argmax(cnn_model.predict(X_test_fashion_normalized_cnn),1)
test_error, test_conf_mat = calc_error(test_predictions, np.argmax(y_test_fashion_cnn,1))
print('Test error: %.1f%%' % test_error)

plt.figure(figsize=(6, 6))
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.grid(False)
plt.xticks(np.arange(num_classes))
plt.yticks(np.arange(num_classes))
plt.imshow(test_conf_mat, cmap=plt.cm.jet, interpolation='nearest');

for i, cas in enumerate(test_conf_mat):
    for j, count in enumerate(cas):
        if count > 0:
            xoff = .07 * len(str(count))
            plt.text(j-xoff, i+.2, int(count), fontsize=13, color='white')
# Out:
# 313/313 [==============================] - 10s 32ms/step
# Test error: 11.3%

# %%
accuracy = np.sum(y_test_fashion_original == test_predictions) / len(y_test_fashion_original)
accuracy
# Out:
# 0.8865

# %% [markdown]
# ## **Part 6 -  Best-performing MLP architecture.**

# %% [markdown]
# ### MLP Implementation 2

# %%
# Instantiate the model
model = Model()
# Add layers
model.add(Layer_Dense(X_train_fashion_normalized.shape[1], 512))
model.add(Activation_ReLU())
model.add(Layer_Dense(512, 512))
model.add(Activation_ReLU())
model.add(Layer_Dense(512, 10))
model.add(Activation_Softmax())

# Set loss, optimizer and accuracy objects
model.set(
loss=Loss_CategoricalCrossentropy(),
optimizer=Optimizer_SGD(learning_rate=0.1),
accuracy=Accuracy_Categorical()
)

# Finalize the model
model.finalize()
# Train the model
model.train(X_train_fashion_normalized, y_train_fashion, validation_data=(X_test_fashion_normalized, y_test_fashion),
epochs=20, batch_size=60, print_every=100)
model.evaluate(X_test_fashion_normalized, y_test_fashion)

plt.figure(figsize=(8, 8))
plt.title("MLP Implementation 2: Plot of Accuracies as Function of Epochs", fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.plot(model.validation_accuracies, 'g-',label='Test Accuracies')
plt.plot(model.training_accuracies, 'r-',label='Training Accuracies')
plt.legend()
# Out:
# epoch: 1
# step: 0, acc: 0.100, loss: 2.303 (data_loss: 2.303, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.467, loss: 1.320 (data_loss: 1.320, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.550, loss: 0.962 (data_loss: 0.962, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.617, loss: 1.110 (data_loss: 1.110, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.517, loss: 1.203 (data_loss: 1.203, reg_loss: 0.000), lr: 0.1
# step: 500, acc: 0.817, loss: 0.499 (data_loss: 0.499, reg_loss: 0.000), lr: 0.1
# step: 600, acc: 0.700, loss: 0.675 (data_loss: 0.675, reg_loss: 0.000), lr: 0.1
# step: 700, acc: 0.800, loss: 0.626 (data_loss: 0.626, reg_loss: 0.000), lr: 0.1
# step: 800, acc: 0.850, loss: 0.495 (data_loss: 0.495, reg_loss: 0.000), lr: 0.1
# step: 900, acc: 0.767, loss: 0.500 (data_loss: 0.500, reg_loss: 0.000), lr: 0.1
# step: 999, acc: 0.767, loss: 0.657 (data_loss: 0.657, reg_loss: 0.000), lr: 0.1
# training, acc: 0.693, loss: 0.840 (data_loss: 0.840, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.781, loss: 0.615
# epoch: 2
# step: 0, acc: 0.850, loss: 0.492 (data_loss: 0.492, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.867, loss: 0.410 (data_loss: 0.410, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.883, loss: 0.325 (data_loss: 0.325, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.783, loss: 0.623 (data_loss: 0.623, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.717, loss: 0.730 (data_loss: 0.730, reg_loss: 0.000), lr: 0.1
# step: 500, acc: 0.850, loss: 0.402 (data_loss: 0.402, reg_loss: 0.000), lr: 0.1
# step: 600, acc: 0.750, loss: 0.595 (data_loss: 0.595, reg_loss: 0.000), lr: 0.1
# step: 700, acc: 0.833, loss: 0.532 (data_loss: 0.532, reg_loss: 0.000), lr: 0.1
# step: 800, acc: 0.833, loss: 0.428 (data_loss: 0.428, reg_loss: 0.000), lr: 0.1
# step: 900, acc: 0.833, loss: 0.377 (data_loss: 0.377, reg_loss: 0.000), lr: 0.1
# step: 999, acc: 0.850, loss: 0.476 (data_loss: 0.476, reg_loss: 0.000), lr: 0.1
# training, acc: 0.834, loss: 0.460 (data_loss: 0.460, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.834, loss: 0.462
# epoch: 3
# step: 0, acc: 0.900, loss: 0.312 (data_loss: 0.312, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.867, loss: 0.324 (data_loss: 0.324, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.883, loss: 0.276 (data_loss: 0.276, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.800, loss: 0.549 (data_loss: 0.549, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.783, loss: 0.614 (data_loss: 0.614, reg_loss: 0.000), lr: 0.1
# step: 500, acc: 0.883, loss: 0.337 (data_loss: 0.337, reg_loss: 0.000), lr: 0.1
# step: 600, acc: 0.767, loss: 0.544 (data_loss: 0.544, reg_loss: 0.000), lr: 0.1
# step: 700, acc: 0.883, loss: 0.507 (data_loss: 0.507, reg_loss: 0.000), lr: 0.1
# step: 800, acc: 0.850, loss: 0.392 (data_loss: 0.392, reg_loss: 0.000), lr: 0.1
# step: 900, acc: 0.900, loss: 0.321 (data_loss: 0.321, reg_loss: 0.000), lr: 0.1
# step: 999, acc: 0.867, loss: 0.394 (data_loss: 0.394, reg_loss: 0.000), lr: 0.1
# training, acc: 0.854, loss: 0.397 (data_loss: 0.397, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.849, loss: 0.418
# epoch: 4
# step: 0, acc: 0.933, loss: 0.249 (data_loss: 0.249, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.883, loss: 0.290 (data_loss: 0.290, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.900, loss: 0.248 (data_loss: 0.248, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.833, loss: 0.509 (data_loss: 0.509, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.800, loss: 0.572 (data_loss: 0.572, reg_loss: 0.000), lr: 0.1
# step: 500, acc: 0.900, loss: 0.276 (data_loss: 0.276, reg_loss: 0.000), lr: 0.1
# step: 600, acc: 0.783, loss: 0.494 (data_loss: 0.494, reg_loss: 0.000), lr: 0.1
# step: 700, acc: 0.867, loss: 0.498 (data_loss: 0.498, reg_loss: 0.000), lr: 0.1
# step: 800, acc: 0.850, loss: 0.373 (data_loss: 0.373, reg_loss: 0.000), lr: 0.1
# step: 900, acc: 0.933, loss: 0.299 (data_loss: 0.299, reg_loss: 0.000), lr: 0.1
# step: 999, acc: 0.883, loss: 0.346 (data_loss: 0.346, reg_loss: 0.000), lr: 0.1
# training, acc: 0.866, loss: 0.362 (data_loss: 0.362, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.858, loss: 0.399
# epoch: 5
# step: 0, acc: 0.950, loss: 0.216 (data_loss: 0.216, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.900, loss: 0.266 (data_loss: 0.266, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.900, loss: 0.236 (data_loss: 0.236, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.850, loss: 0.466 (data_loss: 0.466, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.817, loss: 0.532 (data_loss: 0.532, reg_loss: 0.000), lr: 0.1
# step: 500, acc: 0.917, loss: 0.237 (data_loss: 0.237, reg_loss: 0.000), lr: 0.1
# step: 600, acc: 0.800, loss: 0.460 (data_loss: 0.460, reg_loss: 0.000), lr: 0.1
# step: 700, acc: 0.867, loss: 0.487 (data_loss: 0.487, reg_loss: 0.000), lr: 0.1
# step: 800, acc: 0.867, loss: 0.372 (data_loss: 0.372, reg_loss: 0.000), lr: 0.1
# step: 900, acc: 0.933, loss: 0.278 (data_loss: 0.278, reg_loss: 0.000), lr: 0.1
# step: 999, acc: 0.883, loss: 0.330 (data_loss: 0.330, reg_loss: 0.000), lr: 0.1
# training, acc: 0.875, loss: 0.338 (data_loss: 0.338, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.863, loss: 0.385
# epoch: 6
# step: 0, acc: 0.933, loss: 0.204 (data_loss: 0.204, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.917, loss: 0.247 (data_loss: 0.247, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.917, loss: 0.227 (data_loss: 0.227, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.850, loss: 0.431 (data_loss: 0.431, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.817, loss: 0.504 (data_loss: 0.504, reg_loss: 0.000), lr: 0.1
# step: 500, acc: 0.933, loss: 0.203 (data_loss: 0.203, reg_loss: 0.000), lr: 0.1
# step: 600, acc: 0.833, loss: 0.443 (data_loss: 0.443, reg_loss: 0.000), lr: 0.1
# step: 700, acc: 0.867, loss: 0.484 (data_loss: 0.484, reg_loss: 0.000), lr: 0.1
# step: 800, acc: 0.883, loss: 0.365 (data_loss: 0.365, reg_loss: 0.000), lr: 0.1
# step: 900, acc: 0.933, loss: 0.273 (data_loss: 0.273, reg_loss: 0.000), lr: 0.1
# step: 999, acc: 0.883, loss: 0.316 (data_loss: 0.316, reg_loss: 0.000), lr: 0.1
# training, acc: 0.882, loss: 0.319 (data_loss: 0.319, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.866, loss: 0.376
# epoch: 7
# step: 0, acc: 0.933, loss: 0.205 (data_loss: 0.205, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.917, loss: 0.234 (data_loss: 0.234, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.917, loss: 0.220 (data_loss: 0.220, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.867, loss: 0.392 (data_loss: 0.392, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.833, loss: 0.471 (data_loss: 0.471, reg_loss: 0.000), lr: 0.1
# step: 500, acc: 0.950, loss: 0.184 (data_loss: 0.184, reg_loss: 0.000), lr: 0.1
# step: 600, acc: 0.850, loss: 0.414 (data_loss: 0.414, reg_loss: 0.000), lr: 0.1
# step: 700, acc: 0.867, loss: 0.482 (data_loss: 0.482, reg_loss: 0.000), lr: 0.1
# step: 800, acc: 0.883, loss: 0.361 (data_loss: 0.361, reg_loss: 0.000), lr: 0.1
# step: 900, acc: 0.933, loss: 0.269 (data_loss: 0.269, reg_loss: 0.000), lr: 0.1
# step: 999, acc: 0.883, loss: 0.308 (data_loss: 0.308, reg_loss: 0.000), lr: 0.1
# training, acc: 0.887, loss: 0.303 (data_loss: 0.303, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.868, loss: 0.369
# epoch: 8
# step: 0, acc: 0.917, loss: 0.202 (data_loss: 0.202, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.933, loss: 0.216 (data_loss: 0.216, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.917, loss: 0.219 (data_loss: 0.219, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.867, loss: 0.358 (data_loss: 0.358, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.833, loss: 0.448 (data_loss: 0.448, reg_loss: 0.000), lr: 0.1
# step: 500, acc: 0.967, loss: 0.169 (data_loss: 0.169, reg_loss: 0.000), lr: 0.1
# step: 600, acc: 0.850, loss: 0.397 (data_loss: 0.397, reg_loss: 0.000), lr: 0.1
# step: 700, acc: 0.883, loss: 0.471 (data_loss: 0.471, reg_loss: 0.000), lr: 0.1
# step: 800, acc: 0.883, loss: 0.349 (data_loss: 0.349, reg_loss: 0.000), lr: 0.1
# step: 900, acc: 0.917, loss: 0.254 (data_loss: 0.254, reg_loss: 0.000), lr: 0.1
# step: 999, acc: 0.883, loss: 0.285 (data_loss: 0.285, reg_loss: 0.000), lr: 0.1
# training, acc: 0.892, loss: 0.290 (data_loss: 0.290, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.872, loss: 0.361
# epoch: 9
# step: 0, acc: 0.917, loss: 0.196 (data_loss: 0.196, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.917, loss: 0.202 (data_loss: 0.202, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.950, loss: 0.214 (data_loss: 0.214, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.883, loss: 0.335 (data_loss: 0.335, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.817, loss: 0.423 (data_loss: 0.423, reg_loss: 0.000), lr: 0.1
# step: 500, acc: 0.967, loss: 0.154 (data_loss: 0.154, reg_loss: 0.000), lr: 0.1
# step: 600, acc: 0.850, loss: 0.384 (data_loss: 0.384, reg_loss: 0.000), lr: 0.1
# step: 700, acc: 0.883, loss: 0.473 (data_loss: 0.473, reg_loss: 0.000), lr: 0.1
# step: 800, acc: 0.883, loss: 0.347 (data_loss: 0.347, reg_loss: 0.000), lr: 0.1
# step: 900, acc: 0.900, loss: 0.243 (data_loss: 0.243, reg_loss: 0.000), lr: 0.1
# step: 999, acc: 0.883, loss: 0.284 (data_loss: 0.284, reg_loss: 0.000), lr: 0.1
# training, acc: 0.897, loss: 0.277 (data_loss: 0.277, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.873, loss: 0.355
# epoch: 10
# step: 0, acc: 0.917, loss: 0.188 (data_loss: 0.188, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.900, loss: 0.193 (data_loss: 0.193, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.950, loss: 0.208 (data_loss: 0.208, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.883, loss: 0.306 (data_loss: 0.306, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.833, loss: 0.415 (data_loss: 0.415, reg_loss: 0.000), lr: 0.1
# step: 500, acc: 0.950, loss: 0.147 (data_loss: 0.147, reg_loss: 0.000), lr: 0.1
# step: 600, acc: 0.850, loss: 0.361 (data_loss: 0.361, reg_loss: 0.000), lr: 0.1
# step: 700, acc: 0.883, loss: 0.468 (data_loss: 0.468, reg_loss: 0.000), lr: 0.1
# step: 800, acc: 0.883, loss: 0.335 (data_loss: 0.335, reg_loss: 0.000), lr: 0.1
# step: 900, acc: 0.900, loss: 0.235 (data_loss: 0.235, reg_loss: 0.000), lr: 0.1
# step: 999, acc: 0.883, loss: 0.270 (data_loss: 0.270, reg_loss: 0.000), lr: 0.1
# training, acc: 0.901, loss: 0.265 (data_loss: 0.265, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.876, loss: 0.349
# epoch: 11
# step: 0, acc: 0.917, loss: 0.195 (data_loss: 0.195, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.900, loss: 0.182 (data_loss: 0.182, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.917, loss: 0.209 (data_loss: 0.209, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.900, loss: 0.285 (data_loss: 0.285, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.833, loss: 0.380 (data_loss: 0.380, reg_loss: 0.000), lr: 0.1
# step: 500, acc: 0.967, loss: 0.132 (data_loss: 0.132, reg_loss: 0.000), lr: 0.1
# step: 600, acc: 0.833, loss: 0.358 (data_loss: 0.358, reg_loss: 0.000), lr: 0.1
# step: 700, acc: 0.883, loss: 0.487 (data_loss: 0.487, reg_loss: 0.000), lr: 0.1
# step: 800, acc: 0.883, loss: 0.325 (data_loss: 0.325, reg_loss: 0.000), lr: 0.1
# step: 900, acc: 0.917, loss: 0.233 (data_loss: 0.233, reg_loss: 0.000), lr: 0.1
# step: 999, acc: 0.900, loss: 0.275 (data_loss: 0.275, reg_loss: 0.000), lr: 0.1
# training, acc: 0.905, loss: 0.255 (data_loss: 0.255, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.877, loss: 0.346
# epoch: 12
# step: 0, acc: 0.917, loss: 0.185 (data_loss: 0.185, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.933, loss: 0.172 (data_loss: 0.172, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.983, loss: 0.196 (data_loss: 0.196, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.917, loss: 0.281 (data_loss: 0.281, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.850, loss: 0.352 (data_loss: 0.352, reg_loss: 0.000), lr: 0.1
# step: 500, acc: 0.967, loss: 0.126 (data_loss: 0.126, reg_loss: 0.000), lr: 0.1
# step: 600, acc: 0.867, loss: 0.350 (data_loss: 0.350, reg_loss: 0.000), lr: 0.1
# step: 700, acc: 0.883, loss: 0.480 (data_loss: 0.480, reg_loss: 0.000), lr: 0.1
# step: 800, acc: 0.883, loss: 0.314 (data_loss: 0.314, reg_loss: 0.000), lr: 0.1
# step: 900, acc: 0.917, loss: 0.229 (data_loss: 0.229, reg_loss: 0.000), lr: 0.1
# step: 999, acc: 0.917, loss: 0.248 (data_loss: 0.248, reg_loss: 0.000), lr: 0.1
# training, acc: 0.909, loss: 0.245 (data_loss: 0.245, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.880, loss: 0.342
# epoch: 13
# step: 0, acc: 0.917, loss: 0.181 (data_loss: 0.181, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.900, loss: 0.174 (data_loss: 0.174, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.950, loss: 0.194 (data_loss: 0.194, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.900, loss: 0.251 (data_loss: 0.251, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.850, loss: 0.347 (data_loss: 0.347, reg_loss: 0.000), lr: 0.1
# step: 500, acc: 0.967, loss: 0.113 (data_loss: 0.113, reg_loss: 0.000), lr: 0.1
# step: 600, acc: 0.867, loss: 0.332 (data_loss: 0.332, reg_loss: 0.000), lr: 0.1
# step: 700, acc: 0.883, loss: 0.474 (data_loss: 0.474, reg_loss: 0.000), lr: 0.1
# step: 800, acc: 0.883, loss: 0.311 (data_loss: 0.311, reg_loss: 0.000), lr: 0.1
# step: 900, acc: 0.917, loss: 0.227 (data_loss: 0.227, reg_loss: 0.000), lr: 0.1
# step: 999, acc: 0.900, loss: 0.265 (data_loss: 0.265, reg_loss: 0.000), lr: 0.1
# training, acc: 0.913, loss: 0.235 (data_loss: 0.235, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.879, loss: 0.347
# epoch: 14
# step: 0, acc: 0.933, loss: 0.166 (data_loss: 0.166, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.933, loss: 0.168 (data_loss: 0.168, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.950, loss: 0.181 (data_loss: 0.181, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.883, loss: 0.251 (data_loss: 0.251, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.850, loss: 0.323 (data_loss: 0.323, reg_loss: 0.000), lr: 0.1
# step: 500, acc: 0.983, loss: 0.106 (data_loss: 0.106, reg_loss: 0.000), lr: 0.1
# step: 600, acc: 0.867, loss: 0.316 (data_loss: 0.316, reg_loss: 0.000), lr: 0.1
# step: 700, acc: 0.883, loss: 0.469 (data_loss: 0.469, reg_loss: 0.000), lr: 0.1
# step: 800, acc: 0.883, loss: 0.291 (data_loss: 0.291, reg_loss: 0.000), lr: 0.1
# step: 900, acc: 0.900, loss: 0.226 (data_loss: 0.226, reg_loss: 0.000), lr: 0.1
# step: 999, acc: 0.900, loss: 0.228 (data_loss: 0.228, reg_loss: 0.000), lr: 0.1
# training, acc: 0.916, loss: 0.227 (data_loss: 0.227, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.879, loss: 0.347
# epoch: 15
# step: 0, acc: 0.933, loss: 0.166 (data_loss: 0.166, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.933, loss: 0.165 (data_loss: 0.165, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.983, loss: 0.183 (data_loss: 0.183, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.900, loss: 0.234 (data_loss: 0.234, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.850, loss: 0.293 (data_loss: 0.293, reg_loss: 0.000), lr: 0.1
# step: 500, acc: 0.967, loss: 0.098 (data_loss: 0.098, reg_loss: 0.000), lr: 0.1
# step: 600, acc: 0.900, loss: 0.300 (data_loss: 0.300, reg_loss: 0.000), lr: 0.1
# step: 700, acc: 0.867, loss: 0.478 (data_loss: 0.478, reg_loss: 0.000), lr: 0.1
# step: 800, acc: 0.883, loss: 0.279 (data_loss: 0.279, reg_loss: 0.000), lr: 0.1
# step: 900, acc: 0.917, loss: 0.197 (data_loss: 0.197, reg_loss: 0.000), lr: 0.1
# step: 999, acc: 0.900, loss: 0.218 (data_loss: 0.218, reg_loss: 0.000), lr: 0.1
# training, acc: 0.919, loss: 0.218 (data_loss: 0.218, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.876, loss: 0.360
# epoch: 16
# step: 0, acc: 0.933, loss: 0.172 (data_loss: 0.172, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.950, loss: 0.160 (data_loss: 0.160, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.967, loss: 0.189 (data_loss: 0.189, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.933, loss: 0.218 (data_loss: 0.218, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.900, loss: 0.273 (data_loss: 0.273, reg_loss: 0.000), lr: 0.1
# step: 500, acc: 0.967, loss: 0.095 (data_loss: 0.095, reg_loss: 0.000), lr: 0.1
# step: 600, acc: 0.883, loss: 0.301 (data_loss: 0.301, reg_loss: 0.000), lr: 0.1
# step: 700, acc: 0.883, loss: 0.474 (data_loss: 0.474, reg_loss: 0.000), lr: 0.1
# step: 800, acc: 0.883, loss: 0.270 (data_loss: 0.270, reg_loss: 0.000), lr: 0.1
# step: 900, acc: 0.900, loss: 0.198 (data_loss: 0.198, reg_loss: 0.000), lr: 0.1
# step: 999, acc: 0.900, loss: 0.194 (data_loss: 0.194, reg_loss: 0.000), lr: 0.1
# training, acc: 0.922, loss: 0.210 (data_loss: 0.210, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.881, loss: 0.352
# epoch: 17
# step: 0, acc: 0.933, loss: 0.162 (data_loss: 0.162, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.933, loss: 0.169 (data_loss: 0.169, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.950, loss: 0.173 (data_loss: 0.173, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.933, loss: 0.221 (data_loss: 0.221, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.883, loss: 0.253 (data_loss: 0.253, reg_loss: 0.000), lr: 0.1
# step: 500, acc: 0.983, loss: 0.083 (data_loss: 0.083, reg_loss: 0.000), lr: 0.1
# step: 600, acc: 0.900, loss: 0.268 (data_loss: 0.268, reg_loss: 0.000), lr: 0.1
# step: 700, acc: 0.883, loss: 0.457 (data_loss: 0.457, reg_loss: 0.000), lr: 0.1
# step: 800, acc: 0.883, loss: 0.276 (data_loss: 0.276, reg_loss: 0.000), lr: 0.1
# step: 900, acc: 0.900, loss: 0.193 (data_loss: 0.193, reg_loss: 0.000), lr: 0.1
# step: 999, acc: 0.900, loss: 0.187 (data_loss: 0.187, reg_loss: 0.000), lr: 0.1
# training, acc: 0.924, loss: 0.203 (data_loss: 0.203, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.881, loss: 0.355
# epoch: 18
# step: 0, acc: 0.933, loss: 0.170 (data_loss: 0.170, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.933, loss: 0.177 (data_loss: 0.177, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.983, loss: 0.165 (data_loss: 0.165, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.917, loss: 0.215 (data_loss: 0.215, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.900, loss: 0.245 (data_loss: 0.245, reg_loss: 0.000), lr: 0.1
# step: 500, acc: 0.967, loss: 0.082 (data_loss: 0.082, reg_loss: 0.000), lr: 0.1
# step: 600, acc: 0.917, loss: 0.270 (data_loss: 0.270, reg_loss: 0.000), lr: 0.1
# step: 700, acc: 0.900, loss: 0.446 (data_loss: 0.446, reg_loss: 0.000), lr: 0.1
# step: 800, acc: 0.883, loss: 0.254 (data_loss: 0.254, reg_loss: 0.000), lr: 0.1
# step: 900, acc: 0.933, loss: 0.168 (data_loss: 0.168, reg_loss: 0.000), lr: 0.1
# step: 999, acc: 0.917, loss: 0.190 (data_loss: 0.190, reg_loss: 0.000), lr: 0.1
# training, acc: 0.928, loss: 0.196 (data_loss: 0.196, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.881, loss: 0.352
# epoch: 19
# step: 0, acc: 0.933, loss: 0.159 (data_loss: 0.159, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.950, loss: 0.171 (data_loss: 0.171, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.983, loss: 0.154 (data_loss: 0.154, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.933, loss: 0.189 (data_loss: 0.189, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.883, loss: 0.237 (data_loss: 0.237, reg_loss: 0.000), lr: 0.1
# step: 500, acc: 0.967, loss: 0.073 (data_loss: 0.073, reg_loss: 0.000), lr: 0.1
# step: 600, acc: 0.917, loss: 0.256 (data_loss: 0.256, reg_loss: 0.000), lr: 0.1
# step: 700, acc: 0.883, loss: 0.445 (data_loss: 0.445, reg_loss: 0.000), lr: 0.1
# step: 800, acc: 0.867, loss: 0.242 (data_loss: 0.242, reg_loss: 0.000), lr: 0.1
# step: 900, acc: 0.933, loss: 0.173 (data_loss: 0.173, reg_loss: 0.000), lr: 0.1
# step: 999, acc: 0.933, loss: 0.170 (data_loss: 0.170, reg_loss: 0.000), lr: 0.1
# training, acc: 0.931, loss: 0.189 (data_loss: 0.189, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.882, loss: 0.356
# epoch: 20
# step: 0, acc: 0.933, loss: 0.159 (data_loss: 0.159, reg_loss: 0.000), lr: 0.1
# step: 100, acc: 0.933, loss: 0.161 (data_loss: 0.161, reg_loss: 0.000), lr: 0.1
# step: 200, acc: 0.983, loss: 0.151 (data_loss: 0.151, reg_loss: 0.000), lr: 0.1
# step: 300, acc: 0.933, loss: 0.193 (data_loss: 0.193, reg_loss: 0.000), lr: 0.1
# step: 400, acc: 0.917, loss: 0.253 (data_loss: 0.253, reg_loss: 0.000), lr: 0.1
# step: 500, acc: 0.967, loss: 0.074 (data_loss: 0.074, reg_loss: 0.000), lr: 0.1
# step: 600, acc: 0.933, loss: 0.250 (data_loss: 0.250, reg_loss: 0.000), lr: 0.1
# step: 700, acc: 0.900, loss: 0.442 (data_loss: 0.442, reg_loss: 0.000), lr: 0.1
# step: 800, acc: 0.883, loss: 0.234 (data_loss: 0.234, reg_loss: 0.000), lr: 0.1
# step: 900, acc: 0.950, loss: 0.161 (data_loss: 0.161, reg_loss: 0.000), lr: 0.1
# step: 999, acc: 0.933, loss: 0.153 (data_loss: 0.153, reg_loss: 0.000), lr: 0.1
# training, acc: 0.934, loss: 0.183 (data_loss: 0.183, reg_loss: 0.000), lr: 0.1
# validation, acc: 0.884, loss: 0.355
# validation, acc: 0.884, loss: 0.355

# %% [markdown]
# ### MLP Implementation 1

# %%
# Hyper-parameters
epochs = 250
lr = 1e-2
alpha = 0.1

batch_sizes = [64, 256, 512, 512]
K_sizes = [64, 128, 128, 60]

# ReLU
accuracies1 = []
for batch_size, K in zip(batch_sizes, K_sizes):
    mlp6 = MLP(
        # First Layer
        LinearLayer(n_features, K),
        ReLULayer(),
        # Second Layer
        LinearLayer(K, K),
        ReLULayer(),
        # Output Layer
        LinearLayer(K, n_classes),
        SoftmaxOutputLayer()
    )
    opt6 = GradientDescentOptimizer(mlp6, lr)

    mlp6.fit(opt6, X_train_fashion_std, y_train_fashion, epochs, batch_size, showplot=False)

    # Performance on Test dataset
    yh_test = mlp6.predict(X_test_fashion_std)
    accuracies1.append(evaluate_acc(y_test_fashion, yh_test))

print([(batch_size, K) for batch_size, K in zip(batch_sizes, K_sizes)])
print(accuracies1)

# ReLU
accuracies2 = []
for batch_size, K in zip(batch_sizes, K_sizes):
    mlp6 = MLP(
        # First Layer
        LinearLayer(n_features, K),
        LeakyReLULayer(alpha),
        # Second Layer
        LinearLayer(K, K),
        LeakyReLULayer(alpha),
        # Output Layer
        LinearLayer(K, n_classes),
        SoftmaxOutputLayer()
    )
    opt6 = GradientDescentOptimizer(mlp6, lr)

    mlp6.fit(opt6, X_train_fashion_std, y_train_fashion, epochs, batch_size, showplot=False)

    # Performance on Test dataset
    yh_test = mlp6.predict(X_test_fashion_std)
    accuracies2.append(evaluate_acc(y_test_fashion, yh_test))

print([(batch_size, K) for batch_size, K in zip(batch_sizes, K_sizes)])
print(accuracies2)
# Out:
# 100%|██████████| 250/250 [00:13<00:00, 19.21it/s]
# 100%|██████████| 250/250 [01:00<00:00,  4.17it/s]
# 100%|██████████| 250/250 [01:36<00:00,  2.58it/s]
# 100%|██████████| 250/250 [00:48<00:00,  5.13it/s]
# [(64, 64), (256, 128), (512, 128), (512, 60)]
# [0.6637, 0.7445, 0.7512, 0.6769]
# 100%|██████████| 250/250 [00:09<00:00, 25.90it/s]
# 100%|██████████| 250/250 [01:09<00:00,  3.61it/s]
# 100%|██████████| 250/250 [01:51<00:00,  2.24it/s]
# 100%|██████████| 250/250 [00:50<00:00,  4.91it/s]
# [(64, 64), (256, 128), (512, 128), (512, 60)]
# [0.6895, 0.7506, 0.7642, 0.7233]

# %% [markdown]
# ## **Part 7 - CNN Experiments.**

# %%
# Normalizing and reshaping the data
# First, we normalize the image pixel values from [0, 255] to [-0.5, 0.5]. 
# Second, we reshape the images from (28, 28) to (28, 28, 1) to add the third dimension required by Keras

# Normalize the images
X_train_fashion_normalized_cnn = (X_train_fashion_original / 255) - 0.5
X_test_fashion_normalized_cnn = (X_test_fashion_original / 255) - 0.5

print(X_train_fashion_normalized_cnn.shape) # (60000, 28, 28)
print(X_test_fashion_normalized_cnn.shape)  # (10000, 28, 28)

# Reshape the images.
X_train_fashion_normalized_cnn = np.expand_dims(X_train_fashion_normalized_cnn, axis=3)
X_test_fashion_normalized_cnn = np.expand_dims(X_test_fashion_normalized_cnn, axis=3)

print(X_train_fashion_normalized_cnn.shape) # (60000, 28, 28, 1)
print(X_test_fashion_normalized_cnn.shape)  # (10000, 28, 28, 1)

y_train_fashion_cnn = keras.utils.np_utils.to_categorical(y_train_fashion_original)
y_test_fashion_cnn = keras.utils.np_utils.to_categorical(y_test_fashion_original)
print(y_train_fashion_cnn.shape) # (60000, 10)
print(y_test_fashion_cnn.shape)  # (10000, 10)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)
# (60000, 10)
# (10000, 10)

# %% [markdown]
# ### Experiment 1

# %%
num_filters = 8
filter_size = 3
pool_size   = 2
num_classes = len(set(y_test_fashion_original))
input_shape = (X_train_fashion_normalized_cnn.shape[1:]) # (28, 28, 1)
batch_size  = 64
strides     = 1
padding     = 'valid' # valid: no padding, same: for zeros evenly right/left and up/down
                      # when padding="same" and strides=1, the output has the same size as the input
cnn_model_1 = Sequential()
cnn_model_1.add(Conv2D(filters = 4 * num_filters, # 8 filters 
                 kernel_size = filter_size,
                 strides     = strides,
                 input_shape = input_shape,
                 padding     = padding,
                 activation  = 'relu')) # Sequential model needs the input shape
cnn_model_1.add(Conv2D(filters = 8 * num_filters, kernel_size = (filter_size, filter_size)))
cnn_model_1.add(Dropout(0.25)) # randomly sets input units to 0 with a frequency of rate at each step during training time, to avoid overfitting
cnn_model_1.add(Flatten()) # Flatten serves as a connection between the convolution and dense layers
cnn_model_1.add(Dense(128, activation='relu')) # fully connected layer
cnn_model_1.add(Dense(num_classes, activation='softmax')) # output layer

# Compile the model
cnn_model_1.compile(
  'Adam',                              # Optimizer: SGD for gradient descent-based: https://keras.io/api/optimizers/
  loss='categorical_crossentropy',    # Loss function: Categorical for 10 classes: https://keras.io/api/losses/
  metrics=['accuracy'],               # accuracy metric, can choose from keras metrics: https://keras.io/api/metrics/
)

# Fitting the model
history = cnn_model_1.fit(
  X_train_fashion_normalized_cnn,
  y_train_fashion_cnn, 
  epochs=5,                # number of training epochs
  batch_size=batch_size,
  verbose = 1,
  validation_data=(X_test_fashion_normalized_cnn, y_test_fashion_cnn), # validation data
  callbacks=[checkpoint]      # callback to save the model during trainings 
)

# Model predictions and confusion matrix
test_predictions          = np.argmax(cnn_model_1.predict(X_test_fashion_normalized_cnn),1)
test_error, test_conf_mat = calc_error(test_predictions, np.argmax(y_test_fashion_cnn,1))
print('Test error: %.1f%%' % test_error)
accuracy = np.sum(y_test_fashion_original == test_predictions) / len(y_test_fashion_original)
accuracy
# Out:
# Epoch 1/5
# 938/938 [==============================] - ETA: 0s - loss: 0.3753 - accuracy: 0.8638
# Epoch 1: val_loss did not improve from 0.28023
# 938/938 [==============================] - 197s 209ms/step - loss: 0.3753 - accuracy: 0.8638 - val_loss: 0.3066 - val_accuracy: 0.8874
# Epoch 2/5
# 938/938 [==============================] - ETA: 0s - loss: 0.2501 - accuracy: 0.9082
# Epoch 2: val_loss improved from 0.28023 to 0.27907, saving model to mnist_best_model.hdf5
# 938/938 [==============================] - 197s 210ms/step - loss: 0.2501 - accuracy: 0.9082 - val_loss: 0.2791 - val_accuracy: 0.8958
# Epoch 3/5
# 938/938 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9275
# Epoch 3: val_loss improved from 0.27907 to 0.27029, saving model to mnist_best_model.hdf5
# 938/938 [==============================] - 205s 218ms/step - loss: 0.1952 - accuracy: 0.9275 - val_loss: 0.2703 - val_accuracy: 0.9105
# Epoch 4/5
# 938/938 [==============================] - ETA: 0s - loss: 0.1530 - accuracy: 0.9423
# Epoch 4: val_loss did not improve from 0.27029
# 938/938 [==============================] - 195s 208ms/step - loss: 0.1530 - accuracy: 0.9423 - val_loss: 0.2729 - val_accuracy: 0.9081
# Epoch 5/5
# 938/938 [==============================] - ETA: 0s - loss: 0.1187 - accuracy: 0.9559
# Epoch 5: val_loss did not improve from 0.27029
# 938/938 [==============================] - 195s 208ms/step - loss: 0.1187 - accuracy: 0.9559 - val_loss: 0.3095 - val_accuracy: 0.9041
# 313/313 [==============================] - 8s 25ms/step
# Test error: 9.6%
# 0.9041

# %% [markdown]
# ### Experiment 2

# %%
num_filters = 8
filter_size = 3
pool_size   = 2
num_classes = len(set(y_test_fashion_original))
input_shape = (X_train_fashion_normalized_cnn.shape[1:]) # (28, 28, 1)
batch_size  = 64
strides     = 1
padding     = 'valid' # valid: no padding, same: for zeros evenly right/left and up/down
                      # when padding="same" and strides=1, the output has the same size as the input
cnn_model_2 = Sequential()
cnn_model_2.add(Conv2D(filters = 4 * num_filters, # 8 filters 
                 kernel_size = filter_size,
                 strides     = strides,
                 input_shape = input_shape,
                 padding     = padding,
                 activation  = 'relu')) # Sequential model needs the input shape
cnn_model_2.add(Conv2D(filters = 8 * num_filters, kernel_size = (filter_size, filter_size)))
cnn_model_2.add(Dropout(0.25)) # randomly sets input units to 0 with a frequency of rate at each step during training time, to avoid overfitting
cnn_model_2.add(Flatten()) # Flatten serves as a connection between the convolution and dense layers
cnn_model_2.add(Dense(128, activation='relu')) # fully connected layer
cnn_model_2.add(Dense(num_classes, activation='softmax')) # output layer

# Compile the model
cnn_model_2.compile(
  'Adagrad',                              # Optimizer: SGD for gradient descent-based: https://keras.io/api/optimizers/
  loss='categorical_crossentropy',    # Loss function: Categorical for 10 classes: https://keras.io/api/losses/
  metrics=['accuracy'],               # accuracy metric, can choose from keras metrics: https://keras.io/api/metrics/
)

# Fitting the model
history = cnn_model_2.fit(
  X_train_fashion_normalized_cnn,
  y_train_fashion_cnn, 
  epochs=5,                # number of training epochs
  batch_size=batch_size,
  verbose = 1,
  validation_data=(X_test_fashion_normalized_cnn, y_test_fashion_cnn), # validation data
  callbacks=[checkpoint]      # callback to save the model during trainings 
)

# Model predictions and confusion matrix
test_predictions          = np.argmax(cnn_model_2.predict(X_test_fashion_normalized_cnn),1)
test_error, test_conf_mat = calc_error(test_predictions, np.argmax(y_test_fashion_cnn,1))
print('Test error: %.1f%%' % test_error)
accuracy = np.sum(y_test_fashion_original == test_predictions) / len(y_test_fashion_original)
accuracy
# Out:
# Epoch 1/5
# 938/938 [==============================] - ETA: 0s - loss: 0.8763 - accuracy: 0.7140
# Epoch 1: val_loss did not improve from 0.27029
# 938/938 [==============================] - 197s 210ms/step - loss: 0.8763 - accuracy: 0.7140 - val_loss: 0.6053 - val_accuracy: 0.7736
# Epoch 2/5
# 938/938 [==============================] - ETA: 0s - loss: 0.5505 - accuracy: 0.8004
# Epoch 2: val_loss did not improve from 0.27029
# 938/938 [==============================] - 193s 205ms/step - loss: 0.5505 - accuracy: 0.8004 - val_loss: 0.5667 - val_accuracy: 0.7926
# Epoch 3/5
# 938/938 [==============================] - ETA: 0s - loss: 0.5043 - accuracy: 0.8174
# Epoch 3: val_loss did not improve from 0.27029
# 938/938 [==============================] - 195s 208ms/step - loss: 0.5043 - accuracy: 0.8174 - val_loss: 0.5136 - val_accuracy: 0.8163
# Epoch 4/5
# 938/938 [==============================] - ETA: 0s - loss: 0.4768 - accuracy: 0.8281
# Epoch 4: val_loss did not improve from 0.27029
# 938/938 [==============================] - 195s 208ms/step - loss: 0.4768 - accuracy: 0.8281 - val_loss: 0.4850 - val_accuracy: 0.8280
# Epoch 5/5
# 938/938 [==============================] - ETA: 0s - loss: 0.4556 - accuracy: 0.8375
# Epoch 5: val_loss did not improve from 0.27029
# 938/938 [==============================] - 196s 209ms/step - loss: 0.4556 - accuracy: 0.8375 - val_loss: 0.4820 - val_accuracy: 0.8277
# 313/313 [==============================] - 8s 27ms/step
# Test error: 17.2%
# 0.8277

# %% [markdown]
# ### Experiment 3

# %%
num_filters = 8
filter_size = 3
pool_size   = 2
num_classes = len(set(y_test_fashion_original))
input_shape = (X_train_fashion_normalized_cnn.shape[1:]) # (28, 28, 1)
batch_size  = 64
strides     = 2
padding     = 'same' # valid: no padding, same: for zeros evenly right/left and up/down
                      # when padding="same" and strides=1, the output has the same size as the input
cnn_model_3 = Sequential()
cnn_model_3.add(Conv2D(filters = 4 * num_filters, # 8 filters 
                 kernel_size = filter_size,
                 strides     = strides,
                 input_shape = input_shape,
                 padding     = padding,
                 activation  = 'relu')) # Sequential model needs the input shape
cnn_model_3.add(Conv2D(filters = 8 * num_filters, kernel_size = (filter_size, filter_size)))
cnn_model_3.add(Dropout(0.25)) # randomly sets input units to 0 with a frequency of rate at each step during training time, to avoid overfitting
cnn_model_3.add(Flatten()) # Flatten serves as a connection between the convolution and dense layers
cnn_model_3.add(Dense(128, activation='relu')) # fully connected layer
cnn_model_3.add(Dense(num_classes, activation='softmax')) # output layer

# Compile the model
cnn_model_3.compile(
  'Adam',                              # Optimizer: SGD for gradient descent-based: https://keras.io/api/optimizers/
  loss='categorical_crossentropy',    # Loss function: Categorical for 10 classes: https://keras.io/api/losses/
  metrics=['accuracy'],               # accuracy metric, can choose from keras metrics: https://keras.io/api/metrics/
)

# Fitting the model
history = cnn_model_3.fit(
  X_train_fashion_normalized_cnn,
  y_train_fashion_cnn, 
  epochs=5,                # number of training epochs
  batch_size=batch_size,
  verbose = 1,
  validation_data=(X_test_fashion_normalized_cnn, y_test_fashion_cnn), # validation data
  callbacks=[checkpoint]      # callback to save the model during trainings 
)

# Model predictions and confusion matrix
test_predictions          = np.argmax(cnn_model_3.predict(X_test_fashion_normalized_cnn),1)
test_error, test_conf_mat = calc_error(test_predictions, np.argmax(y_test_fashion_cnn,1))
print('Test error: %.1f%%' % test_error)
accuracy = np.sum(y_test_fashion_original == test_predictions) / len(y_test_fashion_original)
accuracy
# Out:
# Epoch 1/5
# 937/938 [============================>.] - ETA: 0s - loss: 0.4153 - accuracy: 0.8487
# Epoch 1: val_loss did not improve from 0.27029
# 938/938 [==============================] - 57s 60ms/step - loss: 0.4155 - accuracy: 0.8486 - val_loss: 0.3288 - val_accuracy: 0.8836
# Epoch 2/5
# 937/938 [============================>.] - ETA: 0s - loss: 0.2797 - accuracy: 0.8967
# Epoch 2: val_loss did not improve from 0.27029
# 938/938 [==============================] - 56s 60ms/step - loss: 0.2797 - accuracy: 0.8968 - val_loss: 0.2985 - val_accuracy: 0.8924
# Epoch 3/5
# 937/938 [============================>.] - ETA: 0s - loss: 0.2300 - accuracy: 0.9147
# Epoch 3: val_loss improved from 0.27029 to 0.27029, saving model to mnist_best_model.hdf5
# 938/938 [==============================] - 56s 60ms/step - loss: 0.2300 - accuracy: 0.9147 - val_loss: 0.2703 - val_accuracy: 0.9019
# Epoch 4/5
# 937/938 [============================>.] - ETA: 0s - loss: 0.1963 - accuracy: 0.9265
# Epoch 4: val_loss did not improve from 0.27029
# 938/938 [==============================] - 58s 62ms/step - loss: 0.1963 - accuracy: 0.9265 - val_loss: 0.2730 - val_accuracy: 0.9020
# Epoch 5/5
# 937/938 [============================>.] - ETA: 0s - loss: 0.1700 - accuracy: 0.9369
# Epoch 5: val_loss did not improve from 0.27029
# 938/938 [==============================] - 56s 60ms/step - loss: 0.1700 - accuracy: 0.9369 - val_loss: 0.2711 - val_accuracy: 0.9062
# 313/313 [==============================] - 3s 8ms/step
# Test error: 9.4%
# 0.9062

# %% [markdown]
# ### Experiment 4

# %%
num_filters = 8
filter_size = 3
pool_size   = 2
num_classes = len(set(y_test_fashion_original))
input_shape = (X_train_fashion_normalized_cnn.shape[1:]) # (28, 28, 1)
batch_size  = 64
strides     = 2
padding     = 'same' # valid: no padding, same: for zeros evenly right/left and up/down
                      # when padding="same" and strides=1, the output has the same size as the input
cnn_model_4 = Sequential()
cnn_model_4.add(Conv2D(filters = 4 * num_filters, # 8 filters 
                 kernel_size = filter_size,
                 strides     = strides,
                 input_shape = input_shape,
                 padding     = padding,
                 activation  = 'relu')) # Sequential model needs the input shape
cnn_model_4.add(Conv2D(filters = 8 * num_filters, kernel_size = (filter_size, filter_size)))
cnn_model_4.add(Dropout(0.25)) # randomly sets input units to 0 with a frequency of rate at each step during training time, to avoid overfitting
cnn_model_4.add(Flatten()) # Flatten serves as a connection between the convolution and dense layers
cnn_model_4.add(Dense(1000, activation='relu')) # fully connected layer
cnn_model_4.add(Dense(num_classes, activation='softmax')) # output layer

# Compile the model
cnn_model_4.compile(
  'Adam',                              # Optimizer: SGD for gradient descent-based: https://keras.io/api/optimizers/
  loss='categorical_crossentropy',    # Loss function: Categorical for 10 classes: https://keras.io/api/losses/
  metrics=['accuracy'],               # accuracy metric, can choose from keras metrics: https://keras.io/api/metrics/
)

# Fitting the model
history = cnn_model_4.fit(
  X_train_fashion_normalized_cnn,
  y_train_fashion_cnn, 
  epochs=5,                # number of training epochs
  batch_size=batch_size,
  verbose = 1,
  validation_data=(X_test_fashion_normalized_cnn, y_test_fashion_cnn), # validation data
  callbacks=[checkpoint]      # callback to save the model during trainings 
)

# Model predictions and confusion matrix
test_predictions          = np.argmax(cnn_model_4.predict(X_test_fashion_normalized_cnn),1)
test_error, test_conf_mat = calc_error(test_predictions, np.argmax(y_test_fashion_cnn,1))
print('Test error: %.1f%%' % test_error)
accuracy = np.sum(y_test_fashion_original == test_predictions) / len(y_test_fashion_original)
accuracy
# Out:
# Epoch 1/5
# 938/938 [==============================] - ETA: 0s - loss: 0.3761 - accuracy: 0.8643
# Epoch 1: val_loss did not improve from 0.27029
# 938/938 [==============================] - 147s 156ms/step - loss: 0.3761 - accuracy: 0.8643 - val_loss: 0.3122 - val_accuracy: 0.8828
# Epoch 2/5
# 938/938 [==============================] - ETA: 0s - loss: 0.2505 - accuracy: 0.9069
# Epoch 2: val_loss did not improve from 0.27029
# 938/938 [==============================] - 142s 152ms/step - loss: 0.2505 - accuracy: 0.9069 - val_loss: 0.2720 - val_accuracy: 0.9020
# Epoch 3/5
# 938/938 [==============================] - ETA: 0s - loss: 0.1990 - accuracy: 0.9254
# Epoch 3: val_loss improved from 0.27029 to 0.26233, saving model to mnist_best_model.hdf5
# 938/938 [==============================] - 145s 155ms/step - loss: 0.1990 - accuracy: 0.9254 - val_loss: 0.2623 - val_accuracy: 0.9038
# Epoch 4/5
# 938/938 [==============================] - ETA: 0s - loss: 0.1574 - accuracy: 0.9407
# Epoch 4: val_loss did not improve from 0.26233
# 938/938 [==============================] - 143s 152ms/step - loss: 0.1574 - accuracy: 0.9407 - val_loss: 0.2802 - val_accuracy: 0.9046
# Epoch 5/5
# 938/938 [==============================] - ETA: 0s - loss: 0.1236 - accuracy: 0.9531
# Epoch 5: val_loss did not improve from 0.26233
# 938/938 [==============================] - 145s 155ms/step - loss: 0.1236 - accuracy: 0.9531 - val_loss: 0.2910 - val_accuracy: 0.9083
# 313/313 [==============================] - 8s 27ms/step
# Test error: 9.2%
# 0.9083

# %% [markdown]
# ### Experiment 5

# %%
num_filters = 8
filter_size = 3
pool_size   = 2
num_classes = len(set(y_test_fashion_original))
input_shape = (X_train_fashion_normalized_cnn.shape[1:]) # (28, 28, 1)
batch_size  = 64
strides     = 2
padding     = 'same' # valid: no padding, same: for zeros evenly right/left and up/down
                      # when padding="same" and strides=1, the output has the same size as the input
cnn_model_5 = Sequential()
cnn_model_5.add(Conv2D(filters = 4 * num_filters, # 8 filters 
                 kernel_size = filter_size,
                 strides     = strides,
                 input_shape = input_shape,
                 padding     = padding,
                 activation  = 'relu')) # Sequential model needs the input shape
cnn_model_5.add(Conv2D(filters = 8 * num_filters, kernel_size = (filter_size, filter_size)))
cnn_model_5.add(Dropout(0.25)) # randomly sets input units to 0 with a frequency of rate at each step during training time, to avoid overfitting
cnn_model_5.add(Flatten()) # Flatten serves as a connection between the convolution and dense layers
cnn_model_5.add(Dense(10, activation='relu')) # fully connected layer
cnn_model_5.add(Dense(num_classes, activation='softmax')) # output layer

# Compile the model
cnn_model_5.compile(
  'Adam',                              # Optimizer: SGD for gradient descent-based: https://keras.io/api/optimizers/
  loss='categorical_crossentropy',    # Loss function: Categorical for 10 classes: https://keras.io/api/losses/
  metrics=['accuracy'],               # accuracy metric, can choose from keras metrics: https://keras.io/api/metrics/
)

# Fitting the model
history = cnn_model_5.fit(
  X_train_fashion_normalized_cnn,
  y_train_fashion_cnn, 
  epochs=5,                # number of training epochs
  batch_size=batch_size,
  verbose = 1,
  validation_data=(X_test_fashion_normalized_cnn, y_test_fashion_cnn), # validation data
  callbacks=[checkpoint]      # callback to save the model during trainings 
)

# Model predictions and confusion matrix
test_predictions          = np.argmax(cnn_model_5.predict(X_test_fashion_normalized_cnn),1)
test_error, test_conf_mat = calc_error(test_predictions, np.argmax(y_test_fashion_cnn,1))
print('Test error: %.1f%%' % test_error)
accuracy = np.sum(y_test_fashion_original == test_predictions) / len(y_test_fashion_original)
accuracy
# Out:
# Epoch 1/5
# 937/938 [============================>.] - ETA: 0s - loss: 0.5409 - accuracy: 0.8087
# Epoch 1: val_loss did not improve from 0.26233
# 938/938 [==============================] - 45s 48ms/step - loss: 0.5410 - accuracy: 0.8087 - val_loss: 0.4174 - val_accuracy: 0.8491
# Epoch 2/5
# 938/938 [==============================] - ETA: 0s - loss: 0.3676 - accuracy: 0.8683
# Epoch 2: val_loss did not improve from 0.26233
# 938/938 [==============================] - 43s 46ms/step - loss: 0.3676 - accuracy: 0.8683 - val_loss: 0.3647 - val_accuracy: 0.8718
# Epoch 3/5
# 937/938 [============================>.] - ETA: 0s - loss: 0.3270 - accuracy: 0.8827
# Epoch 3: val_loss did not improve from 0.26233
# 938/938 [==============================] - 46s 49ms/step - loss: 0.3270 - accuracy: 0.8827 - val_loss: 0.3415 - val_accuracy: 0.8749
# Epoch 4/5
# 938/938 [==============================] - ETA: 0s - loss: 0.3008 - accuracy: 0.8927
# Epoch 4: val_loss did not improve from 0.26233
# 938/938 [==============================] - 44s 47ms/step - loss: 0.3008 - accuracy: 0.8927 - val_loss: 0.3224 - val_accuracy: 0.8836
# Epoch 5/5
# 937/938 [============================>.] - ETA: 0s - loss: 0.2849 - accuracy: 0.8972
# Epoch 5: val_loss did not improve from 0.26233
# 938/938 [==============================] - 44s 47ms/step - loss: 0.2850 - accuracy: 0.8972 - val_loss: 0.3135 - val_accuracy: 0.8848
# 313/313 [==============================] - 2s 7ms/step
# Test error: 11.5%
# 0.8848

# %% [markdown]
# ### Experiment 6

# %%
num_filters = 8
filter_size = 3
pool_size   = 2
num_classes = len(set(y_test_fashion_original))
input_shape = (X_train_fashion_normalized_cnn.shape[1:]) # (28, 28, 1)
batch_size  = 64
strides     = 2
padding     = 'same' # valid: no padding, same: for zeros evenly right/left and up/down
                      # when padding="same" and strides=1, the output has the same size as the input
cnn_model_6 = Sequential()
cnn_model_6.add(Conv2D(filters = 4 * num_filters, # 8 filters 
                 kernel_size = filter_size,
                 strides     = strides,
                 input_shape = input_shape,
                 padding     = padding,
                 activation  = 'relu')) # Sequential model needs the input shape
cnn_model_6.add(Conv2D(filters = 8 * num_filters, kernel_size = (filter_size, filter_size)))
cnn_model_6.add(Dropout(0.25)) # randomly sets input units to 0 with a frequency of rate at each step during training time, to avoid overfitting
cnn_model_6.add(Flatten()) # Flatten serves as a connection between the convolution and dense layers
cnn_model_6.add(Dense(5000, activation='relu')) # fully connected layer
cnn_model_6.add(Dense(num_classes, activation='softmax')) # output layer

# Compile the model
cnn_model_6.compile(
  'Adam',                              # Optimizer: SGD for gradient descent-based: https://keras.io/api/optimizers/
  loss='categorical_crossentropy',    # Loss function: Categorical for 10 classes: https://keras.io/api/losses/
  metrics=['accuracy'],               # accuracy metric, can choose from keras metrics: https://keras.io/api/metrics/
)

# Fitting the model
history = cnn_model_6.fit(
  X_train_fashion_normalized_cnn,
  y_train_fashion_cnn, 
  epochs=5,                # number of training epochs
  batch_size=batch_size,
  verbose = 1,
  validation_data=(X_test_fashion_normalized_cnn, y_test_fashion_cnn), # validation data
  callbacks=[checkpoint]      # callback to save the model during trainings 
)

# Model predictions and confusion matrix
test_predictions          = np.argmax(cnn_model_6.predict(X_test_fashion_normalized_cnn),1)
test_error, test_conf_mat = calc_error(test_predictions, np.argmax(y_test_fashion_cnn,1))
print('Test error: %.1f%%' % test_error)
accuracy = np.sum(y_test_fashion_original == test_predictions) / len(y_test_fashion_original)
accuracy
# Out:
# Epoch 1/5
# 938/938 [==============================] - ETA: 0s - loss: 0.3867 - accuracy: 0.8607
# Epoch 1: val_loss did not improve from 0.26233
# 938/938 [==============================] - 540s 574ms/step - loss: 0.3867 - accuracy: 0.8607 - val_loss: 0.3082 - val_accuracy: 0.8859
# Epoch 2/5
# 938/938 [==============================] - ETA: 0s - loss: 0.2547 - accuracy: 0.9050
# Epoch 2: val_loss did not improve from 0.26233
# 938/938 [==============================] - 526s 561ms/step - loss: 0.2547 - accuracy: 0.9050 - val_loss: 0.2740 - val_accuracy: 0.9003
# Epoch 3/5
# 938/938 [==============================] - ETA: 0s - loss: 0.1993 - accuracy: 0.9252
# Epoch 3: val_loss did not improve from 0.26233
# 938/938 [==============================] - 538s 573ms/step - loss: 0.1993 - accuracy: 0.9252 - val_loss: 0.2764 - val_accuracy: 0.9006
# Epoch 4/5
# 938/938 [==============================] - ETA: 0s - loss: 0.1539 - accuracy: 0.9420
# Epoch 4: val_loss did not improve from 0.26233
# 938/938 [==============================] - 531s 566ms/step - loss: 0.1539 - accuracy: 0.9420 - val_loss: 0.2709 - val_accuracy: 0.9064
# Epoch 5/5
# 938/938 [==============================] - ETA: 0s - loss: 0.1159 - accuracy: 0.9573
# Epoch 5: val_loss did not improve from 0.26233
# 938/938 [==============================] - 519s 554ms/step - loss: 0.1159 - accuracy: 0.9573 - val_loss: 0.3109 - val_accuracy: 0.9056
# 313/313 [==============================] - 30s 94ms/step
# Test error: 9.4%
# 0.9056

# %% [markdown]
# ### Experiment 7

# %%
num_filters = 8
filter_size = 3
pool_size   = 2
num_classes = len(set(y_test_fashion_original))
input_shape = (X_train_fashion_normalized_cnn.shape[1:]) # (28, 28, 1)
batch_size  = 64
strides     = 4
padding     = 'same' # valid: no padding, same: for zeros evenly right/left and up/down
                      # when padding="same" and strides=1, the output has the same size as the input
cnn_model_7 = Sequential()
cnn_model_7.add(Conv2D(filters = 4 * num_filters, # 8 filters 
                 kernel_size = filter_size,
                 strides     = strides,
                 input_shape = input_shape,
                 padding     = padding,
                 activation  = 'relu')) # Sequential model needs the input shape
# model.add(MaxPooling2D(pool_size=pool_size)) # Keras automatically infers the shapes of inputs of later layers
cnn_model_7.add(Conv2D(filters = 8 * num_filters, kernel_size = (filter_size, filter_size)))
# model.add(MaxPooling2D(pool_size=(pool_size, pool_size)))
cnn_model_7.add(Dropout(0.25)) # randomly sets input units to 0 with a frequency of rate at each step during training time, to avoid overfitting
cnn_model_7.add(Flatten()) # Flatten serves as a connection between the convolution and dense layers
cnn_model_7.add(Dense(1000, activation='relu')) # fully connected layer
cnn_model_7.add(Dense(num_classes, activation='softmax')) # output layer

# Compile the model
cnn_model_7.compile(
  'Adam',                              # Optimizer: SGD for gradient descent-based: https://keras.io/api/optimizers/
  loss='categorical_crossentropy',    # Loss function: Categorical for 10 classes: https://keras.io/api/losses/
  metrics=['accuracy'],               # accuracy metric, can choose from keras metrics: https://keras.io/api/metrics/
)

# Fitting the model
history = cnn_model_7.fit(
  X_train_fashion_normalized_cnn,
  y_train_fashion_cnn, 
  epochs=5,                # number of training epochs
  batch_size=batch_size,
  verbose = 1,
  validation_data=(X_test_fashion_normalized_cnn, y_test_fashion_cnn), # validation data
  callbacks=[checkpoint]      # callback to save the model during trainings 
)

# Model predictions and confusion matrix
test_predictions          = np.argmax(cnn_model_7.predict(X_test_fashion_normalized_cnn),1)
test_error, test_conf_mat = calc_error(test_predictions, np.argmax(y_test_fashion_cnn,1))
print('Test error: %.1f%%' % test_error)
accuracy = np.sum(y_test_fashion_original == test_predictions) / len(y_test_fashion_original)
accuracy
# Out:
# Epoch 1/5
# 938/938 [==============================] - ETA: 0s - loss: 0.4484 - accuracy: 0.8363
# Epoch 1: val_loss did not improve from 0.26233
# 938/938 [==============================] - 37s 38ms/step - loss: 0.4484 - accuracy: 0.8363 - val_loss: 0.3677 - val_accuracy: 0.8651
# Epoch 2/5
# 937/938 [============================>.] - ETA: 0s - loss: 0.3192 - accuracy: 0.8816
# Epoch 2: val_loss did not improve from 0.26233
# 938/938 [==============================] - 37s 40ms/step - loss: 0.3192 - accuracy: 0.8816 - val_loss: 0.3265 - val_accuracy: 0.8806
# Epoch 3/5
# 938/938 [==============================] - ETA: 0s - loss: 0.2767 - accuracy: 0.8976
# Epoch 3: val_loss did not improve from 0.26233
# 938/938 [==============================] - 33s 35ms/step - loss: 0.2767 - accuracy: 0.8976 - val_loss: 0.2943 - val_accuracy: 0.8923
# Epoch 4/5
# 938/938 [==============================] - ETA: 0s - loss: 0.2434 - accuracy: 0.9086
# Epoch 4: val_loss did not improve from 0.26233
# 938/938 [==============================] - 31s 33ms/step - loss: 0.2434 - accuracy: 0.9086 - val_loss: 0.2851 - val_accuracy: 0.8977
# Epoch 5/5
# 937/938 [============================>.] - ETA: 0s - loss: 0.2147 - accuracy: 0.9194
# Epoch 5: val_loss did not improve from 0.26233
# 938/938 [==============================] - 32s 35ms/step - loss: 0.2148 - accuracy: 0.9194 - val_loss: 0.2864 - val_accuracy: 0.8995
# 313/313 [==============================] - 3s 10ms/step
# Test error: 10.0%
# 0.8995

# %% [markdown]
# ## **Part 8 - MLP Implementation 2: Adam Optimizer Experiment**

# %%
class Optimizer_Adam:
    def __init__(self, learning_rate=0.001, decay=0., epsilon=1e-7,
                 beta_1=0.9, beta_2=0.999):
        self.learning_rate = learning_rate
        self.current_learning_rate = learning_rate
        self.decay = decay
        self.iterations = 0
        self.epsilon = epsilon
        self.beta_1 = beta_1
        self.beta_2 = beta_2

    def pre_update_params(self):
        if self.decay:
            self.current_learning_rate = self.learning_rate * (1. / (1. + self.decay * self.iterations))

    # Update parameters
    def update_params(self, layer):
        if not hasattr(layer, 'weight_cache'):
            layer.weight_momentums = np.zeros_like(layer.weights)
            layer.weight_cache = np.zeros_like(layer.weights)
            layer.bias_momentums = np.zeros_like(layer.biases)
            layer.bias_cache = np.zeros_like(layer.biases)
        layer.weight_momentums = self.beta_1 * layer.weight_momentums + (1 - self.beta_1) * layer.dweights
        layer.bias_momentums = self.beta_1 * layer.bias_momentums + (1 - self.beta_1) * layer.dbiases
    
        weight_momentums_corrected = layer.weight_momentums / (1 - self.beta_1 ** (self.iterations + 1))
        bias_momentums_corrected = layer.bias_momentums / (1 - self.beta_1 ** (self.iterations + 1))
        layer.weight_cache = self.beta_2 * layer.weight_cache + (1 - self.beta_2) * layer.dweights**2
        layer.bias_cache = self.beta_2 * layer.bias_cache + (1 - self.beta_2) * layer.dbiases**2
        # Get corrected cache
        weight_cache_corrected = layer.weight_cache /  (1 - self.beta_2 ** (self.iterations + 1))
        bias_cache_corrected = layer.bias_cache /(1 - self.beta_2 ** (self.iterations + 1))
        # Vanilla SGD parameter update + normalization
        # with square rooted cache
        layer.weights += -self.current_learning_rate * weight_momentums_corrected / (np.sqrt(weight_cache_corrected) + self.epsilon)
        layer.biases += -self.current_learning_rate * bias_momentums_corrected / (np.sqrt(bias_cache_corrected) + self.epsilon)

    def post_update_params(self):
        self.iterations += 1
        
# Source: Harrison Kinsley & Daniel Kukieła Neural Networks from Scratch (NNFS) https://nnfs.io

# %%
# Instantiate the model
model = Model()
# Add layers
model.add(Layer_Dense(X_train_fashion_normalized.shape[1], 512))
model.add(Activation_ReLU())
model.add(Layer_Dense(512, 512))
model.add(Activation_ReLU())
model.add(Layer_Dense(512, 10))
model.add(Activation_Softmax())

# Set loss, optimizer and accuracy objects
model.set(
loss=Loss_CategoricalCrossentropy(),
optimizer=Optimizer_Adam(learning_rate=0.001),
accuracy=Accuracy_Categorical()
)

# Finalize the model
model.finalize()
# Train the model
model.train(X_train_fashion_normalized, y_train_fashion, validation_data=(X_test_fashion_normalized, y_test_fashion),
epochs=20, batch_size=60, print_every=100)
model.evaluate(X_test_fashion_normalized, y_test_fashion)

plt.figure(figsize=(8, 8))
plt.title("MLP Implementation 2: Plot of Accuracies as Function of Epochs", fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.plot(model.validation_accuracies, 'g-',label='Test Accuracies')
plt.plot(model.training_accuracies, 'r-',label='Training Accuracies')
plt.legend()
# Out:
# epoch: 1
# step: 0, acc: 0.100, loss: 2.303 (data_loss: 2.303, reg_loss: 0.000), lr: 0.001
# step: 100, acc: 0.767, loss: 0.627 (data_loss: 0.627, reg_loss: 0.000), lr: 0.001
# step: 200, acc: 0.800, loss: 0.441 (data_loss: 0.441, reg_loss: 0.000), lr: 0.001
# step: 300, acc: 0.783, loss: 0.647 (data_loss: 0.647, reg_loss: 0.000), lr: 0.001
# step: 400, acc: 0.733, loss: 0.754 (data_loss: 0.754, reg_loss: 0.000), lr: 0.001
# step: 500, acc: 0.783, loss: 0.489 (data_loss: 0.489, reg_loss: 0.000), lr: 0.001
# step: 600, acc: 0.750, loss: 0.588 (data_loss: 0.588, reg_loss: 0.000), lr: 0.001
# step: 700, acc: 0.883, loss: 0.504 (data_loss: 0.504, reg_loss: 0.000), lr: 0.001
# step: 800, acc: 0.833, loss: 0.418 (data_loss: 0.418, reg_loss: 0.000), lr: 0.001
# step: 900, acc: 0.867, loss: 0.335 (data_loss: 0.335, reg_loss: 0.000), lr: 0.001
# step: 999, acc: 0.833, loss: 0.421 (data_loss: 0.421, reg_loss: 0.000), lr: 0.001
# training, acc: 0.806, loss: 0.527 (data_loss: 0.527, reg_loss: 0.000), lr: 0.001
# validation, acc: 0.829, loss: 0.455
# epoch: 2
# step: 0, acc: 0.917, loss: 0.285 (data_loss: 0.285, reg_loss: 0.000), lr: 0.001
# step: 100, acc: 0.867, loss: 0.333 (data_loss: 0.333, reg_loss: 0.000), lr: 0.001
# step: 200, acc: 0.867, loss: 0.268 (data_loss: 0.268, reg_loss: 0.000), lr: 0.001
# step: 300, acc: 0.817, loss: 0.454 (data_loss: 0.454, reg_loss: 0.000), lr: 0.001
# step: 400, acc: 0.767, loss: 0.659 (data_loss: 0.659, reg_loss: 0.000), lr: 0.001
# step: 500, acc: 0.850, loss: 0.321 (data_loss: 0.321, reg_loss: 0.000), lr: 0.001
# step: 600, acc: 0.833, loss: 0.471 (data_loss: 0.471, reg_loss: 0.000), lr: 0.001
# step: 700, acc: 0.850, loss: 0.478 (data_loss: 0.478, reg_loss: 0.000), lr: 0.001
# step: 800, acc: 0.850, loss: 0.438 (data_loss: 0.438, reg_loss: 0.000), lr: 0.001
# step: 900, acc: 0.933, loss: 0.281 (data_loss: 0.281, reg_loss: 0.000), lr: 0.001
# step: 999, acc: 0.867, loss: 0.354 (data_loss: 0.354, reg_loss: 0.000), lr: 0.001
# training, acc: 0.864, loss: 0.368 (data_loss: 0.368, reg_loss: 0.000), lr: 0.001
# validation, acc: 0.844, loss: 0.427
# epoch: 3
# step: 0, acc: 0.933, loss: 0.243 (data_loss: 0.243, reg_loss: 0.000), lr: 0.001
# step: 100, acc: 0.883, loss: 0.282 (data_loss: 0.282, reg_loss: 0.000), lr: 0.001
# step: 200, acc: 0.917, loss: 0.210 (data_loss: 0.210, reg_loss: 0.000), lr: 0.001
# step: 300, acc: 0.850, loss: 0.358 (data_loss: 0.358, reg_loss: 0.000), lr: 0.001
# step: 400, acc: 0.783, loss: 0.603 (data_loss: 0.603, reg_loss: 0.000), lr: 0.001
# step: 500, acc: 0.883, loss: 0.230 (data_loss: 0.230, reg_loss: 0.000), lr: 0.001
# step: 600, acc: 0.833, loss: 0.432 (data_loss: 0.432, reg_loss: 0.000), lr: 0.001
# step: 700, acc: 0.867, loss: 0.495 (data_loss: 0.495, reg_loss: 0.000), lr: 0.001
# step: 800, acc: 0.817, loss: 0.409 (data_loss: 0.409, reg_loss: 0.000), lr: 0.001
# step: 900, acc: 0.933, loss: 0.249 (data_loss: 0.249, reg_loss: 0.000), lr: 0.001
# step: 999, acc: 0.867, loss: 0.348 (data_loss: 0.348, reg_loss: 0.000), lr: 0.001
# training, acc: 0.881, loss: 0.325 (data_loss: 0.325, reg_loss: 0.000), lr: 0.001
# validation, acc: 0.853, loss: 0.397
# epoch: 4
# step: 0, acc: 0.933, loss: 0.215 (data_loss: 0.215, reg_loss: 0.000), lr: 0.001
# step: 100, acc: 0.883, loss: 0.253 (data_loss: 0.253, reg_loss: 0.000), lr: 0.001
# step: 200, acc: 0.950, loss: 0.168 (data_loss: 0.168, reg_loss: 0.000), lr: 0.001
# step: 300, acc: 0.833, loss: 0.318 (data_loss: 0.318, reg_loss: 0.000), lr: 0.001
# step: 400, acc: 0.817, loss: 0.524 (data_loss: 0.524, reg_loss: 0.000), lr: 0.001
# step: 500, acc: 0.933, loss: 0.203 (data_loss: 0.203, reg_loss: 0.000), lr: 0.001
# step: 600, acc: 0.867, loss: 0.396 (data_loss: 0.396, reg_loss: 0.000), lr: 0.001
# step: 700, acc: 0.883, loss: 0.513 (data_loss: 0.513, reg_loss: 0.000), lr: 0.001
# step: 800, acc: 0.833, loss: 0.418 (data_loss: 0.418, reg_loss: 0.000), lr: 0.001
# step: 900, acc: 0.933, loss: 0.289 (data_loss: 0.289, reg_loss: 0.000), lr: 0.001
# step: 999, acc: 0.883, loss: 0.321 (data_loss: 0.321, reg_loss: 0.000), lr: 0.001
# training, acc: 0.889, loss: 0.299 (data_loss: 0.299, reg_loss: 0.000), lr: 0.001
# validation, acc: 0.865, loss: 0.374
# epoch: 5
# step: 0, acc: 0.917, loss: 0.184 (data_loss: 0.184, reg_loss: 0.000), lr: 0.001
# step: 100, acc: 0.900, loss: 0.253 (data_loss: 0.253, reg_loss: 0.000), lr: 0.001
# step: 200, acc: 0.933, loss: 0.156 (data_loss: 0.156, reg_loss: 0.000), lr: 0.001
# step: 300, acc: 0.883, loss: 0.273 (data_loss: 0.273, reg_loss: 0.000), lr: 0.001
# step: 400, acc: 0.817, loss: 0.433 (data_loss: 0.433, reg_loss: 0.000), lr: 0.001
# step: 500, acc: 0.950, loss: 0.176 (data_loss: 0.176, reg_loss: 0.000), lr: 0.001
# step: 600, acc: 0.850, loss: 0.391 (data_loss: 0.391, reg_loss: 0.000), lr: 0.001
# step: 700, acc: 0.867, loss: 0.506 (data_loss: 0.506, reg_loss: 0.000), lr: 0.001
# step: 800, acc: 0.833, loss: 0.395 (data_loss: 0.395, reg_loss: 0.000), lr: 0.001
# step: 900, acc: 0.917, loss: 0.260 (data_loss: 0.260, reg_loss: 0.000), lr: 0.001
# step: 999, acc: 0.850, loss: 0.321 (data_loss: 0.321, reg_loss: 0.000), lr: 0.001
# training, acc: 0.896, loss: 0.277 (data_loss: 0.277, reg_loss: 0.000), lr: 0.001
# validation, acc: 0.868, loss: 0.365
# epoch: 6
# step: 0, acc: 0.933, loss: 0.188 (data_loss: 0.188, reg_loss: 0.000), lr: 0.001
# step: 100, acc: 0.883, loss: 0.246 (data_loss: 0.246, reg_loss: 0.000), lr: 0.001
# step: 200, acc: 0.933, loss: 0.180 (data_loss: 0.180, reg_loss: 0.000), lr: 0.001
# step: 300, acc: 0.867, loss: 0.270 (data_loss: 0.270, reg_loss: 0.000), lr: 0.001
# step: 400, acc: 0.817, loss: 0.396 (data_loss: 0.396, reg_loss: 0.000), lr: 0.001
# step: 500, acc: 0.950, loss: 0.167 (data_loss: 0.167, reg_loss: 0.000), lr: 0.001
# step: 600, acc: 0.867, loss: 0.424 (data_loss: 0.424, reg_loss: 0.000), lr: 0.001
# step: 700, acc: 0.883, loss: 0.494 (data_loss: 0.494, reg_loss: 0.000), lr: 0.001
# step: 800, acc: 0.833, loss: 0.345 (data_loss: 0.345, reg_loss: 0.000), lr: 0.001
# step: 900, acc: 0.900, loss: 0.255 (data_loss: 0.255, reg_loss: 0.000), lr: 0.001
# step: 999, acc: 0.850, loss: 0.274 (data_loss: 0.274, reg_loss: 0.000), lr: 0.001
# training, acc: 0.902, loss: 0.258 (data_loss: 0.258, reg_loss: 0.000), lr: 0.001
# validation, acc: 0.869, loss: 0.369
# epoch: 7
# step: 0, acc: 0.933, loss: 0.178 (data_loss: 0.178, reg_loss: 0.000), lr: 0.001
# step: 100, acc: 0.883, loss: 0.199 (data_loss: 0.199, reg_loss: 0.000), lr: 0.001
# step: 200, acc: 0.950, loss: 0.156 (data_loss: 0.156, reg_loss: 0.000), lr: 0.001
# step: 300, acc: 0.883, loss: 0.220 (data_loss: 0.220, reg_loss: 0.000), lr: 0.001
# step: 400, acc: 0.883, loss: 0.348 (data_loss: 0.348, reg_loss: 0.000), lr: 0.001
# step: 500, acc: 0.967, loss: 0.150 (data_loss: 0.150, reg_loss: 0.000), lr: 0.001
# step: 600, acc: 0.883, loss: 0.351 (data_loss: 0.351, reg_loss: 0.000), lr: 0.001
# step: 700, acc: 0.900, loss: 0.449 (data_loss: 0.449, reg_loss: 0.000), lr: 0.001
# step: 800, acc: 0.800, loss: 0.401 (data_loss: 0.401, reg_loss: 0.000), lr: 0.001
# step: 900, acc: 0.917, loss: 0.250 (data_loss: 0.250, reg_loss: 0.000), lr: 0.001
# step: 999, acc: 0.850, loss: 0.263 (data_loss: 0.263, reg_loss: 0.000), lr: 0.001
# training, acc: 0.908, loss: 0.243 (data_loss: 0.243, reg_loss: 0.000), lr: 0.001
# validation, acc: 0.875, loss: 0.366
# epoch: 8
# step: 0, acc: 0.917, loss: 0.180 (data_loss: 0.180, reg_loss: 0.000), lr: 0.001
# step: 100, acc: 0.883, loss: 0.201 (data_loss: 0.201, reg_loss: 0.000), lr: 0.001
# step: 200, acc: 0.950, loss: 0.121 (data_loss: 0.121, reg_loss: 0.000), lr: 0.001
# step: 300, acc: 0.867, loss: 0.191 (data_loss: 0.191, reg_loss: 0.000), lr: 0.001
# step: 400, acc: 0.867, loss: 0.332 (data_loss: 0.332, reg_loss: 0.000), lr: 0.001
# step: 500, acc: 0.950, loss: 0.120 (data_loss: 0.120, reg_loss: 0.000), lr: 0.001
# step: 600, acc: 0.883, loss: 0.329 (data_loss: 0.329, reg_loss: 0.000), lr: 0.001
# step: 700, acc: 0.883, loss: 0.490 (data_loss: 0.490, reg_loss: 0.000), lr: 0.001
# step: 800, acc: 0.850, loss: 0.278 (data_loss: 0.278, reg_loss: 0.000), lr: 0.001
# step: 900, acc: 0.933, loss: 0.267 (data_loss: 0.267, reg_loss: 0.000), lr: 0.001
# step: 999, acc: 0.883, loss: 0.282 (data_loss: 0.282, reg_loss: 0.000), lr: 0.001
# training, acc: 0.913, loss: 0.229 (data_loss: 0.229, reg_loss: 0.000), lr: 0.001
# validation, acc: 0.875, loss: 0.364
# epoch: 9
# step: 0, acc: 0.950, loss: 0.151 (data_loss: 0.151, reg_loss: 0.000), lr: 0.001
# step: 100, acc: 0.917, loss: 0.195 (data_loss: 0.195, reg_loss: 0.000), lr: 0.001
# step: 200, acc: 0.967, loss: 0.106 (data_loss: 0.106, reg_loss: 0.000), lr: 0.001
# step: 300, acc: 0.900, loss: 0.202 (data_loss: 0.202, reg_loss: 0.000), lr: 0.001
# step: 400, acc: 0.850, loss: 0.293 (data_loss: 0.293, reg_loss: 0.000), lr: 0.001
# step: 500, acc: 0.983, loss: 0.112 (data_loss: 0.112, reg_loss: 0.000), lr: 0.001
# step: 600, acc: 0.883, loss: 0.309 (data_loss: 0.309, reg_loss: 0.000), lr: 0.001
# step: 700, acc: 0.883, loss: 0.427 (data_loss: 0.427, reg_loss: 0.000), lr: 0.001
# step: 800, acc: 0.867, loss: 0.256 (data_loss: 0.256, reg_loss: 0.000), lr: 0.001
# step: 900, acc: 0.950, loss: 0.235 (data_loss: 0.235, reg_loss: 0.000), lr: 0.001
# step: 999, acc: 0.883, loss: 0.223 (data_loss: 0.223, reg_loss: 0.000), lr: 0.001
# training, acc: 0.917, loss: 0.217 (data_loss: 0.217, reg_loss: 0.000), lr: 0.001
# validation, acc: 0.877, loss: 0.362
# epoch: 10
# step: 0, acc: 0.950, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# step: 100, acc: 0.900, loss: 0.182 (data_loss: 0.182, reg_loss: 0.000), lr: 0.001
# step: 200, acc: 0.983, loss: 0.081 (data_loss: 0.081, reg_loss: 0.000), lr: 0.001
# step: 300, acc: 0.883, loss: 0.181 (data_loss: 0.181, reg_loss: 0.000), lr: 0.001
# step: 400, acc: 0.867, loss: 0.302 (data_loss: 0.302, reg_loss: 0.000), lr: 0.001
# step: 500, acc: 0.950, loss: 0.129 (data_loss: 0.129, reg_loss: 0.000), lr: 0.001
# step: 600, acc: 0.850, loss: 0.341 (data_loss: 0.341, reg_loss: 0.000), lr: 0.001
# step: 700, acc: 0.883, loss: 0.449 (data_loss: 0.449, reg_loss: 0.000), lr: 0.001
# step: 800, acc: 0.917, loss: 0.203 (data_loss: 0.203, reg_loss: 0.000), lr: 0.001
# step: 900, acc: 0.933, loss: 0.199 (data_loss: 0.199, reg_loss: 0.000), lr: 0.001
# step: 999, acc: 0.917, loss: 0.222 (data_loss: 0.222, reg_loss: 0.000), lr: 0.001
# training, acc: 0.922, loss: 0.205 (data_loss: 0.205, reg_loss: 0.000), lr: 0.001
# validation, acc: 0.885, loss: 0.348
# epoch: 11
# step: 0, acc: 0.950, loss: 0.118 (data_loss: 0.118, reg_loss: 0.000), lr: 0.001
# step: 100, acc: 0.900, loss: 0.196 (data_loss: 0.196, reg_loss: 0.000), lr: 0.001
# step: 200, acc: 0.983, loss: 0.069 (data_loss: 0.069, reg_loss: 0.000), lr: 0.001
# step: 300, acc: 0.917, loss: 0.186 (data_loss: 0.186, reg_loss: 0.000), lr: 0.001
# step: 400, acc: 0.900, loss: 0.289 (data_loss: 0.289, reg_loss: 0.000), lr: 0.001
# step: 500, acc: 0.967, loss: 0.146 (data_loss: 0.146, reg_loss: 0.000), lr: 0.001
# step: 600, acc: 0.850, loss: 0.297 (data_loss: 0.297, reg_loss: 0.000), lr: 0.001
# step: 700, acc: 0.917, loss: 0.405 (data_loss: 0.405, reg_loss: 0.000), lr: 0.001
# step: 800, acc: 0.883, loss: 0.214 (data_loss: 0.214, reg_loss: 0.000), lr: 0.001
# step: 900, acc: 0.950, loss: 0.199 (data_loss: 0.199, reg_loss: 0.000), lr: 0.001
# step: 999, acc: 0.883, loss: 0.190 (data_loss: 0.190, reg_loss: 0.000), lr: 0.001
# training, acc: 0.925, loss: 0.195 (data_loss: 0.195, reg_loss: 0.000), lr: 0.001
# validation, acc: 0.882, loss: 0.369
# epoch: 12
# step: 0, acc: 0.933, loss: 0.137 (data_loss: 0.137, reg_loss: 0.000), lr: 0.001
# step: 100, acc: 0.900, loss: 0.165 (data_loss: 0.165, reg_loss: 0.000), lr: 0.001
# step: 200, acc: 0.967, loss: 0.112 (data_loss: 0.112, reg_loss: 0.000), lr: 0.001
# step: 300, acc: 0.967, loss: 0.104 (data_loss: 0.104, reg_loss: 0.000), lr: 0.001
# step: 400, acc: 0.883, loss: 0.273 (data_loss: 0.273, reg_loss: 0.000), lr: 0.001
# step: 500, acc: 0.983, loss: 0.082 (data_loss: 0.082, reg_loss: 0.000), lr: 0.001
# step: 600, acc: 0.917, loss: 0.245 (data_loss: 0.245, reg_loss: 0.000), lr: 0.001
# step: 700, acc: 0.883, loss: 0.430 (data_loss: 0.430, reg_loss: 0.000), lr: 0.001
# step: 800, acc: 0.883, loss: 0.203 (data_loss: 0.203, reg_loss: 0.000), lr: 0.001
# step: 900, acc: 0.950, loss: 0.208 (data_loss: 0.208, reg_loss: 0.000), lr: 0.001
# step: 999, acc: 0.917, loss: 0.185 (data_loss: 0.185, reg_loss: 0.000), lr: 0.001
# training, acc: 0.929, loss: 0.185 (data_loss: 0.185, reg_loss: 0.000), lr: 0.001
# validation, acc: 0.876, loss: 0.402
# epoch: 13
# step: 0, acc: 0.933, loss: 0.114 (data_loss: 0.114, reg_loss: 0.000), lr: 0.001
# step: 100, acc: 0.917, loss: 0.186 (data_loss: 0.186, reg_loss: 0.000), lr: 0.001
# step: 200, acc: 1.000, loss: 0.060 (data_loss: 0.060, reg_loss: 0.000), lr: 0.001
# step: 300, acc: 0.917, loss: 0.148 (data_loss: 0.148, reg_loss: 0.000), lr: 0.001
# step: 400, acc: 0.883, loss: 0.264 (data_loss: 0.264, reg_loss: 0.000), lr: 0.001
# step: 500, acc: 0.967, loss: 0.104 (data_loss: 0.104, reg_loss: 0.000), lr: 0.001
# step: 600, acc: 0.917, loss: 0.193 (data_loss: 0.193, reg_loss: 0.000), lr: 0.001
# step: 700, acc: 0.900, loss: 0.389 (data_loss: 0.389, reg_loss: 0.000), lr: 0.001
# step: 800, acc: 0.900, loss: 0.202 (data_loss: 0.202, reg_loss: 0.000), lr: 0.001
# step: 900, acc: 0.933, loss: 0.187 (data_loss: 0.187, reg_loss: 0.000), lr: 0.001
# step: 999, acc: 0.950, loss: 0.158 (data_loss: 0.158, reg_loss: 0.000), lr: 0.001
# training, acc: 0.932, loss: 0.177 (data_loss: 0.177, reg_loss: 0.000), lr: 0.001
# validation, acc: 0.884, loss: 0.380
# epoch: 14
# step: 0, acc: 0.967, loss: 0.096 (data_loss: 0.096, reg_loss: 0.000), lr: 0.001
# step: 100, acc: 0.867, loss: 0.199 (data_loss: 0.199, reg_loss: 0.000), lr: 0.001
# step: 200, acc: 0.967, loss: 0.087 (data_loss: 0.087, reg_loss: 0.000), lr: 0.001
# step: 300, acc: 0.950, loss: 0.143 (data_loss: 0.143, reg_loss: 0.000), lr: 0.001
# step: 400, acc: 0.883, loss: 0.226 (data_loss: 0.226, reg_loss: 0.000), lr: 0.001
# step: 500, acc: 0.983, loss: 0.072 (data_loss: 0.072, reg_loss: 0.000), lr: 0.001
# step: 600, acc: 0.950, loss: 0.180 (data_loss: 0.180, reg_loss: 0.000), lr: 0.001
# step: 700, acc: 0.883, loss: 0.408 (data_loss: 0.408, reg_loss: 0.000), lr: 0.001
# step: 800, acc: 0.917, loss: 0.155 (data_loss: 0.155, reg_loss: 0.000), lr: 0.001
# step: 900, acc: 0.917, loss: 0.191 (data_loss: 0.191, reg_loss: 0.000), lr: 0.001
# step: 999, acc: 0.933, loss: 0.159 (data_loss: 0.159, reg_loss: 0.000), lr: 0.001
# training, acc: 0.934, loss: 0.169 (data_loss: 0.169, reg_loss: 0.000), lr: 0.001
# validation, acc: 0.886, loss: 0.381
# epoch: 15
# step: 0, acc: 0.967, loss: 0.093 (data_loss: 0.093, reg_loss: 0.000), lr: 0.001
# step: 100, acc: 0.917, loss: 0.128 (data_loss: 0.128, reg_loss: 0.000), lr: 0.001
# step: 200, acc: 1.000, loss: 0.043 (data_loss: 0.043, reg_loss: 0.000), lr: 0.001
# step: 300, acc: 0.967, loss: 0.106 (data_loss: 0.106, reg_loss: 0.000), lr: 0.001
# step: 400, acc: 0.933, loss: 0.185 (data_loss: 0.185, reg_loss: 0.000), lr: 0.001
# step: 500, acc: 0.983, loss: 0.098 (data_loss: 0.098, reg_loss: 0.000), lr: 0.001
# step: 600, acc: 0.900, loss: 0.166 (data_loss: 0.166, reg_loss: 0.000), lr: 0.001
# step: 700, acc: 0.933, loss: 0.313 (data_loss: 0.313, reg_loss: 0.000), lr: 0.001
# step: 800, acc: 0.933, loss: 0.156 (data_loss: 0.156, reg_loss: 0.000), lr: 0.001
# step: 900, acc: 0.933, loss: 0.186 (data_loss: 0.186, reg_loss: 0.000), lr: 0.001
# step: 999, acc: 0.950, loss: 0.205 (data_loss: 0.205, reg_loss: 0.000), lr: 0.001
# training, acc: 0.938, loss: 0.160 (data_loss: 0.160, reg_loss: 0.000), lr: 0.001
# validation, acc: 0.876, loss: 0.410
# epoch: 16
# step: 0, acc: 0.933, loss: 0.111 (data_loss: 0.111, reg_loss: 0.000), lr: 0.001
# step: 100, acc: 0.900, loss: 0.213 (data_loss: 0.213, reg_loss: 0.000), lr: 0.001
# step: 200, acc: 1.000, loss: 0.043 (data_loss: 0.043, reg_loss: 0.000), lr: 0.001
# step: 300, acc: 0.933, loss: 0.127 (data_loss: 0.127, reg_loss: 0.000), lr: 0.001
# step: 400, acc: 0.950, loss: 0.199 (data_loss: 0.199, reg_loss: 0.000), lr: 0.001
# step: 500, acc: 0.983, loss: 0.069 (data_loss: 0.069, reg_loss: 0.000), lr: 0.001
# step: 600, acc: 0.967, loss: 0.130 (data_loss: 0.130, reg_loss: 0.000), lr: 0.001
# step: 700, acc: 0.933, loss: 0.324 (data_loss: 0.324, reg_loss: 0.000), lr: 0.001
# step: 800, acc: 0.933, loss: 0.184 (data_loss: 0.184, reg_loss: 0.000), lr: 0.001
# step: 900, acc: 0.900, loss: 0.209 (data_loss: 0.209, reg_loss: 0.000), lr: 0.001
# step: 999, acc: 0.900, loss: 0.192 (data_loss: 0.192, reg_loss: 0.000), lr: 0.001
# training, acc: 0.941, loss: 0.151 (data_loss: 0.151, reg_loss: 0.000), lr: 0.001
# validation, acc: 0.874, loss: 0.448
# epoch: 17
# step: 0, acc: 0.950, loss: 0.124 (data_loss: 0.124, reg_loss: 0.000), lr: 0.001
# step: 100, acc: 0.933, loss: 0.176 (data_loss: 0.176, reg_loss: 0.000), lr: 0.001
# step: 200, acc: 0.983, loss: 0.059 (data_loss: 0.059, reg_loss: 0.000), lr: 0.001
# step: 300, acc: 0.967, loss: 0.106 (data_loss: 0.106, reg_loss: 0.000), lr: 0.001
# step: 400, acc: 0.933, loss: 0.114 (data_loss: 0.114, reg_loss: 0.000), lr: 0.001
# step: 500, acc: 0.950, loss: 0.133 (data_loss: 0.133, reg_loss: 0.000), lr: 0.001
# step: 600, acc: 0.900, loss: 0.198 (data_loss: 0.198, reg_loss: 0.000), lr: 0.001
# step: 700, acc: 0.933, loss: 0.284 (data_loss: 0.284, reg_loss: 0.000), lr: 0.001
# step: 800, acc: 0.950, loss: 0.132 (data_loss: 0.132, reg_loss: 0.000), lr: 0.001
# step: 900, acc: 0.950, loss: 0.149 (data_loss: 0.149, reg_loss: 0.000), lr: 0.001
# step: 999, acc: 0.933, loss: 0.138 (data_loss: 0.138, reg_loss: 0.000), lr: 0.001
# training, acc: 0.942, loss: 0.149 (data_loss: 0.149, reg_loss: 0.000), lr: 0.001
# validation, acc: 0.883, loss: 0.420
# epoch: 18
# step: 0, acc: 0.933, loss: 0.118 (data_loss: 0.118, reg_loss: 0.000), lr: 0.001
# step: 100, acc: 0.900, loss: 0.168 (data_loss: 0.168, reg_loss: 0.000), lr: 0.001
# step: 200, acc: 0.967, loss: 0.089 (data_loss: 0.089, reg_loss: 0.000), lr: 0.001
# step: 300, acc: 0.967, loss: 0.236 (data_loss: 0.236, reg_loss: 0.000), lr: 0.001
# step: 400, acc: 0.983, loss: 0.125 (data_loss: 0.125, reg_loss: 0.000), lr: 0.001
# step: 500, acc: 0.983, loss: 0.052 (data_loss: 0.052, reg_loss: 0.000), lr: 0.001
# step: 600, acc: 0.917, loss: 0.156 (data_loss: 0.156, reg_loss: 0.000), lr: 0.001
# step: 700, acc: 0.917, loss: 0.265 (data_loss: 0.265, reg_loss: 0.000), lr: 0.001
# step: 800, acc: 0.967, loss: 0.164 (data_loss: 0.164, reg_loss: 0.000), lr: 0.001
# step: 900, acc: 0.967, loss: 0.134 (data_loss: 0.134, reg_loss: 0.000), lr: 0.001
# step: 999, acc: 0.950, loss: 0.133 (data_loss: 0.133, reg_loss: 0.000), lr: 0.001
# training, acc: 0.944, loss: 0.144 (data_loss: 0.144, reg_loss: 0.000), lr: 0.001
# validation, acc: 0.884, loss: 0.455
# epoch: 19
# step: 0, acc: 0.933, loss: 0.117 (data_loss: 0.117, reg_loss: 0.000), lr: 0.001
# step: 100, acc: 0.850, loss: 0.243 (data_loss: 0.243, reg_loss: 0.000), lr: 0.001
# step: 200, acc: 0.983, loss: 0.070 (data_loss: 0.070, reg_loss: 0.000), lr: 0.001
# step: 300, acc: 0.950, loss: 0.100 (data_loss: 0.100, reg_loss: 0.000), lr: 0.001
# step: 400, acc: 0.933, loss: 0.262 (data_loss: 0.262, reg_loss: 0.000), lr: 0.001
# step: 500, acc: 0.933, loss: 0.087 (data_loss: 0.087, reg_loss: 0.000), lr: 0.001
# step: 600, acc: 0.883, loss: 0.190 (data_loss: 0.190, reg_loss: 0.000), lr: 0.001
# step: 700, acc: 0.933, loss: 0.207 (data_loss: 0.207, reg_loss: 0.000), lr: 0.001
# step: 800, acc: 0.950, loss: 0.121 (data_loss: 0.121, reg_loss: 0.000), lr: 0.001
# step: 900, acc: 0.950, loss: 0.138 (data_loss: 0.138, reg_loss: 0.000), lr: 0.001
# step: 999, acc: 0.933, loss: 0.233 (data_loss: 0.233, reg_loss: 0.000), lr: 0.001
# training, acc: 0.947, loss: 0.134 (data_loss: 0.134, reg_loss: 0.000), lr: 0.001
# validation, acc: 0.871, loss: 0.590
# epoch: 20
# step: 0, acc: 0.933, loss: 0.236 (data_loss: 0.236, reg_loss: 0.000), lr: 0.001
# step: 100, acc: 0.900, loss: 0.190 (data_loss: 0.190, reg_loss: 0.000), lr: 0.001
# step: 200, acc: 0.933, loss: 0.087 (data_loss: 0.087, reg_loss: 0.000), lr: 0.001
# step: 300, acc: 0.967, loss: 0.203 (data_loss: 0.203, reg_loss: 0.000), lr: 0.001
# step: 400, acc: 0.950, loss: 0.111 (data_loss: 0.111, reg_loss: 0.000), lr: 0.001
# step: 500, acc: 1.000, loss: 0.038 (data_loss: 0.038, reg_loss: 0.000), lr: 0.001
# step: 600, acc: 0.883, loss: 0.319 (data_loss: 0.319, reg_loss: 0.000), lr: 0.001
# step: 700, acc: 0.917, loss: 0.195 (data_loss: 0.195, reg_loss: 0.000), lr: 0.001
# step: 800, acc: 0.950, loss: 0.154 (data_loss: 0.154, reg_loss: 0.000), lr: 0.001
# step: 900, acc: 0.933, loss: 0.172 (data_loss: 0.172, reg_loss: 0.000), lr: 0.001
# step: 999, acc: 0.917, loss: 0.114 (data_loss: 0.114, reg_loss: 0.000), lr: 0.001
# training, acc: 0.949, loss: 0.130 (data_loss: 0.130, reg_loss: 0.000), lr: 0.001
# validation, acc: 0.882, loss: 0.487
# validation, acc: 0.882, loss: 0.487
